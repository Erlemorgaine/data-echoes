# %%
# Restrictions: ONLY named individuals

import pandas as pd

json_file_path = './ice-and-fire.json'
df = pd.read_json(json_file_path)
df.drop('predecessor', axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1345 entries, 0 to 1344
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1345 non-null   object
#  1   allegiance     1186 non-null   object
#  2   father         942 non-null    object
#  3   successor      194 non-null    object
#  4   url            1345 non-null   object
#  5   fatherRumored  11 non-null     object
#  6   mother         490 non-null    object
#  7   spouse         524 non-null    object
#  8   motherRumored  2 non-null      object
# dtypes: object(9)
# memory usage: 94.7+ KB

# %%
# Remove datapoints that have no relation at all.
# Old code and technically not necessarily anymore, already done in node.js
data_without_relation = df[(df['father'].isnull()) \
                           & (df['mother'].isnull()) \
                           & (df['successor'].isnull()) \
                           & (df['spouse'].isnull())]

data_with_relation = df[~df['name'].isin(data_without_relation['name'])]
data_with_relation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1316 entries, 0 to 1344
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1316 non-null   object
#  1   allegiance     1173 non-null   object
#  2   father         942 non-null    object
#  3   successor      194 non-null    object
#  4   url            1316 non-null   object
#  5   fatherRumored  11 non-null     object
#  6   mother         490 non-null    object
#  7   spouse         524 non-null    object
#  8   motherRumored  2 non-null      object
# dtypes: object(9)
# memory usage: 102.8+ KB

# %%
duplicate_names = df[df['name'].duplicated()]
duplicate_names['name'].value_counts()
# Out:
# Series([], Name: name, dtype: int64)

# %%
# Weed out double fathers.
# Some are actually double, because they are rumoured
multiple_fathers = df[df['father'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_fathers['father']
# Out:
# Series([], Name: father, dtype: object)

# %%
# Weed out double moms.
# Some are actually double, because they are rumoured
multiple_mothers = df[df['mother'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_mothers['mother']
# Out:
# Series([], Name: mother, dtype: object)

# %%
# Weed out erratic spouses.
multiple_spouses = df[df['spouse'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_spouses[['name', 'spouse']]
# Out:
#                                         name  \
# 5                              Adrack Humble
# 82                             Alys Karstark
# 103                          Alyssa Velaryon
# 108                              Amerei Frey
# 290                                  Craster
# 293                             Cregan Stark
# 310                         Daemon Targaryen
# 328                           Dalton Greyjoy
# 342                              Davos Dayne
# 369                         Donella Hornwood
# 401                        Elaena Targaryen
# 407                         Elenda Baratheon
# 413                         Elinor Costayne
# 421                              Ellyn Reyne
# 497                         Gerold Lannister
# 518                      Gunthor Goodbrother
# 596                              Huzhor Amai
# 621          Jason Lannister (son of Gerold)
# 652      Jeyne Westerling (wife of Maegor I)
# 669                                Jon Arryn
# 689                             Jonnel Stark
# 694                            Jorah Mormont
# 710                          Kiera of Tyrosh
# 795                               Lysa Arryn
# 796                              Lysa Farman
# 824                          Margaery Tyrell
# 924                        Nymeria of Ny Sar
# 986                          Quellon Greyjoy
# 994                              Ramsay Snow
# 1019  Rhaena Targaryen (daughter of Aenys I)
# 1020   Rhaena Targaryen (daughter of Daemon)
# 1022                      Rhaenyra Targaryen
# 1077                        Rohanne Webber
# 1093                            Roose Bolton
# 1120                          Samantha Tarly
# 1138                            Serena Stark
# 1172                            Stevron Frey
# 1193                                    Tess
# 1239                        Tyrion Lannister
# 1274                           Veron Greyjoy
# 1301                             Walder Frey
# 1323                            Willam Stark
#
#                                                  spouse
# 5                                [Rock wife, Salt wife]
# 82                                     [Sigorn, Thenns]
# 103                [Aenys I Targaryen, Rogar Baratheon]
# 108           [Pate of the Blue Fork, Lancel Lannister]
# 290                         [Dyah, Ferny, Nella, Gilly]
# 293     [Arra Norrey, Alysanne Blackwood, Lynara Stark]
# 310    [Rhea Royce, Laena Velaryon, Rhaenyra Targaryen]
# 328                          [Tess, Kayce, Lysa Farman]
# 342                                   [Nymeria, Ny Sar]
# 369                       [Halys Hornwood, Ramsay Snow]
# 401   [Ossifer Plumm, Ronnel Penrose, Michael Manwoody]
# 407              [Borros Baratheon, Steffon Connington]
# 413                  [Theo Bolling, Maegor I Targaryen]
# 421                  [Tion Lannister, Walderan Tarbeck]
# 497                   [Alysanne Farman, Rohanne Webber]
# 518                            [Lysa Farman, Salt wife]
# 596                            [Cymmeri, Gipps, Zoqora]
# 621                    [Alys Stackspear, Marla Prester]
# 652                  [Alyn Tarbeck, Maegor I Targaryen]
# 669             [Jeyne Royce, Rowena Arryn, Lysa Arryn]
# 689   [Sansa Stark (daughter of Rickon), Robyn Ryswell]
# 694                   [House Glover, Lynesse Hightower]
# 710   [Valarr Targaryen, Daeron Targaryen (son of Ma...
# 795                          [Jon Arryn, Petyr Baelish]
# 796    [Dalton Greyjoy, Salt wife, Gunthor Goodbrother]
# 824   [Renly Baratheon, Joffrey Baratheon, Tommen Ba...
# 924   [Mors Martell, House Uller, Hellholt, Davos Da...
# 986   [Lady Stonetree (wife of Quellon Greyjoy), Lad...
# 994                     [Donella Hornwood, Jeyne Poole]
# 1019  [Aegon Targaryen (son of Aenys I), Maegor I Ta...
# 1020                [Corwyn Corbray, Garmund Hightower]
# 1022                [Laenor Velaryon, Daemon Targaryen]
# 1077  [Simon Staunton, Rolland Uffering, Eustace Osg...
# 1093  [Bethany Bolton, Walda Frey (daughter of Merre...
# 1120               [Ormund Hightower, Lyonel Hightower]
# 1138  [Jon Umber (husband of Serena), Edric Stark (s...
# 1172   [Corenna Swann, Jeyne Lydden, Marsella Waynwood]
# 1193                        [Dalton Greyjoy, Salt wife]
# 1239                               [Tysha, Sansa Stark]
# 1274                          [House Farman, Salt wife]
# 1301  [Perra Royce, Cyrenna Swann, Amarei Crakehall,...
# 1323                [Lyanne Glover, Melantha Blackwood]

# %%
# Datapoints with children
data_with_children = data_with_relation[
    (~data_with_relation['successor'].isnull()) 
    | (data_with_relation['name'].isin(data_with_relation['mother']))
    | (data_with_relation['name'].isin(data_with_relation['father']))]

data_with_children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462 entries, 0 to 1343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           462 non-null    object
#  1   allegiance     374 non-null    object
#  2   father         255 non-null    object
#  3   successor      194 non-null    object
#  4   url            462 non-null    object
#  5   fatherRumored  2 non-null      object
#  6   mother         148 non-null    object
#  7   spouse         290 non-null    object
#  8   motherRumored  0 non-null      object
# dtypes: object(9)
# memory usage: 36.1+ KB

# %%
# Datapoints for whom spouse is the only relationship

data_with_spouses = data_with_relation[(~data_with_relation['spouse'].isnull()) 
                                      & (df['father'].isnull()) 
                                       & (df['mother'].isnull()) 
                                       & (df['successor'].isnull())]

data_with_spouses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 5 to 1343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           257 non-null    object
#  1   allegiance     242 non-null    object
#  2   father         0 non-null      object
#  3   successor      0 non-null      object
#  4   url            257 non-null    object
#  5   fatherRumored  0 non-null      object
#  6   mother         0 non-null      object
#  7   spouse         257 non-null    object
#  8   motherRumored  0 non-null      object
# dtypes: object(9)
# memory usage: 20.1+ KB
# /var/folders/dy/hw0ckby90bxf_gm4t4jmb1yh0000gn/T/ipykernel_73323/936377067.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_with_spouses = data_with_relation[(~data_with_relation['spouse'].isnull())

# %%
data_with_spouses.head()
# Out:
#                name                        allegiance father successor  \
# 5     Adrack Humble     [House Humble, House Greyjoy]    NaN      None
# 22  Aelinor Penrose  [House Penrose, House Targaryen]    NaN      None
# 47    Alarra Massey    [House Massey, House Velaryon]    NaN      None
# 50           Alayne                   [House Baelish]    NaN      None
# 74     Alyn Tarbeck                   [House Tarbeck]    NaN      None
#
#                                                   url fatherRumored mother  \
# 5   http://awoiaf.westeros.org/index.php/Adrack_Hu...           NaN    NaN
# 22  http://awoiaf.westeros.org/index.php/Aelinor_P...           NaN    NaN
# 47  http://awoiaf.westeros.org/index.php/Alarra_Ma...           NaN    NaN
# 50  http://awoiaf.westeros.org/index.php/Alayne_Ba...           NaN    NaN
# 74  http://awoiaf.westeros.org/index.php/Alyn_Tarbeck           NaN    NaN
#
#                                    spouse motherRumored
# 5                  [Rock wife, Salt wife]           NaN
# 22                    [Aerys I Targaryen]           NaN
# 47                      [Aethan Velaryon]           NaN
# 50                       [Baelish (lord)]           NaN
# 74  [Jeyne Westerling (wife of Maegor I)]           NaN

# %%
# Get spouses that have a spouse present in the dataset with all 
# parent-child relationships

parent_child_spouses = df.explode('spouse').dropna(subset=['spouse'])['spouse'].unique()
data_spouse_family = data_with_spouses[data_with_spouses['name'].isin(parent_child_spouses)]
data_spouse_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 47 to 1343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           192 non-null    object
#  1   allegiance     182 non-null    object
#  2   father         0 non-null      object
#  3   successor      0 non-null      object
#  4   url            192 non-null    object
#  5   fatherRumored  0 non-null      object
#  6   mother         0 non-null      object
#  7   spouse         192 non-null    object
#  8   motherRumored  0 non-null      object
# dtypes: object(9)
# memory usage: 15.0+ KB

# %%
data_spouse_family.head()
# Out:
#                             name                      allegiance father  \
# 47                 Alarra Massey  [House Massey, House Velaryon]    NaN
# 74                  Alyn Tarbeck                 [House Tarbeck]    NaN
# 78  Alys Arryn (wife of Rhaegel)  [House Arryn, House Targaryen]    NaN
# 79                 Alys Beesbury  [House Beesbury, House Tyrell]    NaN
# 80                     Alys Frey                    [House Frey]    NaN
#
#    successor                                                url fatherRumored  \
# 47      None  http://awoiaf.westeros.org/index.php/Alarra_Ma...           NaN
# 74      None  http://awoiaf.westeros.org/index.php/Alyn_Tarbeck           NaN
# 78      None  http://awoiaf.westeros.org/index.php/Alys_Arry...           NaN
# 79      None  http://awoiaf.westeros.org/index.php/Alys_Bees...           NaN
# 80      None     http://awoiaf.westeros.org/index.php/Alys_Frey           NaN
#
#    mother                                 spouse motherRumored
# 47    NaN                      [Aethan Velaryon]           NaN
# 74    NaN  [Jeyne Westerling (wife of Maegor I)]           NaN
# 78    NaN                    [Rhaegel Targaryen]           NaN
# 79    NaN           [Leo Tyrell (son of Victor)]           NaN
# 80    NaN                           [Jared Frey]           NaN

# %%
all_usable_data = pd.concat([data_with_children, data_spouse_family])
len(all_usable_data)
# Out:
# 654

# %%
all_usable_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 654 entries, 0 to 1343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           654 non-null    object
#  1   allegiance     556 non-null    object
#  2   father         255 non-null    object
#  3   successor      194 non-null    object
#  4   url            654 non-null    object
#  5   fatherRumored  2 non-null      object
#  6   mother         148 non-null    object
#  7   spouse         482 non-null    object
#  8   motherRumored  0 non-null      object
# dtypes: object(9)
# memory usage: 51.1+ KB

# %%
first_layer = all_usable_data[(all_usable_data['father'].isnull()) & (all_usable_data['mother'].isnull())]
first_layer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 47 to 1343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           392 non-null    object
#  1   allegiance     344 non-null    object
#  2   father         0 non-null      object
#  3   successor      80 non-null     object
#  4   url            392 non-null    object
#  5   fatherRumored  0 non-null      object
#  6   mother         0 non-null      object
#  7   spouse         324 non-null    object
#  8   motherRumored  0 non-null      object
# dtypes: object(9)
# memory usage: 30.6+ KB

# %%
all_usable_data.explode('allegiance').dropna(subset=['allegiance']).value_counts('allegiance').head(50)
# Out:
# allegiance
# House Frey                        87
# House Targaryen                   63
# House Stark                       55
# House Lannister                   47
# Blacks                            29
# House Tyrell                      25
# House Baratheon                   18
# House Hightower                   18
# House Velaryon                    16
# House Arryn                       13
# Greens                            13
# House Martell                     12
# House Greyjoy                     11
# House Waynwood                    10
# House Tarbeck                      9
# House Tully                        9
# House Florent                      9
# House Royce                        8
# House Manderly                     8
# House Glover                       8
# House Westerling                   8
# House Blackwood                    7
# House Redwyne                      7
# House Stokeworth                   7
# City Watch of King's Landing       7
# House Swann                        6
# House Locke                        6
# House Bracken                      6
# House Karstark                     6
# Kingsguard                         6
# Brotherhood without banners        6
# House Rowan                        6
# House Beesbury                     6
# Night's Watch                      6
# House Tallhart                     5
# House Baratheon of Dragonstone     5
# House Crakehall                    5
# House Blackfyre                    5
# House Wylde                        5
# House Mormont                      5
# House Whent                        5
# House Bolton                       5
# House Osgrey                       5
# House Tarly                        4
# House Hornwood                     4
# House Marbrand                     4
# House Reed                         4
# House Darklyn                      4
# House Haigh                        4
# Second Sons                        4
# dtype: int64

# %%
first_layer[first_layer['successor'].notna()]['successor'].head(100)
# Out:
# 58          [Alekyne Florent, Davos Seaworth]
# 65           [Edwell Celtigar, Osmund Strong]
# 73      [Lord Stokeworth, Maegor I Targaryen]
# 107                            [Lord Hayford]
# 131                       [Arlan V Durrandon]
#                         ...
# 1257                        [Torgon Greyiron]
# 1263                      [Urrigon Hightower]
# 1273                                 [Qyburn]
# 1322                         [Barbrey Dustin]
# 1331                         [Rohanne Webber]
# Name: successor, Length: 80, dtype: object

# %%
# Transform nodes into partnerships (= single or couple), 
# so that they will be easier to use in a hierarchical structure

all_with_spouse = all_usable_data[all_usable_data['spouse'].notnull()]
all_with_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 482 entries, 24 to 1343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           482 non-null    object
#  1   allegiance     467 non-null    object
#  2   father         155 non-null    object
#  3   successor      61 non-null     object
#  4   url            482 non-null    object
#  5   fatherRumored  1 non-null      object
#  6   mother         102 non-null    object
#  7   spouse         482 non-null    object
#  8   motherRumored  0 non-null      object
# dtypes: object(9)
# memory usage: 37.7+ KB

# %%
all_no_spouse = all_usable_data[all_usable_data['spouse'].isna()]
all_no_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 0 to 1331
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           172 non-null    object
#  1   allegiance     89 non-null     object
#  2   father         100 non-null    object
#  3   successor      133 non-null    object
#  4   url            172 non-null    object
#  5   fatherRumored  1 non-null      object
#  6   mother         46 non-null     object
#  7   spouse         0 non-null      object
#  8   motherRumored  0 non-null      object
# dtypes: object(9)
# memory usage: 13.4+ KB

# %%
all_with_spouse.reset_index(inplace=True)
all_relations = all_with_spouse.explode('spouse').dropna(subset=['spouse'])
all_relations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 519 entries, 0 to 481
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          519 non-null    int64
#  1   name           519 non-null    object
#  2   allegiance     500 non-null    object
#  3   father         188 non-null    object
#  4   successor      77 non-null     object
#  5   url            519 non-null    object
#  6   fatherRumored  1 non-null      object
#  7   mother         119 non-null    object
#  8   spouse         519 non-null    object
#  9   motherRumored  0 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 44.6+ KB

# %%
# all_relations.reset_index(inplace=True)
all_relations_with_spouse = all_relations.merge(all_relations, how='left', left_on='spouse', right_on='name', suffixes=('', '_spouse'))

# trick to be able to drop duplicates even of some values are lists
# all_relations_with_spouse = all_relations_with_spouse.loc[all_relations_with_spouse.astype(str).drop_duplicates().index]
all_relations_with_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 527 entries, 0 to 827
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 527 non-null    int64
#  1   name                  527 non-null    object
#  2   allegiance            502 non-null    object
#  3   father                208 non-null    object
#  4   successor             86 non-null     object
#  5   url                   527 non-null    object
#  6   fatherRumored         1 non-null      object
#  7   mother                130 non-null    object
#  8   spouse                527 non-null    object
#  9   motherRumored         0 non-null      object
#  10  index_spouse          417 non-null    float64
#  11  name_spouse           417 non-null    object
#  12  allegiance_spouse     397 non-null    object
#  13  father_spouse         241 non-null    object
#  14  successor_spouse      70 non-null     object
#  15  url_spouse            417 non-null    object
#  16  fatherRumored_spouse  1 non-null      object
#  17  mother_spouse         122 non-null    object
#  18  spouse_spouse         417 non-null    object
#  19  motherRumored_spouse  0 non-null      object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 86.5+ KB

# %%
all_relations_with_spouse[all_relations_with_spouse['name_spouse'].isna()].head(20)
# Out:
#      index                name  \
# 0       24    Aelora Targaryen
# 1       26         Aemma Arryn
# 8       45      Alannys Harlaw
# 15      62   Alicent Hightower
# 26      81       Alys Harroway
# 35      99  Alysanne Targaryen
# 44     102    Alyssa Targaryen
# 45     103     Alyssa Velaryon
# 55     107  Ambrose Butterwell
# 73     143          Arya Flint
# 89     200     Betha Blackwood
# 103    210    Borros Baratheon
# 113    264        Cerissa Brax
# 114    266    Cersei Lannister
# 123    290             Craster
# 138    306    Daemon Blackfyre
# 143    312     Daena Targaryen
# 144    313   Daenaera Velaryon
# 153    327               Dalla
# 156    328      Dalton Greyjoy
#
#                                             allegiance                 father  \
# 0                                    [House Targaryen]      Rhaegel Targaryen
# 1                       [House Arryn, House Targaryen]           Rodrik Arryn
# 8                        [House Greyjoy, House Harlaw]           House Harlaw
# 15          [House Hightower, House Targaryen, Greens]         Otto Hightower
# 26                   [House Harroway, House Targaryen]         Lucas Harroway
# 35                                   [House Targaryen]      Aenys I Targaryen
# 44                                   [House Targaryen]  Jaehaerys I Targaryen
# 45   [House Velaryon, House Targaryen, House Barath...        Aethan Velaryon
# 55   [House Butterwell, House Targaryen, House Blac...                    NaN
# 73         [House Flint of the mountains, House Stark]                    NaN
# 89                  [House Blackwood, House Targaryen]        House Blackwood
# 103                          [House Baratheon, Greens]     Boremund Baratheon
# 113                      [House Brax, House Lannister]                    NaN
# 114  [House Lannister, House Baratheon of King's La...        Tywin Lannister
# 123                                                NaN                    NaN
# 138                                  [House Blackfyre]     Aegon IV Targaryen
# 143                                  [House Targaryen]    Aegon III Targaryen
# 144                  [House Velaryon, House Targaryen]        Daeron Velaryon
# 153                                     [Mance Rayder]                    NaN
# 156                            [House Greyjoy, Blacks]          House Greyjoy
#
#                                              successor  \
# 0                                 [Maekar I Targaryen]
# 1                                  [Alicent Hightower]
# 8                                                 None
# 15               [Helaena Targaryen, Daemon Targaryen]
# 26             [Ceryse Hightower, Tyanna of the Tower]
# 35                                       [Aemma Arryn]
# 44                                                None
# 45                                                None
# 55                                      [Lord Hayford]
# 73                                                None
# 89                                  [Shaera Targaryen]
# 103                                               None
# 113                                               None
# 114  [Joffrey Baratheon, Kevan Lannister, Margaery ...
# 123                                               None
# 138        [Daemon II Blackfyre, Blackfyre Pretenders]
# 143                                 [Naerys Targaryen]
# 144                                  [Daena Targaryen]
# 153                                               None
# 156                                               None
#
#                                                    url fatherRumored  \
# 0    http://awoiaf.westeros.org/index.php/Aelora_Ta...           NaN
# 1     http://awoiaf.westeros.org/index.php/Aemma_Arryn           NaN
# 8    http://awoiaf.westeros.org/index.php/Alannys_H...           NaN
# 15   http://awoiaf.westeros.org/index.php/Alicent_H...           NaN
# 26   http://awoiaf.westeros.org/index.php/Alys_Harr...           NaN
# 35   http://awoiaf.westeros.org/index.php/Alysanne_...           NaN
# 44   http://awoiaf.westeros.org/index.php/Alyssa_Ta...           NaN
# 45   http://awoiaf.westeros.org/index.php/Alyssa_Ve...           NaN
# 55   http://awoiaf.westeros.org/index.php/Ambrose_B...           NaN
# 73     http://awoiaf.westeros.org/index.php/Arya_Flint           NaN
# 89   http://awoiaf.westeros.org/index.php/Betha_Bla...           NaN
# 103  http://awoiaf.westeros.org/index.php/Borros_Ba...           NaN
# 113  http://awoiaf.westeros.org/index.php/Cerissa_Brax           NaN
# 114  http://awoiaf.westeros.org/index.php/Cersei_La...           NaN
# 123       http://awoiaf.westeros.org/index.php/Craster           NaN
# 138  http://awoiaf.westeros.org/index.php/Daemon_I_...           NaN
# 143  http://awoiaf.westeros.org/index.php/Daena_Tar...           NaN
# 144  http://awoiaf.westeros.org/index.php/Daenaera_...           NaN
# 153         http://awoiaf.westeros.org/index.php/Dalla           NaN
# 156  http://awoiaf.westeros.org/index.php/Dalton_Gr...           NaN
#
#                                          mother  \
# 0                  Alys Arryn (wife of Rhaegel)
# 1    Daella Targaryen (daughter of Jaehaerys I)
# 8                                           NaN
# 15                                          NaN
# 26                                          NaN
# 35                              Alyssa Velaryon
# 44                           Alysanne Targaryen
# 45                                Alarra Massey
# 55                                          NaN
# 73                                          NaN
# 89                                          NaN
# 103                                         NaN
# 113                                         NaN
# 114                            Joanna Lannister
# 123                                         NaN
# 138                             Daena Targaryen
# 143                           Daenaera Velaryon
# 144                                 Hazel Harte
# 153                                         NaN
# 156                                         NaN
#
#                                      spouse motherRumored  index_spouse  \
# 0                           Aelor Targaryen           NaN           NaN
# 1                       Viserys I Targaryen           NaN           NaN
# 8                             Balon Greyjoy           NaN           NaN
# 15                      Viserys I Targaryen           NaN           NaN
# 26                       Maegor I Targaryen           NaN           NaN
# 35                    Jaehaerys I Targaryen           NaN           NaN
# 44    Baelon Targaryen (son of Jaehaerys I)           NaN           NaN
# 45                        Aenys I Targaryen           NaN           NaN
# 55   Lady Frey (wife of Ambrose Butterwell)           NaN           NaN
# 73              Rodrik Stark (son of Beron)           NaN           NaN
# 89                        Aegon V Targaryen           NaN           NaN
# 103                            Elenda Caron           NaN           NaN
# 113                  Damon Lannister (lord)           NaN           NaN
# 114                      Robert I Baratheon           NaN           NaN
# 123                                   Gilly           NaN           NaN
# 138                       Rohanne of Tyrosh           NaN           NaN
# 143                      Baelor I Targaryen           NaN           NaN
# 144                     Aegon III Targaryen           NaN           NaN
# 153                            Mance Rayder           NaN           NaN
# 156                                   Kayce           NaN           NaN
#
#     name_spouse allegiance_spouse father_spouse successor_spouse url_spouse  \
# 0           NaN               NaN           NaN              NaN        NaN
# 1           NaN               NaN           NaN              NaN        NaN
# 8           NaN               NaN           NaN              NaN        NaN
# 15          NaN               NaN           NaN              NaN        NaN
# 26          NaN               NaN           NaN              NaN        NaN
# 35          NaN               NaN           NaN              NaN        NaN
# 44          NaN               NaN           NaN              NaN        NaN
# 45          NaN               NaN           NaN              NaN        NaN
# 55          NaN               NaN           NaN              NaN        NaN
# 73          NaN               NaN           NaN              NaN        NaN
# 89          NaN               NaN           NaN              NaN        NaN
# 103         NaN               NaN           NaN              NaN        NaN
# 113         NaN               NaN           NaN              NaN        NaN
# 114         NaN               NaN           NaN              NaN        NaN
# 123         NaN               NaN           NaN              NaN        NaN
# 138         NaN               NaN           NaN              NaN        NaN
# 143         NaN               NaN           NaN              NaN        NaN
# 144         NaN               NaN           NaN              NaN        NaN
# 153         NaN               NaN           NaN              NaN        NaN
# 156         NaN               NaN           NaN              NaN        NaN
#
#     fatherRumored_spouse mother_spouse spouse_spouse motherRumored_spouse
# 0                    NaN           NaN           NaN                  NaN
# 1                    NaN           NaN           NaN                  NaN
# 8                    NaN           NaN           NaN                  NaN
# 15                   NaN           NaN           NaN                  NaN
# 26                   NaN           NaN           NaN                  NaN
# 35                   NaN           NaN           NaN                  NaN
# 44                   NaN           NaN           NaN                  NaN
# 45                   NaN           NaN           NaN                  NaN
# 55                   NaN           NaN           NaN                  NaN
# 73                   NaN           NaN           NaN                  NaN
# 89                   NaN           NaN           NaN                  NaN
# 103                  NaN           NaN           NaN                  NaN
# 113                  NaN           NaN           NaN                  NaN
# 114                  NaN           NaN           NaN                  NaN
# 123                  NaN           NaN           NaN                  NaN
# 138                  NaN           NaN           NaN                  NaN
# 143                  NaN           NaN           NaN                  NaN
# 144                  NaN           NaN           NaN                  NaN
# 153                  NaN           NaN           NaN                  NaN
# 156                  NaN           NaN           NaN                  NaN

# %%
# all_relations_with_spouse.reset_index(inplace=True)
# all_no_spouse.reset_index(inplace=True)
final_data = pd.concat([all_relations_with_spouse, all_no_spouse])
final_data.info()

# Save final dataset
# all_usable_data.to_json('./ice_and_fire_final.json', orient='records')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 171
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   level_0               527 non-null    float64
#  1   index                 699 non-null    int64
#  2   name                  699 non-null    object
#  3   allegiance            591 non-null    object
#  4   father                308 non-null    object
#  5   successor             219 non-null    object
#  6   url                   699 non-null    object
#  7   fatherRumored         2 non-null      object
#  8   mother                176 non-null    object
#  9   spouse                527 non-null    object
#  10  motherRumored         0 non-null      object
#  11  index_spouse          417 non-null    float64
#  12  name_spouse           417 non-null    object
#  13  allegiance_spouse     397 non-null    object
#  14  father_spouse         241 non-null    object
#  15  successor_spouse      70 non-null     object
#  16  url_spouse            417 non-null    object
#  17  fatherRumored_spouse  1 non-null      object
#  18  mother_spouse         122 non-null    object
#  19  spouse_spouse         417 non-null    object
#  20  motherRumored_spouse  0 non-null      object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 120.1+ KB
