# %%
# Restrictions: ONLY named individuals

import pandas as pd

json_file_path = './ice-and-fire.json'
df = pd.read_json(json_file_path)

# Really only focus on family relations
df.drop('predecessor', axis=1, inplace=True)
df.drop('successor', axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1345 entries, 0 to 1344
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1345 non-null   object
#  1   allegiance     1186 non-null   object
#  2   father         942 non-null    object
#  3   url            1345 non-null   object
#  4   fatherRumored  11 non-null     object
#  5   mother         490 non-null    object
#  6   spouse         523 non-null    object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 84.2+ KB

# %%
# Remove datapoints that have no relation at all.
# Old code and technically not necessarily anymore, already done in node.js
data_without_relation = df[(df['father'].isnull()) \
                           & (df['mother'].isnull()) \
                           & (df['spouse'].isnull())]

data_with_relation = df[~df['name'].isin(data_without_relation['name'])]
data_with_relation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1247 entries, 0 to 1344
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1247 non-null   object
#  1   allegiance     1139 non-null   object
#  2   father         942 non-null    object
#  3   url            1247 non-null   object
#  4   fatherRumored  11 non-null     object
#  5   mother         490 non-null    object
#  6   spouse         523 non-null    object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 87.7+ KB

# %%
duplicate_names = df[df['name'].duplicated()]
duplicate_names['name'].value_counts()
# Out:
# Series([], Name: name, dtype: int64)

# %%
# Weed out double fathers.
# Some are actually double, because they are rumoured
multiple_fathers = df[df['father'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_fathers['father']
# Out:
# Series([], Name: father, dtype: object)

# %%
# Weed out double moms.
# Some are actually double, because they are rumoured
multiple_mothers = df[df['mother'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_mothers['mother']
# Out:
# Series([], Name: mother, dtype: object)

# %%
# Weed out erratic spouses.
multiple_spouses = df[df['spouse'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_spouses[['name', 'spouse']]
# Out:
#                                         name  \
# 82                             Alys Karstark
# 103                          Alyssa Velaryon
# 108                              Amerei Frey
# 290                                  Craster
# 293                             Cregan Stark
# 310                         Daemon Targaryen
# 328                           Dalton Greyjoy
# 342                              Davos Dayne
# 369                         Donella Hornwood
# 401                        Elaena Targaryen
# 407                         Elenda Baratheon
# 413                         Elinor Costayne
# 421                              Ellyn Reyne
# 497                         Gerold Lannister
# 518                      Gunthor Goodbrother
# 596                              Huzhor Amai
# 621          Jason Lannister (son of Gerold)
# 652      Jeyne Westerling (wife of Maegor I)
# 669                                Jon Arryn
# 689                             Jonnel Stark
# 694                            Jorah Mormont
# 710                          Kiera of Tyrosh
# 795                               Lysa Arryn
# 796                              Lysa Farman
# 824                          Margaery Tyrell
# 924                        Nymeria of Ny Sar
# 986                          Quellon Greyjoy
# 994                              Ramsay Snow
# 1019  Rhaena Targaryen (daughter of Aenys I)
# 1020   Rhaena Targaryen (daughter of Daemon)
# 1022                      Rhaenyra Targaryen
# 1077                        Rohanne Webber
# 1093                            Roose Bolton
# 1120                          Samantha Tarly
# 1138                            Serena Stark
# 1172                            Stevron Frey
# 1193                                    Tess
# 1239                        Tyrion Lannister
# 1274                           Veron Greyjoy
# 1301                             Walder Frey
# 1323                            Willam Stark
#
#                                                  spouse
# 82                                     [Sigorn, Thenns]
# 103                [Aenys I Targaryen, Rogar Baratheon]
# 108           [Pate of the Blue Fork, Lancel Lannister]
# 290                         [Dyah, Ferny, Nella, Gilly]
# 293     [Arra Norrey, Alysanne Blackwood, Lynara Stark]
# 310    [Rhea Royce, Laena Velaryon, Rhaenyra Targaryen]
# 328                          [Tess, Kayce, Lysa Farman]
# 342                                   [Nymeria, Ny Sar]
# 369                       [Halys Hornwood, Ramsay Snow]
# 401   [Ossifer Plumm, Ronnel Penrose, Michael Manwoody]
# 407              [Borros Baratheon, Steffon Connington]
# 413                  [Theo Bolling, Maegor I Targaryen]
# 421                  [Tion Lannister, Walderan Tarbeck]
# 497                   [Alysanne Farman, Rohanne Webber]
# 518                            [Lysa Farman, Salt wife]
# 596                            [Cymmeri, Gipps, Zoqora]
# 621                    [Alys Stackspear, Marla Prester]
# 652                  [Alyn Tarbeck, Maegor I Targaryen]
# 669             [Jeyne Royce, Rowena Arryn, Lysa Arryn]
# 689   [Sansa Stark (daughter of Rickon), Robyn Ryswell]
# 694                   [House Glover, Lynesse Hightower]
# 710   [Valarr Targaryen, Daeron Targaryen (son of Ma...
# 795                          [Jon Arryn, Petyr Baelish]
# 796    [Dalton Greyjoy, Salt wife, Gunthor Goodbrother]
# 824   [Renly Baratheon, Joffrey Baratheon, Tommen Ba...
# 924   [Mors Martell, House Uller, Hellholt, Davos Da...
# 986   [Lady Stonetree (wife of Quellon Greyjoy), Lad...
# 994                     [Donella Hornwood, Jeyne Poole]
# 1019  [Aegon Targaryen (son of Aenys I), Maegor I Ta...
# 1020                [Corwyn Corbray, Garmund Hightower]
# 1022                [Laenor Velaryon, Daemon Targaryen]
# 1077  [Simon Staunton, Rolland Uffering, Eustace Osg...
# 1093  [Bethany Bolton, Walda Frey (daughter of Merre...
# 1120               [Ormund Hightower, Lyonel Hightower]
# 1138  [Jon Umber (husband of Serena), Edric Stark (s...
# 1172   [Corenna Swann, Jeyne Lydden, Marsella Waynwood]
# 1193                        [Dalton Greyjoy, Salt wife]
# 1239                               [Tysha, Sansa Stark]
# 1274                          [House Farman, Salt wife]
# 1301  [Perra Royce, Cyrenna Swann, Amarei Crakehall,...
# 1323                [Lyanne Glover, Melantha Blackwood]

# %%
# Datapoints with children
data_with_children = data_without_relation[
    (data_without_relation['name'].isin(data_with_relation['mother']))
    | (data_without_relation['name'].isin(data_with_relation['father']))]

data_with_children.head()
# Out:
#                                  name          allegiance father  \
# 73                    Alyn Stokeworth  [House Stokeworth]    NaN
# 131                   Arrec Durrandon                 NaN    NaN
# 180                Benedict I Justman                 NaN    NaN
# 220        Brandon Stark (Shipwright)                 NaN    NaN
# 223  Brandon Stark (father of Walton)       [House Stark]    NaN
#
#                                                    url fatherRumored mother  \
# 73   http://awoiaf.westeros.org/index.php/Alyn_Stok...           NaN    NaN
# 131  http://awoiaf.westeros.org/index.php/Arrec_Dur...           NaN    NaN
# 180  http://awoiaf.westeros.org/index.php/Benedict_...           NaN    NaN
# 220  http://awoiaf.westeros.org/index.php/Brandon_S...           NaN    NaN
# 223  http://awoiaf.westeros.org/index.php/Brandon_S...           NaN    NaN
#
#     spouse motherRumored
# 73     NaN           NaN
# 131    NaN           NaN
# 180    NaN           NaN
# 220    NaN           NaN
# 223    NaN           NaN

# %%
# data_with_relation[data_with_relation['name'] == 'Aelor Targaryen']
data_with_relation['father']
# Out:
# 0       Manfred Hightower (Aegon's Conquest)
# 1                             Damon Marbrand
# 2                             Eustace Osgrey
# 3                            Laenor Velaryon
# 4                            House Whitehead
#                         ...
# 1340                                     NaN
# 1341                              Yohn Royce
# 1342                              Tytos Frey
# 1343                                     NaN
# 1344                              Tytos Frey
# Name: father, Length: 1247, dtype: object

# %%
# Datapoints for whom spouse is the only relationship

data_with_spouses = data_with_relation[(~data_with_relation['spouse'].isnull()) 
                                      & (df['father'].isnull()) 
                                       & (df['mother'].isnull())]

data_with_spouses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268 entries, 22 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           268 non-null    object
#  1   allegiance     252 non-null    object
#  2   father         0 non-null      object
#  3   url            268 non-null    object
#  4   fatherRumored  0 non-null      object
#  5   mother         0 non-null      object
#  6   spouse         268 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 18.8+ KB
# /var/folders/dy/hw0ckby90bxf_gm4t4jmb1yh0000gn/T/ipykernel_64569/3414280336.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_with_spouses = data_with_relation[(~data_with_relation['spouse'].isnull())

# %%
data_with_spouses.head()
# Out:
#                name                                         allegiance father  \
# 22  Aelinor Penrose                   [House Penrose, House Targaryen]    NaN
# 47    Alarra Massey                     [House Massey, House Velaryon]    NaN
# 50           Alayne                                    [House Baelish]    NaN
# 58  Alester Florent  [House Florent, House Tyrell, House Baratheon ...    NaN
# 74     Alyn Tarbeck                                    [House Tarbeck]    NaN
#
#                                                   url fatherRumored mother  \
# 22  http://awoiaf.westeros.org/index.php/Aelinor_P...           NaN    NaN
# 47  http://awoiaf.westeros.org/index.php/Alarra_Ma...           NaN    NaN
# 50  http://awoiaf.westeros.org/index.php/Alayne_Ba...           NaN    NaN
# 58  http://awoiaf.westeros.org/index.php/Alester_F...           NaN    NaN
# 74  http://awoiaf.westeros.org/index.php/Alyn_Tarbeck           NaN    NaN
#
#                                    spouse motherRumored
# 22                    [Aerys I Targaryen]           NaN
# 47                      [Aethan Velaryon]           NaN
# 50                       [Baelish (lord)]           NaN
# 58                         [Melara Crane]           NaN
# 74  [Jeyne Westerling (wife of Maegor I)]           NaN

# %%
# Get spouses that have a spouse present in the dataset with all 
# parent-child relationships

parent_child_spouses = df.explode('spouse').dropna(subset=['spouse'])['spouse'].unique()
data_spouse_family = data_with_spouses[data_with_spouses['name'].isin(parent_child_spouses)]
data_spouse_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 47 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           202 non-null    object
#  1   allegiance     192 non-null    object
#  2   father         0 non-null      object
#  3   url            202 non-null    object
#  4   fatherRumored  0 non-null      object
#  5   mother         0 non-null      object
#  6   spouse         202 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 14.2+ KB

# %%
data_spouse_family.head()
# Out:
#                             name  \
# 47                 Alarra Massey
# 58               Alester Florent
# 74                  Alyn Tarbeck
# 78  Alys Arryn (wife of Rhaegel)
# 79                 Alys Beesbury
#
#                                            allegiance father  \
# 47                     [House Massey, House Velaryon]    NaN
# 58  [House Florent, House Tyrell, House Baratheon ...    NaN
# 74                                    [House Tarbeck]    NaN
# 78                     [House Arryn, House Targaryen]    NaN
# 79                     [House Beesbury, House Tyrell]    NaN
#
#                                                   url fatherRumored mother  \
# 47  http://awoiaf.westeros.org/index.php/Alarra_Ma...           NaN    NaN
# 58  http://awoiaf.westeros.org/index.php/Alester_F...           NaN    NaN
# 74  http://awoiaf.westeros.org/index.php/Alyn_Tarbeck           NaN    NaN
# 78  http://awoiaf.westeros.org/index.php/Alys_Arry...           NaN    NaN
# 79  http://awoiaf.westeros.org/index.php/Alys_Bees...           NaN    NaN
#
#                                    spouse motherRumored
# 47                      [Aethan Velaryon]           NaN
# 58                         [Melara Crane]           NaN
# 74  [Jeyne Westerling (wife of Maegor I)]           NaN
# 78                    [Rhaegel Targaryen]           NaN
# 79           [Leo Tyrell (son of Victor)]           NaN

# %%
all_usable_data = pd.concat([data_with_children, data_spouse_family, data_with_relation])
len(all_usable_data)
# Out:
# 1485

# %%
all_usable_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1485 entries, 73 to 1344
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1485 non-null   object
#  1   allegiance     1346 non-null   object
#  2   father         942 non-null    object
#  3   url            1485 non-null   object
#  4   fatherRumored  11 non-null     object
#  5   mother         490 non-null    object
#  6   spouse         725 non-null    object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 104.4+ KB

# %%
first_layer = all_usable_data[(all_usable_data['father'].isnull()) & (all_usable_data['mother'].isnull())]
first_layer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 73 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           506 non-null    object
#  1   allegiance     459 non-null    object
#  2   father         0 non-null      object
#  3   url            506 non-null    object
#  4   fatherRumored  0 non-null      object
#  5   mother         0 non-null      object
#  6   spouse         470 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 35.6+ KB

# %%
all_usable_data.explode('allegiance').dropna(subset=['allegiance']).value_counts('allegiance').head(50)
# Out:
# allegiance
# House Frey                        163
# House Targaryen                   142
# House Stark                       110
# House Lannister                    82
# Blacks                             53
# House Tyrell                       52
# House Hightower                    45
# House Martell                      36
# House Baratheon                    36
# House Greyjoy                      32
# House Arryn                        28
# House Velaryon                     28
# Greens                             23
# House Tully                        18
# House Blackwood                    18
# House Bracken                      17
# House Manderly                     17
# House Royce                        17
# Night's Watch                      16
# House Florent                      16
# House Redwyne                      16
# House Blackfyre                    14
# House Waynwood                     14
# House Tarbeck                      14
# Citadel                            13
# House Baratheon of Dragonstone     13
# House Rowan                        12
# House Osgrey                       12
# House Bolton                       12
# House Karstark                     12
# Kingsguard                         12
# Faith of the Seven                 12
# House Tarly                        12
# House Westerling                   11
# House Seaworth                     11
# House Stokeworth                   11
# House Mormont                      11
# House Glover                       11
# House Darklyn                      10
# Brotherhood without banners        10
# House Umber                        10
# House Crakehall                     9
# House Farman                        9
# Mance Rayder                        9
# House Penrose                       9
# House Brax                          9
# House Botley                        9
# House Sarwyck                       9
# House Whent                         9
# House Beesbury                      9
# dtype: int64

# %%
# first_layer[first_layer['successor'].notna()]['successor'].head(100)

# %%
# Transform nodes into partnerships (= single or couple), 
# so that they will be easier to use in a hierarchical structure

all_with_spouse = all_usable_data[all_usable_data['spouse'].notnull()]
all_with_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 725 entries, 47 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           725 non-null    object
#  1   allegiance     695 non-null    object
#  2   father         251 non-null    object
#  3   url            725 non-null    object
#  4   fatherRumored  2 non-null      object
#  5   mother         149 non-null    object
#  6   spouse         725 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 51.0+ KB

# %%
all_no_spouse = all_usable_data[all_usable_data['spouse'].isna()]
all_no_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 73 to 1344
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           760 non-null    object
#  1   allegiance     651 non-null    object
#  2   father         691 non-null    object
#  3   url            760 non-null    object
#  4   fatherRumored  9 non-null      object
#  5   mother         341 non-null    object
#  6   spouse         0 non-null      object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 53.4+ KB

# %%
all_relations = all_with_spouse.explode('spouse').dropna(subset=['spouse'])
all_relations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 761 entries, 47 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           761 non-null    object
#  1   allegiance     731 non-null    object
#  2   father         291 non-null    object
#  3   url            761 non-null    object
#  4   fatherRumored  2 non-null      object
#  5   mother         171 non-null    object
#  6   spouse         761 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 53.5+ KB

# %%
# all_relations.reset_index(inplace=True)
all_relations_with_spouse = pd.merge(all_relations, all_relations, how='left', left_on='spouse', right_on='name', suffixes=('', '_spouse'))
all_relations_with_spouse = all_relations_with_spouse.reset_index()
all_relations_with_spouse = pd.merge(all_relations_with_spouse, all_no_spouse, how='left', left_on='spouse', right_on='name', suffixes=('', '_no-spouse'))

all_relations_with_spouse.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1336 entries, 0 to 1335
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    1336 non-null   int64
#  1   name                     1336 non-null   object
#  2   allegiance               1241 non-null   object
#  3   father                   478 non-null    object
#  4   url                      1336 non-null   object
#  5   fatherRumored            2 non-null      object
#  6   mother                   273 non-null    object
#  7   spouse                   1336 non-null   object
#  8   motherRumored            0 non-null      object
#  9   name_spouse              1212 non-null   object
#  10  allegiance_spouse        1122 non-null   object
#  11  father_spouse            563 non-null    object
#  12  url_spouse               1212 non-null   object
#  13  fatherRumored_spouse     2 non-null      object
#  14  mother_spouse            282 non-null    object
#  15  spouse_spouse            1212 non-null   object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: int64(1), object(24)
# memory usage: 271.4+ KB

# %%
all_relations_with_spouse = all_relations_with_spouse.drop_duplicates(subset=['name', 'father', 'mother', 'spouse', 'name_spouse', 'father_spouse', 'mother_spouse'], ignore_index=True)
all_relations_with_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    549 non-null    int64
#  1   name                     549 non-null    object
#  2   allegiance               532 non-null    object
#  3   father                   291 non-null    object
#  4   url                      549 non-null    object
#  5   fatherRumored            2 non-null      object
#  6   mother                   171 non-null    object
#  7   spouse                   549 non-null    object
#  8   motherRumored            0 non-null      object
#  9   name_spouse              443 non-null    object
#  10  allegiance_spouse        429 non-null    object
#  11  father_spouse            226 non-null    object
#  12  url_spouse               443 non-null    object
#  13  fatherRumored_spouse     2 non-null      object
#  14  mother_spouse            141 non-null    object
#  15  spouse_spouse            443 non-null    object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: int64(1), object(24)
# memory usage: 107.4+ KB

# %%
all_relations_with_spouse[all_relations_with_spouse['name_spouse'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106 entries, 16 to 542
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    106 non-null    int64
#  1   name                     106 non-null    object
#  2   allegiance               103 non-null    object
#  3   father                   57 non-null     object
#  4   url                      106 non-null    object
#  5   fatherRumored            0 non-null      object
#  6   mother                   29 non-null     object
#  7   spouse                   106 non-null    object
#  8   motherRumored            0 non-null      object
#  9   name_spouse              0 non-null      object
#  10  allegiance_spouse        0 non-null      object
#  11  father_spouse            0 non-null      object
#  12  url_spouse               0 non-null      object
#  13  fatherRumored_spouse     0 non-null      object
#  14  mother_spouse            0 non-null      object
#  15  spouse_spouse            0 non-null      object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: int64(1), object(24)
# memory usage: 21.5+ KB

# %%
all_relations_with_spouse[all_relations_with_spouse['name_no-spouse'].notna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 215 to 530
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    24 non-null     int64
#  1   name                     24 non-null     object
#  2   allegiance               22 non-null     object
#  3   father                   21 non-null     object
#  4   url                      24 non-null     object
#  5   fatherRumored            0 non-null      object
#  6   mother                   12 non-null     object
#  7   spouse                   24 non-null     object
#  8   motherRumored            0 non-null      object
#  9   name_spouse              0 non-null      object
#  10  allegiance_spouse        0 non-null      object
#  11  father_spouse            0 non-null      object
#  12  url_spouse               0 non-null      object
#  13  fatherRumored_spouse     0 non-null      object
#  14  mother_spouse            0 non-null      object
#  15  spouse_spouse            0 non-null      object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: int64(1), object(24)
# memory usage: 4.9+ KB

# %%
all_relations_with_spouse[all_relations_with_spouse['name_spouse'].isna()].sort_values('name').head(20)
# Out:
#      index                 name  \
# 215    404      Aelinor Penrose
# 218    407          Aemma Arryn
# 223    413  Aerion Targaryen[1]
# 225    416       Alannys Harlaw
# 227    420               Alayne
# 229    424     Aliandra Martell
# 230    425    Alicent Hightower
# 233    436        Alys Harroway
# 235    438        Alys Karstark
# 241    454   Alysanne Targaryen
# 242    463     Alyssa Targaryen
# 243    464      Alyssa Velaryon
# 246    477          Amerei Frey
# 245    476          Amerei Frey
# 253    503        Arwen Upcliff
# 16      45           Arya Flint
# 266    535      Betha Blackwood
# 268    551     Borros Baratheon
# 34      80         Cerissa Brax
# 275    576     Cersei Lannister
#
#                                             allegiance                 father  \
# 215                   [House Penrose, House Targaryen]                    NaN
# 218                     [House Arryn, House Targaryen]           Rodrik Arryn
# 223                                  [House Targaryen]      Daemion Targaryen
# 225                      [House Greyjoy, House Harlaw]           House Harlaw
# 227                                    [House Baelish]                    NaN
# 229                                    [House Martell]          Qoren Martell
# 230         [House Hightower, House Targaryen, Greens]         Otto Hightower
# 233                  [House Harroway, House Targaryen]         Lucas Harroway
# 235                      [House Karstark, House Thenn]       Rickard Karstark
# 241                                  [House Targaryen]      Aenys I Targaryen
# 242                                  [House Targaryen]  Jaehaerys I Targaryen
# 243  [House Velaryon, House Targaryen, House Barath...        Aethan Velaryon
# 246             [House Frey, House Lannister of Darry]           Merrett Frey
# 245             [House Frey, House Lannister of Darry]           Merrett Frey
# 253                       [House Upcliff, House Arryn]                    NaN
# 16         [House Flint of the mountains, House Stark]                    NaN
# 266                 [House Blackwood, House Targaryen]        House Blackwood
# 268                          [House Baratheon, Greens]     Boremund Baratheon
# 34                       [House Brax, House Lannister]                    NaN
# 275  [House Lannister, House Baratheon of King's La...        Tywin Lannister
#
#                                                    url fatherRumored  \
# 215  http://awoiaf.westeros.org/index.php/Aelinor_P...           NaN
# 218   http://awoiaf.westeros.org/index.php/Aemma_Arryn           NaN
# 223  http://awoiaf.westeros.org/index.php/Aerion_Ta...           NaN
# 225  http://awoiaf.westeros.org/index.php/Alannys_H...           NaN
# 227  http://awoiaf.westeros.org/index.php/Alayne_Ba...           NaN
# 229  http://awoiaf.westeros.org/index.php/Aliandra_...           NaN
# 230  http://awoiaf.westeros.org/index.php/Alicent_H...           NaN
# 233  http://awoiaf.westeros.org/index.php/Alys_Harr...           NaN
# 235  http://awoiaf.westeros.org/index.php/Alys_Kars...           NaN
# 241  http://awoiaf.westeros.org/index.php/Alysanne_...           NaN
# 242  http://awoiaf.westeros.org/index.php/Alyssa_Ta...           NaN
# 243  http://awoiaf.westeros.org/index.php/Alyssa_Ve...           NaN
# 246   http://awoiaf.westeros.org/index.php/Amerei_Frey           NaN
# 245   http://awoiaf.westeros.org/index.php/Amerei_Frey           NaN
# 253  http://awoiaf.westeros.org/index.php/Arwen_Upc...           NaN
# 16     http://awoiaf.westeros.org/index.php/Arya_Flint           NaN
# 266  http://awoiaf.westeros.org/index.php/Betha_Bla...           NaN
# 268  http://awoiaf.westeros.org/index.php/Borros_Ba...           NaN
# 34   http://awoiaf.westeros.org/index.php/Cerissa_Brax           NaN
# 275  http://awoiaf.westeros.org/index.php/Cersei_La...           NaN
#
#                                          mother  \
# 215                                         NaN
# 218  Daella Targaryen (daughter of Jaehaerys I)
# 223                                         NaN
# 225                                         NaN
# 227                                         NaN
# 229                                         NaN
# 230                                         NaN
# 233                                         NaN
# 235                                         NaN
# 241                             Alyssa Velaryon
# 242                          Alysanne Targaryen
# 243                               Alarra Massey
# 246                                Mariya Darry
# 245                                Mariya Darry
# 253                                         NaN
# 16                                          NaN
# 266                                         NaN
# 268                                         NaN
# 34                                          NaN
# 275                            Joanna Lannister
#
#                                     spouse motherRumored name_spouse  ...  \
# 215                      Aerys I Targaryen           NaN         NaN  ...
# 218                    Viserys I Targaryen           NaN         NaN  ...
# 223                       Valaena Velaryon           NaN         NaN  ...
# 225                          Balon Greyjoy           NaN         NaN  ...
# 227                         Baelish (lord)           NaN         NaN  ...
# 229                        Drazenko Rogare           NaN         NaN  ...
# 230                    Viserys I Targaryen           NaN         NaN  ...
# 233                     Maegor I Targaryen           NaN         NaN  ...
# 235                                 Thenns           NaN         NaN  ...
# 241                  Jaehaerys I Targaryen           NaN         NaN  ...
# 242  Baelon Targaryen (son of Jaehaerys I)           NaN         NaN  ...
# 243                      Aenys I Targaryen           NaN         NaN  ...
# 246                       Lancel Lannister           NaN         NaN  ...
# 245                  Pate of the Blue Fork           NaN         NaN  ...
# 253                       Alester II Arryn           NaN         NaN  ...
# 16             Rodrik Stark (son of Beron)           NaN         NaN  ...
# 266                      Aegon V Targaryen           NaN         NaN  ...
# 268                           Elenda Caron           NaN         NaN  ...
# 34                  Damon Lannister (lord)           NaN         NaN  ...
# 275                     Robert I Baratheon           NaN         NaN  ...
#
#     spouse_spouse motherRumored_spouse       name_no-spouse  \
# 215           NaN                  NaN    Aerys I Targaryen
# 218           NaN                  NaN  Viserys I Targaryen
# 223           NaN                  NaN                  NaN
# 225           NaN                  NaN        Balon Greyjoy
# 227           NaN                  NaN                  NaN
# 229           NaN                  NaN                  NaN
# 230           NaN                  NaN  Viserys I Targaryen
# 233           NaN                  NaN                  NaN
# 235           NaN                  NaN                  NaN
# 241           NaN                  NaN                  NaN
# 242           NaN                  NaN                  NaN
# 243           NaN                  NaN    Aenys I Targaryen
# 246           NaN                  NaN                  NaN
# 245           NaN                  NaN                  NaN
# 253           NaN                  NaN                  NaN
# 16            NaN                  NaN                  NaN
# 266           NaN                  NaN    Aegon V Targaryen
# 268           NaN                  NaN                  NaN
# 34            NaN                  NaN                  NaN
# 275           NaN                  NaN                  NaN
#
#     allegiance_no-spouse                       father_no-spouse  \
# 215                  NaN                    Daeron II Targaryen
# 218                  NaN  Baelon Targaryen (son of Jaehaerys I)
# 223                  NaN                                    NaN
# 225                  NaN                        Quellon Greyjoy
# 227                  NaN                                    NaN
# 229                  NaN                                    NaN
# 230                  NaN  Baelon Targaryen (son of Jaehaerys I)
# 233                  NaN                                    NaN
# 235                  NaN                                    NaN
# 241                  NaN                                    NaN
# 242                  NaN                                    NaN
# 243                  NaN                      Aegon I Targaryen
# 246                  NaN                                    NaN
# 245                  NaN                                    NaN
# 253                  NaN                                    NaN
# 16                   NaN                                    NaN
# 266                  NaN                     Maekar I Targaryen
# 268                  NaN                                    NaN
# 34                   NaN                                    NaN
# 275                  NaN                                    NaN
#
#                                          url_no-spouse  \
# 215  http://awoiaf.westeros.org/index.php/Aerys_I_T...
# 218  http://awoiaf.westeros.org/index.php/Viserys_I...
# 223                                                NaN
# 225  http://awoiaf.westeros.org/index.php/Balon_Gre...
# 227                                                NaN
# 229                                                NaN
# 230  http://awoiaf.westeros.org/index.php/Viserys_I...
# 233                                                NaN
# 235                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243  http://awoiaf.westeros.org/index.php/Aenys_I_T...
# 246                                                NaN
# 245                                                NaN
# 253                                                NaN
# 16                                                 NaN
# 266  http://awoiaf.westeros.org/index.php/Aegon_V_T...
# 268                                                NaN
# 34                                                 NaN
# 275                                                NaN
#
#     fatherRumored_no-spouse                         mother_no-spouse  \
# 215                     NaN                           Myriah Martell
# 218                     NaN                         Alyssa Targaryen
# 223                     NaN                                      NaN
# 225                     NaN  Lady Sunderly (wife of Quellon Greyjoy)
# 227                     NaN                                      NaN
# 229                     NaN                                      NaN
# 230                     NaN                         Alyssa Targaryen
# 233                     NaN                                      NaN
# 235                     NaN                                      NaN
# 241                     NaN                                      NaN
# 242                     NaN                                      NaN
# 243                     NaN                        Rhaenys Targaryen
# 246                     NaN                                      NaN
# 245                     NaN                                      NaN
# 253                     NaN                                      NaN
# 16                      NaN                                      NaN
# 266                     NaN                             Dyanna Dayne
# 268                     NaN                                      NaN
# 34                      NaN                                      NaN
# 275                     NaN                                      NaN
#
#     spouse_no-spouse motherRumored_no-spouse
# 215              NaN                     NaN
# 218              NaN                     NaN
# 223              NaN                     NaN
# 225              NaN                     NaN
# 227              NaN                     NaN
# 229              NaN                     NaN
# 230              NaN                     NaN
# 233              NaN                     NaN
# 235              NaN                     NaN
# 241              NaN                     NaN
# 242              NaN                     NaN
# 243              NaN                     NaN
# 246              NaN                     NaN
# 245              NaN                     NaN
# 253              NaN                     NaN
# 16               NaN                     NaN
# 266              NaN                     NaN
# 268              NaN                     NaN
# 34               NaN                     NaN
# 275              NaN                     NaN
#
# [20 rows x 25 columns]

# %%
# all_relations_with_spouse.reset_index(inplace=True)
# all_no_spouse.reset_index(inplace=True)
final_data = pd.concat([all_relations_with_spouse, all_no_spouse])
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1344
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    549 non-null    float64
#  1   name                     1309 non-null   object
#  2   allegiance               1183 non-null   object
#  3   father                   982 non-null    object
#  4   url                      1309 non-null   object
#  5   fatherRumored            11 non-null     object
#  6   mother                   512 non-null    object
#  7   spouse                   549 non-null    object
#  8   motherRumored            2 non-null      object
#  9   name_spouse              443 non-null    object
#  10  allegiance_spouse        429 non-null    object
#  11  father_spouse            226 non-null    object
#  12  url_spouse               443 non-null    object
#  13  fatherRumored_spouse     2 non-null      object
#  14  mother_spouse            141 non-null    object
#  15  spouse_spouse            443 non-null    object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: float64(1), object(24)
# memory usage: 265.9+ KB

# %%
# successors = all_usable_data[all_usable_data['successor'].notna()]['successor']
# successors.head(50)

# %%
# Save final dataset
all_usable_data.to_json('./ice_and_fire_final.json', orient='records')
