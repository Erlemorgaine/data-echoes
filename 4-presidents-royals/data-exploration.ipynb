# %%
# Restrictions: ONLY named individuals

import pandas as pd

json_file_path = './ice-and-fire.json'
df = pd.read_json(json_file_path)

# Really only focus on family relations
df.drop('predecessor', axis=1, inplace=True)
df.drop('successor', axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1344 non-null   object
#  1   allegiance     1185 non-null   object
#  2   father         941 non-null    object
#  3   url            1344 non-null   object
#  4   fatherRumored  11 non-null     object
#  5   mother         490 non-null    object
#  6   spouse         523 non-null    object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 84.1+ KB

# %%
# Remove datapoints that have no relation at all.
# Old code and technically not necessarily anymore, already done in node.js
data_without_relation = df[(df['father'].isnull()) \
                           & (df['mother'].isnull()) \
                           & (df['spouse'].isnull())]

data_with_relation = df[~df['name'].isin(data_without_relation['name'])]
data_with_relation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1246 entries, 0 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1246 non-null   object
#  1   allegiance     1138 non-null   object
#  2   father         941 non-null    object
#  3   url            1246 non-null   object
#  4   fatherRumored  11 non-null     object
#  5   mother         490 non-null    object
#  6   spouse         523 non-null    object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 87.6+ KB

# %%
duplicate_names = df[df['name'].duplicated()]
duplicate_names['name'].value_counts()
# Out:
# Series([], Name: name, dtype: int64)

# %%
# Weed out double fathers.
# Some are actually double, because they are rumoured
multiple_fathers = df[df['father'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_fathers['father']
# Out:
# Series([], Name: father, dtype: object)

# %%
# Weed out double moms.
# Some are actually double, because they are rumoured
multiple_mothers = df[df['mother'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_mothers['mother']
# Out:
# Series([], Name: mother, dtype: object)

# %%
# Weed out erratic spouses.
multiple_spouses = df[df['spouse'].apply(lambda x: isinstance(x, list) and len(x) > 1)]
multiple_spouses[['name', 'spouse']]
# Out:
#                                         name  \
# 81                             Alys Karstark
# 102                          Alyssa Velaryon
# 107                              Amerei Frey
# 289                                  Craster
# 292                             Cregan Stark
# 309                         Daemon Targaryen
# 327                           Dalton Greyjoy
# 341                              Davos Dayne
# 368                         Donella Hornwood
# 400                        Elaena Targaryen
# 406                         Elenda Baratheon
# 412                         Elinor Costayne
# 420                              Ellyn Reyne
# 496                         Gerold Lannister
# 517                      Gunthor Goodbrother
# 595                              Huzhor Amai
# 620          Jason Lannister (son of Gerold)
# 651      Jeyne Westerling (wife of Maegor I)
# 668                                Jon Arryn
# 688                             Jonnel Stark
# 693                            Jorah Mormont
# 709                          Kiera of Tyrosh
# 794                               Lysa Arryn
# 795                              Lysa Farman
# 823                          Margaery Tyrell
# 923                        Nymeria of Ny Sar
# 985                          Quellon Greyjoy
# 993                              Ramsay Snow
# 1018  Rhaena Targaryen (daughter of Aenys I)
# 1019   Rhaena Targaryen (daughter of Daemon)
# 1021                      Rhaenyra Targaryen
# 1076                        Rohanne Webber
# 1092                            Roose Bolton
# 1119                          Samantha Tarly
# 1137                            Serena Stark
# 1171                            Stevron Frey
# 1192                                    Tess
# 1238                        Tyrion Lannister
# 1273                           Veron Greyjoy
# 1300                             Walder Frey
# 1322                            Willam Stark
#
#                                                  spouse
# 81                                     [Sigorn, Thenns]
# 102                [Aenys I Targaryen, Rogar Baratheon]
# 107           [Pate of the Blue Fork, Lancel Lannister]
# 289                         [Dyah, Ferny, Nella, Gilly]
# 292     [Arra Norrey, Alysanne Blackwood, Lynara Stark]
# 309    [Rhea Royce, Laena Velaryon, Rhaenyra Targaryen]
# 327                          [Tess, Kayce, Lysa Farman]
# 341                                   [Nymeria, Ny Sar]
# 368                       [Halys Hornwood, Ramsay Snow]
# 400   [Ossifer Plumm, Ronnel Penrose, Michael Manwoody]
# 406              [Borros Baratheon, Steffon Connington]
# 412                  [Theo Bolling, Maegor I Targaryen]
# 420                  [Tion Lannister, Walderan Tarbeck]
# 496                   [Alysanne Farman, Rohanne Webber]
# 517                            [Lysa Farman, Salt wife]
# 595                            [Cymmeri, Gipps, Zoqora]
# 620                    [Alys Stackspear, Marla Prester]
# 651                  [Alyn Tarbeck, Maegor I Targaryen]
# 668             [Jeyne Royce, Rowena Arryn, Lysa Arryn]
# 688   [Sansa Stark (daughter of Rickon), Robyn Ryswell]
# 693                   [House Glover, Lynesse Hightower]
# 709   [Valarr Targaryen, Daeron Targaryen (son of Ma...
# 794                          [Jon Arryn, Petyr Baelish]
# 795    [Dalton Greyjoy, Salt wife, Gunthor Goodbrother]
# 823   [Renly Baratheon, Joffrey Baratheon, Tommen Ba...
# 923   [Mors Martell, House Uller, Hellholt, Davos Da...
# 985   [Lady Stonetree (wife of Quellon Greyjoy), Lad...
# 993                     [Donella Hornwood, Jeyne Poole]
# 1018  [Aegon Targaryen (son of Aenys I), Maegor I Ta...
# 1019                [Corwyn Corbray, Garmund Hightower]
# 1021                [Laenor Velaryon, Daemon Targaryen]
# 1076  [Simon Staunton, Rolland Uffering, Eustace Osg...
# 1092  [Bethany Bolton, Walda Frey (daughter of Merre...
# 1119               [Ormund Hightower, Lyonel Hightower]
# 1137  [Jon Umber (husband of Serena), Edric Stark (s...
# 1171   [Corenna Swann, Jeyne Lydden, Marsella Waynwood]
# 1192                        [Dalton Greyjoy, Salt wife]
# 1238                               [Tysha, Sansa Stark]
# 1273                          [House Farman, Salt wife]
# 1300  [Perra Royce, Cyrenna Swann, Amarei Crakehall,...
# 1322                [Lyanne Glover, Melantha Blackwood]

# %%
# Datapoints with children
data_with_children = data_without_relation[
    (data_without_relation['name'].isin(data_with_relation['mother']))
    | (data_without_relation['name'].isin(data_with_relation['father']))]

data_with_children.head()
# Out:
#                                  name          allegiance father  \
# 72                    Alyn Stokeworth  [House Stokeworth]    NaN
# 130                   Arrec Durrandon                 NaN    NaN
# 179                Benedict I Justman                 NaN    NaN
# 219        Brandon Stark (Shipwright)                 NaN    NaN
# 222  Brandon Stark (father of Walton)       [House Stark]    NaN
#
#                                                    url fatherRumored mother  \
# 72   http://awoiaf.westeros.org/index.php/Alyn_Stok...           NaN    NaN
# 130  http://awoiaf.westeros.org/index.php/Arrec_Dur...           NaN    NaN
# 179  http://awoiaf.westeros.org/index.php/Benedict_...           NaN    NaN
# 219  http://awoiaf.westeros.org/index.php/Brandon_S...           NaN    NaN
# 222  http://awoiaf.westeros.org/index.php/Brandon_S...           NaN    NaN
#
#     spouse motherRumored
# 72     NaN           NaN
# 130    NaN           NaN
# 179    NaN           NaN
# 219    NaN           NaN
# 222    NaN           NaN

# %%
# data_with_relation[data_with_relation['name'] == 'Aelor Targaryen']
data_with_relation['father']
# Out:
# 0       Manfred Hightower (Aegon's Conquest)
# 1                             Damon Marbrand
# 2                             Eustace Osgrey
# 3                            Laenor Velaryon
# 6                         Daemon I Blackfyre
#                         ...
# 1339                                     NaN
# 1340                              Yohn Royce
# 1341                              Tytos Frey
# 1342                                     NaN
# 1343                              Tytos Frey
# Name: father, Length: 1246, dtype: object

# %%
# Datapoints for whom spouse is the only relationship

data_with_spouses = data_with_relation[(~data_with_relation['spouse'].isnull()) 
                                      & (df['father'].isnull()) 
                                       & (df['mother'].isnull())]

data_with_spouses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268 entries, 21 to 1342
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           268 non-null    object
#  1   allegiance     252 non-null    object
#  2   father         0 non-null      object
#  3   url            268 non-null    object
#  4   fatherRumored  0 non-null      object
#  5   mother         0 non-null      object
#  6   spouse         268 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 18.8+ KB
# /var/folders/dy/hw0ckby90bxf_gm4t4jmb1yh0000gn/T/ipykernel_73658/3414280336.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_with_spouses = data_with_relation[(~data_with_relation['spouse'].isnull())

# %%
data_with_spouses.head()
# Out:
#                name                                         allegiance father  \
# 21  Aelinor Penrose                   [House Penrose, House Targaryen]    NaN
# 46    Alarra Massey                     [House Massey, House Velaryon]    NaN
# 49           Alayne                                    [House Baelish]    NaN
# 57  Alester Florent  [House Florent, House Tyrell, House Baratheon ...    NaN
# 73     Alyn Tarbeck                                    [House Tarbeck]    NaN
#
#                                                   url fatherRumored mother  \
# 21  http://awoiaf.westeros.org/index.php/Aelinor_P...           NaN    NaN
# 46  http://awoiaf.westeros.org/index.php/Alarra_Ma...           NaN    NaN
# 49  http://awoiaf.westeros.org/index.php/Alayne_Ba...           NaN    NaN
# 57  http://awoiaf.westeros.org/index.php/Alester_F...           NaN    NaN
# 73  http://awoiaf.westeros.org/index.php/Alyn_Tarbeck           NaN    NaN
#
#                                    spouse motherRumored
# 21                    [Aerys I Targaryen]           NaN
# 46                      [Aethan Velaryon]           NaN
# 49                       [Baelish (lord)]           NaN
# 57                         [Melara Crane]           NaN
# 73  [Jeyne Westerling (wife of Maegor I)]           NaN

# %%
# Get spouses that have a spouse present in the dataset with all 
# parent-child relationships

parent_child_spouses = df.explode('spouse').dropna(subset=['spouse'])['spouse'].unique()
data_spouse_family = data_with_spouses[data_with_spouses['name'].isin(parent_child_spouses)]
data_spouse_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 46 to 1342
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           202 non-null    object
#  1   allegiance     192 non-null    object
#  2   father         0 non-null      object
#  3   url            202 non-null    object
#  4   fatherRumored  0 non-null      object
#  5   mother         0 non-null      object
#  6   spouse         202 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 14.2+ KB

# %%
data_spouse_family.head()
# Out:
#                             name  \
# 46                 Alarra Massey
# 57               Alester Florent
# 73                  Alyn Tarbeck
# 77  Alys Arryn (wife of Rhaegel)
# 78                 Alys Beesbury
#
#                                            allegiance father  \
# 46                     [House Massey, House Velaryon]    NaN
# 57  [House Florent, House Tyrell, House Baratheon ...    NaN
# 73                                    [House Tarbeck]    NaN
# 77                     [House Arryn, House Targaryen]    NaN
# 78                     [House Beesbury, House Tyrell]    NaN
#
#                                                   url fatherRumored mother  \
# 46  http://awoiaf.westeros.org/index.php/Alarra_Ma...           NaN    NaN
# 57  http://awoiaf.westeros.org/index.php/Alester_F...           NaN    NaN
# 73  http://awoiaf.westeros.org/index.php/Alyn_Tarbeck           NaN    NaN
# 77  http://awoiaf.westeros.org/index.php/Alys_Arry...           NaN    NaN
# 78  http://awoiaf.westeros.org/index.php/Alys_Bees...           NaN    NaN
#
#                                    spouse motherRumored
# 46                      [Aethan Velaryon]           NaN
# 57                         [Melara Crane]           NaN
# 73  [Jeyne Westerling (wife of Maegor I)]           NaN
# 77                    [Rhaegel Targaryen]           NaN
# 78           [Leo Tyrell (son of Victor)]           NaN

# %%
all_usable_data = pd.concat([data_with_children, data_spouse_family, data_with_relation])
len(all_usable_data)
# Out:
# 1484

# %%
all_usable_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1484 entries, 72 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1484 non-null   object
#  1   allegiance     1345 non-null   object
#  2   father         941 non-null    object
#  3   url            1484 non-null   object
#  4   fatherRumored  11 non-null     object
#  5   mother         490 non-null    object
#  6   spouse         725 non-null    object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 104.3+ KB

# %%
first_layer = all_usable_data[(all_usable_data['father'].isnull()) & (all_usable_data['mother'].isnull())]
first_layer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 72 to 1342
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           506 non-null    object
#  1   allegiance     459 non-null    object
#  2   father         0 non-null      object
#  3   url            506 non-null    object
#  4   fatherRumored  0 non-null      object
#  5   mother         0 non-null      object
#  6   spouse         470 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 35.6+ KB

# %%
all_usable_data.explode('allegiance').dropna(subset=['allegiance']).value_counts('allegiance').head(50)
# Out:
# allegiance
# House Frey                        163
# House Targaryen                   142
# House Stark                       110
# House Lannister                    82
# Blacks                             53
# House Tyrell                       52
# House Hightower                    45
# House Baratheon                    36
# House Martell                      36
# House Greyjoy                      32
# House Velaryon                     28
# House Arryn                        28
# Greens                             23
# House Blackwood                    18
# House Tully                        18
# House Manderly                     17
# House Royce                        17
# House Bracken                      17
# House Redwyne                      16
# House Florent                      16
# Night's Watch                      16
# House Tarbeck                      14
# House Blackfyre                    14
# House Waynwood                     14
# House Baratheon of Dragonstone     13
# Citadel                            13
# House Osgrey                       12
# Faith of the Seven                 12
# Kingsguard                         12
# House Bolton                       12
# House Karstark                     12
# House Tarly                        12
# House Rowan                        12
# House Seaworth                     11
# House Westerling                   11
# House Mormont                      11
# House Stokeworth                   11
# House Glover                       11
# House Darklyn                      10
# House Umber                        10
# Brotherhood without banners        10
# Mance Rayder                        9
# House Crakehall                     9
# House Penrose                       9
# House Brax                          9
# House Farman                        9
# House Whent                         9
# House Botley                        9
# House Sarwyck                       9
# House Beesbury                      9
# dtype: int64

# %%
# first_layer[first_layer['successor'].notna()]['successor'].head(100)

# %%
# Transform nodes into partnerships (= single or couple), 
# so that they will be easier to use in a hierarchical structure

all_with_spouse = all_usable_data[all_usable_data['spouse'].notnull()]
all_with_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 725 entries, 46 to 1342
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           725 non-null    object
#  1   allegiance     695 non-null    object
#  2   father         251 non-null    object
#  3   url            725 non-null    object
#  4   fatherRumored  2 non-null      object
#  5   mother         149 non-null    object
#  6   spouse         725 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 51.0+ KB

# %%
all_no_spouse = all_usable_data[all_usable_data['spouse'].isna()]
all_no_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 759 entries, 72 to 1343
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           759 non-null    object
#  1   allegiance     650 non-null    object
#  2   father         690 non-null    object
#  3   url            759 non-null    object
#  4   fatherRumored  9 non-null      object
#  5   mother         341 non-null    object
#  6   spouse         0 non-null      object
#  7   motherRumored  2 non-null      object
# dtypes: object(8)
# memory usage: 53.4+ KB

# %%
all_relations = all_with_spouse.explode('spouse').dropna(subset=['spouse'])
all_relations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 761 entries, 46 to 1342
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           761 non-null    object
#  1   allegiance     731 non-null    object
#  2   father         291 non-null    object
#  3   url            761 non-null    object
#  4   fatherRumored  2 non-null      object
#  5   mother         171 non-null    object
#  6   spouse         761 non-null    object
#  7   motherRumored  0 non-null      object
# dtypes: object(8)
# memory usage: 53.5+ KB

# %%
# all_relations.reset_index(inplace=True)
all_relations_with_spouse = pd.merge(all_relations, all_relations, how='left', left_on='spouse', right_on='name', suffixes=('', '_spouse'))
all_relations_with_spouse = all_relations_with_spouse.reset_index()
all_relations_with_spouse = pd.merge(all_relations_with_spouse, all_no_spouse, how='left', left_on='spouse', right_on='name', suffixes=('', '_no-spouse'))

all_relations_with_spouse.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1336 entries, 0 to 1335
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    1336 non-null   int64
#  1   name                     1336 non-null   object
#  2   allegiance               1241 non-null   object
#  3   father                   478 non-null    object
#  4   url                      1336 non-null   object
#  5   fatherRumored            2 non-null      object
#  6   mother                   273 non-null    object
#  7   spouse                   1336 non-null   object
#  8   motherRumored            0 non-null      object
#  9   name_spouse              1213 non-null   object
#  10  allegiance_spouse        1123 non-null   object
#  11  father_spouse            564 non-null    object
#  12  url_spouse               1213 non-null   object
#  13  fatherRumored_spouse     2 non-null      object
#  14  mother_spouse            282 non-null    object
#  15  spouse_spouse            1213 non-null   object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: int64(1), object(24)
# memory usage: 271.4+ KB

# %%
all_relations_with_spouse = all_relations_with_spouse.drop_duplicates(subset=['name', 'father', 'mother', 'spouse', 'name_spouse', 'father_spouse', 'mother_spouse'], ignore_index=True)
all_relations_with_spouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    549 non-null    int64
#  1   name                     549 non-null    object
#  2   allegiance               532 non-null    object
#  3   father                   291 non-null    object
#  4   url                      549 non-null    object
#  5   fatherRumored            2 non-null      object
#  6   mother                   171 non-null    object
#  7   spouse                   549 non-null    object
#  8   motherRumored            0 non-null      object
#  9   name_spouse              444 non-null    object
#  10  allegiance_spouse        430 non-null    object
#  11  father_spouse            227 non-null    object
#  12  url_spouse               444 non-null    object
#  13  fatherRumored_spouse     2 non-null      object
#  14  mother_spouse            141 non-null    object
#  15  spouse_spouse            444 non-null    object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: int64(1), object(24)
# memory usage: 107.4+ KB

# %%
# all_relations_with_spouse[all_relations_with_spouse['name_spouse'].isna()].info()

# %%
# all_relations_with_spouse[all_relations_with_spouse['name_no-spouse'].notna()].info()

# %%
# all_relations_with_spouse[all_relations_with_spouse['name_spouse'].isna()].sort_values('name').head(20)

# %%
# all_relations_with_spouse.reset_index(inplace=True)
# all_no_spouse.reset_index(inplace=True)
final_data = pd.concat([all_relations_with_spouse, all_no_spouse])
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1308 entries, 0 to 1343
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    549 non-null    float64
#  1   name                     1308 non-null   object
#  2   allegiance               1182 non-null   object
#  3   father                   981 non-null    object
#  4   url                      1308 non-null   object
#  5   fatherRumored            11 non-null     object
#  6   mother                   512 non-null    object
#  7   spouse                   549 non-null    object
#  8   motherRumored            2 non-null      object
#  9   name_spouse              444 non-null    object
#  10  allegiance_spouse        430 non-null    object
#  11  father_spouse            227 non-null    object
#  12  url_spouse               444 non-null    object
#  13  fatherRumored_spouse     2 non-null      object
#  14  mother_spouse            141 non-null    object
#  15  spouse_spouse            444 non-null    object
#  16  motherRumored_spouse     0 non-null      object
#  17  name_no-spouse           24 non-null     object
#  18  allegiance_no-spouse     1 non-null      object
#  19  father_no-spouse         22 non-null     object
#  20  url_no-spouse            24 non-null     object
#  21  fatherRumored_no-spouse  2 non-null      object
#  22  mother_no-spouse         21 non-null     object
#  23  spouse_no-spouse         0 non-null      object
#  24  motherRumored_no-spouse  0 non-null      object
# dtypes: float64(1), object(24)
# memory usage: 265.7+ KB

# %%
all_names = final_data['name']


mothers_no_primary_name = final_data[(final_data['mother'].notna() & ~final_data['mother'].isin(all_names))]['mother']
fathers_no_primary_name = final_data[(final_data['father'].notna() & ~final_data['father'].isin(all_names))]['father']
spouses_no_primary_name = final_data[(final_data['spouse'].notna() & ~final_data['spouse'].isin(all_names))]['spouse']

mothers_no_primary_name.drop_duplicates()
# Out:
# 212                 Daenys Targaryen
# 231                  Marilda of Hull
# 255                    Catelyn Tully
# 272                Rohanne of Tyrosh
# 325              Goddess of the wind
# 364                   Rohanne Webber
# 388                      Dorna Swyft
# 411                   Olenna Redwyne
# 445                   Alayne Baelish
# 462                 Shaera Targaryen
# 471                 Valaena Velaryon
# 487                 Delonne Allyrion
# 524                  House Targaryen
# 27                    House Charlton
# 48                           Chataya
# 59                     Dorna Sarwyck
# 87                             Cissy
# 90                           Megette
# 127     House Fossoway of New Barrel
# 144                   Arwyn Oakheart
# 158                Bellegere Otherys
# 167                          Mhaegen
# 172                            Whore
# 174                Bellonara Otherys
# 177                         Dothraki
# 239                Melissa Blackwood
# 267                     Prostitution
# 402                    House Belmore
# 424                   House Fossoway
# 464                            Essie
# 505                      Penny Jenny
# 506             Maiden-Made-of-Light
# 546                    House Serrett
# 551                   House Waynwood
# 650                 Elaena Targaryen
# 678                            Wylla
# 689                     Sharra Arryn
# 700                           Briony
# 705                  Larra Blackmont
# 722                    Sailor's Wife
# 750                       Wylla Fenn
# 754                   House Gardener
# 867                            Doshi
# 901                    Anya Waynwood
# 905                        Smallfolk
# 924                        Old Blood
# 1040                   Squinty Jeyne
# 1045                      Lysa Tully
# 1058                    Lyessa Flint
# 1129                 Summer Islander
# 1148                  Serenei of Lys
# 1155                          Esgred
# 1190                  Nymella Toland
# 1313                 House Hightower
# Name: mother, dtype: object

# %%
fathers_no_primary_name.drop_duplicates().head(50)
# Out:
# 219                    Jaehaerys I Targaryen
# 224                          Daemon Velaryon
# 225                             House Harlaw
# 232                             Jasper Arryn
# 233                           Lucas Harroway
# 234                         Rickard Karstark
# 236                           House Oakheart
# 237                            Lyonel Strong
# 238                         House Stackspear
# 239                          House Blackwood
# 261                           Rodrik Ryswell
# 262                             Raymar Royce
# 269              Rodrik Stark (son of Beron)
# 272                       Daemon I Blackfyre
# 278                                 Gulltown
# 280                            House Corbray
# 281                Lord Costayne (Daeron II)
# 287    Baelon Targaryen (son of Jaehaerys I)
# 295                         Vaemond Velaryon
# 297                            House Greyjoy
# 305                            Colin Florent
# 310                                   Bharbo
# 322                           William Mooton
# 323                              Royce Caron
# 325                                  Sea god
# 328                           House Costayne
# 330                             Robert Reyne
# 336                              Andros Brax
# 338                                Lord Frey
# 339                          Aenar Targaryen
# 344                   Damon Lannister (lord)
# 347                          House Baratheon
# 353            Lord Tully (father of Hoster)
# 367            Lord Darry (father of Raymun)
# 368                            Alyn Marbrand
# 369                              Vayon Poole
# 375                        Roland Westerling
# 391                          Lysandro Rogare
# 392                          House Lannister
# 393                            Victor Tyrell
# 398                             Moryn Tyrell
# 402          Lord Corbray (father of Lyonel)
# 407             Lord Farman (father of Lysa)
# 416                          Garth Greenhand
# 418                            House Prester
# 420                          Bertrand Tyrell
# 428                                  Tormund
# 429                           Horton Redfort
# 438                        Runceford Redwyne
# 439                           Quentin Tyrell
# Name: father, dtype: object

# %%
spouses_no_primary_name.drop_duplicates().tail(16)
# Out:
# 432                        Corpse queen
# 434                         House Uller
# 435                            Hellholt
# 448                       House Grafton
# 453                         Edmyn Tully
# 457                       Dorna Sarwyck
# 462                  Aerys II Targaryen
# 464    Aegon Targaryen (son of Aenys I)
# 480                  Daemon I Blackfyre
# 485                       House Belmore
# 499                 Arlan III Durrandon
# 510                      Roland I Arryn
# 523                                Jarl
# 526                        House Farman
# 540                      House Charlton
# 542                         House Rowan
# Name: spouse, dtype: object

# %%
# Save final dataset
# all_usable_data.to_json('./ice_and_fire_final.json', orient='records')
final_data[['name', 'allegiance', 'url', 'mother', 'father', 'spouse', 'motherRumored', 'fatherRumored']].to_json('./ice_and_fire_final.json', orient='records')
