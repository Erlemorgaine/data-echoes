# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import string
import nltk

nltk.download('punkt')

datasets = ['ayam', 'ikan', 'kambing', 'sapi', 'telur', 'tahu', 'tempe', 'udang']
dfs = [pd.read_csv(f'./indo-food/dataset-{food}.csv') for food in datasets]
recipes = pd.concat(dfs)

recipes.dropna(inplace=True)
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15593 entries, 0 to 1993
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        15593 non-null  object
#  1   Ingredients  15593 non-null  object
# dtypes: object(2)
# memory usage: 365.5+ KB
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Erle_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Function to tokenize and clean text
def process_text(text):
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens if word.isalpha()]
    return tokens

recipes['ingredients_clean'] = recipes['Ingredients'].apply(process_text)
all_ingredients = [ingredient for sublist in recipes['ingredients_clean'].tolist() for ingredient in sublist]

punctuation = list(string.punctuation)
filtered_ingredients = [ingredient for ingredient in all_ingredients if ingredient not in punctuation]

# %%
# Calculate word frequencies
freq_dist = FreqDist(filtered_ingredients)

n_most_common = 100 
most_common_words = freq_dist.most_common(n_most_common)

# %%
most_common_words
# Out:
# [('bawang', 31410),
#  ('secukupnya', 22657),
#  ('merah', 18519),
#  ('buah', 17682),
#  ('siung', 16885),
#  ('putih', 16278),
#  ('garam', 13771),
#  ('daun', 11842),
#  ('cabe', 10716),
#  ('gula', 8705),
#  ('iris', 7015),
#  ('butir', 6665),
#  ('air', 6631),
#  ('potong', 6490),
#  ('bubuk', 6287),
#  ('minyak', 6270),
#  ('rawit', 6040),
#  ('kecap', 5685),
#  ('goreng', 5203),
#  ('ayam', 4927),
#  ('ruas', 4864),
#  ('tomat', 4825),
#  ('jeruk', 4595),
#  ('lembar', 4519),
#  ('tepung', 4304),
#  ('telur', 4283),
#  ('manis', 4165),
#  ('merica', 3887),
#  ('batang', 3859),
#  ('jahe', 3857),
#  ('selera', 3701),
#  ('salam', 3630),
#  ('lada', 3606),
#  ('daging', 3585),
#  ('dan', 3316),
#  ('penyedap', 3253),
#  ('sesuai', 3244),
#  ('kunyit', 3119),
#  ('besar', 3105),
#  ('kecil', 3093),
#  ('tahu', 3061),
#  ('untuk', 3016),
#  ('cabai', 2997),
#  ('kemiri', 2970),
#  ('bumbu', 2910),
#  ('sapi', 2878),
#  ('halus', 2840),
#  ('ketumbar', 2822),
#  ('geprek', 2667),
#  ('lengkuas', 2640),
#  ('tempe', 2523),
#  ('udang', 2475),
#  ('bombay', 2414),
#  ('kaldu', 2409),
#  ('tipis', 2335),
#  ('saus', 2326),
#  ('rasa', 2250),
#  ('biji', 2199),
#  ('tiram', 2012),
#  ('gram', 1971),
#  ('sendok', 1911),
#  ('kambing', 1875),
#  ('pasir', 1866),
#  ('wortel', 1855),
#  ('ikan', 1833),
#  ('saos', 1788),
#  ('sedikit', 1739),
#  ('cincang', 1733),
#  ('santan', 1693),
#  ('di', 1678),
#  ('menumis', 1676),
#  ('ukuran', 1664),
#  ('terigu', 1630),
#  ('hijau', 1625),
#  ('keriting', 1574),
#  ('bungkus', 1566),
#  ('papan', 1566),
#  ('serai', 1456),
#  ('sereh', 1410),
#  ('jari', 1397),
#  ('saya', 1378),
#  ('sedang', 1350),
#  ('nipis', 1281),
#  ('ekor', 1270),
#  ('yg', 1150),
#  ('dadu', 1146),
#  ('jawa', 1065),
#  ('pakai', 1060),
#  ('lbr', 1045),
#  ('rebus', 1043),
#  ('bisa', 1020),
#  ('btr', 1016),
#  ('kentang', 990),
#  ('royco', 988),
#  ('kotak', 969),
#  ('asin', 927),
#  ('haluskan', 915),
#  ('atau', 893),
#  ('asam', 882),
#  ('kupas', 879)]

# %%
most_common_english = [
 'onion',
 'to taste',
 'red',
 'fruit',
 'clove',
 'white',
 'salt',
 'leaf',
 'chili',
 'sugar',
 'slice',
 'grain',
 'water',
 'cut',
 'powder',
 'oil',
 'chili pepper',
 'soy sauce',
 'fried',
 'chicken',
 'segment',
 'tomato',
 'orange',
 'sheet',
 'flour',
 'egg',
 'sweet',
 'pepper',
 'stalk',
 'ginger',
 'taste',
 'bay leaf',
 'pepper',
 'meat',
 'and',
 'seasoning',
 'according',
 'turmeric',
 'big',
 'small',
 'tofu',
 'for',
 'chili',
 'candlenut',
 'spice',
 'beef',
 'smooth',
 'coriander',
 'crushed',
 'galangal',
 'tempeh',
 'shrimp',
 'onion',
 'broth',
 'thin',
 'sauce',
 'taste',
 'seed',
 'oyster sauce',
 'gram',
 'spoon',
 'goat',
 'sand',
 'carrot',
 'fish',
 'sauce',
 'a little',
 'chopped',
 'coconut milk',
 'in',
 'stir-fry',
 'size',
 'flour',
 'green',
 'curly',
 'pack',
 'board',
 'lemongrass',
 'lemongrass',
 'finger',
 'I',
 'medium',
 'thin',
 'tail',
 'which',
 'dice',
 'Java',
 'use',
 'sheet',
 'boil',
 'can',
 'seed',
 'potato',
 'royco',
 'box',
 'salty',
 'smooth',
 'or',
 'tamarind',
 'peel']

# %%
most_common_spices = [
 ('onion', 'bawang/bombay', 33824),
 ('red', 'merah', 18519),
 ('fruit', 'buah', 17682),   
 ('clove', 'siung', 16885),
 ('white', 'putih', 16278),
 ('chili', 'cabe/cabai', 13713),
 ('leaf', 'daun', 11842),
 ('sugar', 'gula', 8705),
 ('powder', 'bubuk', 6287),
 ('chili pepper', 'rawit', 6040),
 ('pepper', 'merica', 3887),
 ('ginger', 'jahe', 3857),
 ('bay leaf', 'salam', 3630),
 ('pepper', 'lada', 3606),
 ('seasoning', 'penyedap', 3253),
 ('turmeric', 'kunyit', 3119),
 ('chili', 'cabai', 2997),
 ('candlenut', 'kemiri', 2970),
 ('lemongrass', 'sereh/serai', 2866),
 ('coriander', 'ketumbar', 2822),
 ('galangal', 'lengkuas', 2640),
 ('tempeh', 'tempe', 2523),
 ('seed', 'biji', 2199),
 ('sand', 'pasir', 1866),
 ('coconut milk', 'santan', 1693),
 ('green', 'hijau', 1625),
 ('curly', 'keriting', 1574),
 ('Java', 'jawa', 1065),
 ('seed', 'btr', 1016),
 ('salty', 'asin', 927),
 ('tamarind', 'asam', 882)]

# %%
duplicate_recipes = recipes[recipes.duplicated(subset=['Title'])]
duplicate_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3135 entries, 18 to 1989
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              3135 non-null   object
#  1   Ingredients        3135 non-null   object
#  2   ingredients_clean  3135 non-null   object
# dtypes: object(3)
# memory usage: 98.0+ KB

# %%
unique_recipes = recipes.drop_duplicates(subset=['Title'])
unique_recipes = unique_recipes.reset_index()
unique_recipes.info()
unique_recipes['Title'].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12458 entries, 0 to 12457
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              12458 non-null  int64
#  1   Title              12458 non-null  object
#  2   Ingredients        12458 non-null  object
#  3   ingredients_clean  12458 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 389.4+ KB
# 12458

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(unique_recipes['Title'])

# Apply t-SNE to reduce the dimensionality
tsne = TSNE(n_components=2, random_state=42, init='random')
tsne_result = tsne.fit_transform(tfidf_matrix)

# %%
tsne_recipes = pd.DataFrame(tsne_result, columns=['tsne_1', 'tsne_2'])
tsne_recipes.info()
unique_recipes['Title'].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12458 entries, 0 to 12457
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tsne_1  12458 non-null  float32
#  1   tsne_2  12458 non-null  float32
# dtypes: float32(2)
# memory usage: 97.5 KB
# 12458

# %%
tsne_recipes['recipe'] = unique_recipes['Title']
tsne_recipes.head(10)
# Out:
#       tsne_1     tsne_2                         recipe
# 0  -4.538434 -83.260063               Ayam Woku Manado
# 1  24.954378 -72.955711       Ayam goreng tulang lunak
# 2 -76.478569 -32.169785               Ayam cabai kawin
# 3  -3.956352 -23.852463                    Ayam Geprek
# 4 -23.488886  21.775349                    Minyak Ayam
# 5  14.304609 -41.217674                Nasi Bakar Ayam
# 6 -27.668842  30.539787        Ayam Saus Hintalu Jaruk
# 7 -33.649857  78.256081  Ayam saos teriyaki Lada Hitam
# 8  14.148297  69.556618                     Steak ayam
# 9  -1.584802 -40.231346    Ayam Saos Asam Manis Simple

# %%
from sklearn.cluster import KMeans

n_clusters = 200
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
tsne_recipes['cluster'] = kmeans.fit_predict(tsne_recipes[['tsne_1', 'tsne_2']])

# Find cluster centers
cluster_centers = kmeans.cluster_centers_
# Out:
# C:\Users\Erle_\MyCode\my-code\data-echoes\.data-echoes\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import numpy as np

# Get distances to each cluster center for each data point
distances_per_cluster = kmeans.transform(tsne_recipes[['tsne_1', 'tsne_2']])

# Get the smallest distance each data point
distances = np.min(distances_per_cluster, axis=1)

tsne_recipes['distance'] = distances
center_recipes = tsne_recipes[['cluster', 'recipe', 'distance']].groupby('cluster').min()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(tsne_recipes['tsne_1'], tsne_recipes['tsne_2'], c=tsne_recipes['cluster'], cmap='Pastel1')

# Annotate cluster centers
for center, label in zip(cluster_centers, center_recipes['recipe']):
    plt.annotate(label, (center[0], center[1]), textcoords="offset points", xytext=(0, 0), ha='center', size=8)

plt.title('t-SNE Visualization of Recipe Names')
plt.show()
