# %%
import pandas as pd

raw_data_1 = pd.read_json('./ppg-episode-transcripts-1.json', encoding='utf-8')
raw_data_2 = pd.read_json('./ppg-episode-transcripts-2.json', encoding='utf-8')

# %%
raw_data = pd.concat([raw_data_1, raw_data_2])

raw_data.head()
# Out:
#                             episode  \
# 0  'Twas the Fight Before Christmas
# 1                15 Minutes of Fame
# 2               A Comedy of Terrors
# 3                     A Documentary
# 4                   A Made Up Story
#
#                                               dialog
# 0  [Narrator: 'Twas the city of Townsville, and a...
# 1  [Angela: And over here is our newest acquisiti...
# 2                  [Kaoru Matsubara: Check him out.]
# 3  [Brian Larsen: The city of Townsville. This is...
# 4  [Narrator: The city of Townsville!  Where some...

# %%
raw_data.describe()
# Out:
#                                  episode dialog
# count                                252    251
# unique                               252    237
# top     'Twas the Fight Before Christmas     []
# freq                                   1     15

# %%
# Drop all
# - Animated shorts
# - Movies
# - PPG Z episodes
episodes_to_drop = [
   'a comedy of terrors', # powerpuff girls Z
    'enter the entourage',  # powerpuff girls Z
    "it's all because of him", # powerpuff girls Z
    'powerpuff girls to the rescue', # powerpuff girls Z

   'air buttercup', # Animated short, 2016
   "bubbles' beauty blog", # Animated short, 2016
   'ping pong z', # Animated short, 2016
   'run, blossom, run!', # Animated short, 2016
    "i'll be bake", # Animated short, 2017
    'mojo builds a shelf', # Animated short, 2017
    'the powerpuff girls rule!!!', # TV short, 2008

   'crime 101', # Pilot, 1995/1996
   'meat fuzzy lumkins', # Pilot, 1995

   'whoopass stew' # Movie, their first-ever appearance, 1992
   'the powerpuff girls movie', # Movie, 2002
   "'twas the fight before christmas",  # Movie, 2003
   'powerpuff girls special: dance pantsed', # Movie (weird style), 2014

   'ttg v ppg', # Teen titans, not ppg 
]

raw_data = raw_data[~raw_data['episode'].str.lower().isin(episodes_to_drop)]

# %%
all_lines = raw_data.explode(column='dialog')
all_lines = all_lines.reset_index(drop=True)
all_lines.head()
# Out:
#               episode                                             dialog
# 0  15 Minutes of Fame  Angela: And over here is our newest acquisitio...
# 1  15 Minutes of Fame  Blossom: Bubbles, you can calm down now. You d...
# 2  15 Minutes of Fame               Buttercup: Yeah, dude! Check it out!
# 3  15 Minutes of Fame                                          Cat: Meow
# 4  15 Minutes of Fame  Blossom: That's right, cats can always get up ...

# %%
all_lines[all_lines['dialog'].isna()]['episode']
# Out:
# 2494                      Bye Bye, Bellum
# 2873                        Cheep Thrills
# 6668                     Horn, Sweet Horn
# 11011                         Night Mayor
# 11709              Once Upon a Townsville
# 14907                        Sideline Dad
# 14908                    Silent Treatment
# 15316    Small World: Heart to Heartstone
# 16126                        Strong-Armed
# 17210         Take Your Kids to Dooms Day
# 17477                       The Big Sleep
# 17930                             The Fog
# 18623                     The Squashening
# 18624                        The Stayover
# 19471           Total Eclipse of the Kart
# Name: episode, dtype: object

# %%
speakers = all_lines['dialog'].str.extract("^([.,*#-'/\w\s]*):")

all_lines['speaker'] = speakers
all_lines['speaker'] = all_lines['speaker'].str.strip()
all_lines['speaker'] = all_lines['speaker'].str.lower()
speakers.nunique()
# Out:
# 0    1114
# dtype: int64

# %%
all_lines['dialog'].head(50)
# Out:
# 0     Angela: And over here is our newest acquisitio...
# 1     Blossom: Bubbles, you can calm down now. You d...
# 2                  Buttercup: Yeah, dude! Check it out!
# 3                                             Cat: Meow
# 4     Blossom: That's right, cats can always get up ...
# 5                                      Cat: Meow, Meow.
# 6     Brian Larsen: The city of Townsville. This is ...
# 7     Brian: Oh, you might know them as those three ...
# 8     Brian: I'm Brian, and this is my documentary. ...
# 9         Brian: Sugar... spice... and everything nice.
# 10    Brian: Yep, those are pretty normal ingredient...
# 11    Brian: The city of Townsville. A great city wi...
# 12    Brian: The newly renovated and revitalized Old...
# 13    Brian: Although this bus looks better than tha...
# 14    Brian: There are other reminders and countless...
# 15    Brian: Their photos have graced newspapers and...
# 16    Brian: They have merchandising... and even the...
# 17    Brian: My first visit was unannounced... and j...
# 18    Brian: the girls flew away. Three bright strea...
# 19    Brian: Okay... I'm driving up through the city...
# 20    Brian: I keep trying to get closer, but the ba...
# 21    Brian: I'm- I'm okay, now I'm gonna get out of...
# 22    Brian: And just when I thought I was going to ...
# 23    Brian: And although I played this cat- and- mo...
# 24    Brian: I started at their school, the Pokey Oa...
# 25    Ms. Keane: Well, let me tell you, the girls ar...
# 26    Brian: Could you tell me more about the Powerp...
# 27    Ms. Keane: Well, um... I'm their teacher. I re...
# 28    Brian: As I left the school, I happened upon t...
# 29    Carl: About the Powerpuff Girls, huh? Well, th...
# 30    Brian: I didn't get much from Carl. But he gav...
# 31    Brian: This is Dave, the local cop who hauled ...
# 32    Dave: Oh, yeah. I been in a few sticky situati...
# 33    Dave: Naah, I don't have monster enforcement t...
# 34    Brian: With little luck on the grassroots leve...
# 35    Mayor: Okay, everyone. That about does it for ...
# 36    Brian: Ah, Mayor!  Uh, hi. I'm shooting a docu...
# 37    Mayor: Look, I don't know nothin' about nothin...
# 38    Ms. Bellum: I'm sorry, but you're going to hav...
# 39          Brian: Uh, just let me ask a few questions.
# 40    Ms. Bellum: Uh, this is an unannounced visit. ...
# 41                       Brian: Don't touch the camera!
# 42    Brian: That really didn't get me anywhere. Wit...
# 43    Talking Dog: I'm a talking dog. That is so muc...
# 44    Brian: Having dealt with the positive side of ...
# 45           Brian: But this proved even more fleeting.
# 46                      Princess: Sorry. No interviews!
# 47               Fuzzy: GET OFFA MY PROPERTY, DAGNABIT!
# 48             Brian: Yeah, but wait, I just want to...
# 49                          Fuzzy: NO TRESPASSIN'! OFF!
# Name: dialog, dtype: object

# %%
dialog_lines = all_lines['dialog']
dialog_lines = dialog_lines.reset_index(drop=True)
dialog_lines
# Out:
# 0        Angela: And over here is our newest acquisitio...
# 1        Blossom: Bubbles, you can calm down now. You d...
# 2                     Buttercup: Yeah, dude! Check it out!
# 3                                                Cat: Meow
# 4        Blossom: That's right, cats can always get up ...
#                                ...
# 20406    Mojo: But it is I who planned it! I did it, no...
# 20407    Mojo: Iam responsible for trying to destroy you!
# 20408                   Blossom: Okay. Thenyougo to jail.
# 20409                                  Mojo: That's right!
# 20410    Narrator: So once again the day is saved-thank...
# Name: dialog, Length: 20411, dtype: object

# %%
def process_dialog(dialog):
    if isinstance(dialog, str):
        parts = dialog.split(': ')
        if len(parts) > 1:
            return ' '.join(parts[1:])
        elif len(parts) == 1:
            return parts[0]
    else:
        return None
    
dialog_without_speaker = dialog_lines.apply(process_dialog)

# %%
dialog_without_speaker.head(50)
# Out:
# 0     And over here is our newest acquisition to the...
# 1           Bubbles, you can calm down now. You did it!
# 2                             Yeah, dude! Check it out!
# 3                                                  Meow
# 4     That's right, cats can always get up a tree......
# 5                                           Meow, Meow.
# 6     The city of Townsville. This is where the Powe...
# 7     Oh, you might know them as those three cute li...
# 8     I'm Brian, and this is my documentary. And you...
# 9                Sugar... spice... and everything nice.
# 10    Yep, those are pretty normal ingredients, all ...
# 11    The city of Townsville. A great city with many...
# 12    The newly renovated and revitalized Old Townsv...
# 13    Although this bus looks better than that corpo...
# 14    There are other reminders and countless monume...
# 15    Their photos have graced newspapers and tabloi...
# 16    They have merchandising... and even their own ...
# 17    My first visit was unannounced... and just as ...
# 18    the girls flew away. Three bright streaks cut ...
# 19    Okay... I'm driving up through the city, and t...
# 20    I keep trying to get closer, but the battle ke...
# 21    I'm- I'm okay, now I'm gonna get out of my car...
# 22    And just when I thought I was going to capture...
# 23    And although I played this cat- and- mouse gam...
# 24    I started at their school, the Pokey Oaks. Ms....
# 25    Well, let me tell you, the girls are fantastic...
# 26    Could you tell me more about the Powerpuff sid...
# 27    Well, um... I'm their teacher. I really don't ...
# 28    As I left the school, I happened upon the tras...
# 29    About the Powerpuff Girls, huh? Well, they kee...
# 30    I didn't get much from Carl. But he gave me an...
# 31    This is Dave, the local cop who hauled me in f...
# 32    Oh, yeah. I been in a few sticky situations wi...
# 33    Naah, I don't have monster enforcement trainin...
# 34    With little luck on the grassroots level, I de...
# 35    Okay, everyone. That about does it for the pay...
# 36    Ah, Mayor!  Uh, hi. I'm shooting a documentary...
# 37    Look, I don't know nothin' about nothin'!  You...
# 38        I'm sorry, but you're going to have to leave.
# 39                 Uh, just let me ask a few questions.
# 40          Uh, this is an unannounced visit. Security!
# 41                              Don't touch the camera!
# 42    That really didn't get me anywhere. With my in...
# 43    I'm a talking dog. That is so much better than...
# 44    Having dealt with the positive side of the spe...
# 45                  But this proved even more fleeting.
# 46                                Sorry. No interviews!
# 47                      GET OFFA MY PROPERTY, DAGNABIT!
# 48                    Yeah, but wait, I just want to...
# 49                                 NO TRESPASSIN'! OFF!
# Name: dialog, dtype: object

# %%
all_lines['dialog'] = dialog_without_speaker
all_lines['dialog']
# Out:
# 0        And over here is our newest acquisition to the...
# 1              Bubbles, you can calm down now. You did it!
# 2                                Yeah, dude! Check it out!
# 3                                                     Meow
# 4        That's right, cats can always get up a tree......
#                                ...
# 20406    But it is I who planned it! I did it, not them...
# 20407          Iam responsible for trying to destroy you!
# 20408                            Okay. Thenyougo to jail.
# 20409                                        That's right!
# 20410    So once again the day is saved-thanks to the P...
# Name: dialog, Length: 20411, dtype: object

# %%
unique_speakers = all_lines['speaker'].unique()

for speaker in unique_speakers:
    if isinstance(speaker, str) and ',' in speaker:
        print(speaker)
# Out:
# bubbles, buttercup
# blossom, buttercup
# blossom, bubbles and buttercup
# kids, blossom
# slim, junior
# mojo, princess, boys
# blossom, bubbles, buttercup and the professor
# blossom, bubbles, and buttercup
# professor, blossom, buttercup
# brick, butch
# blossom, bubbles
# teen blossom, teen buttercup
# girl 2, boy 1
# blossom/ms. bellum, buttercup/professor
# mayor, ms. bellum
# mojo, 'him'
# bossman, bossman 2
# slim, slim 2
# junior, juniors 2 and 3
# bubbles, buttercup, random boy, random girl, another random boy, robin snyder, another random boy, two random boys, blossom, jared, and barry
# random girl , random boy , random boy , buttercup  on the left, jared , and robin , blossom , and two boys
# blossom, buttercup, jared, barry, and robin
# chad, man with glasses, and pink haired lady
# driver, robbers
# girls, duplicates
# kids, parents
# stan, sandra
# fields, anthropist, blind
# class, ms. keane
# girls, professor
# professor, ms. keane
# ace, billy, arturo
# fuzzy, princess, 'him'
# kim, jeff, mary
# joey, kim
# necktie wearing monster, waitress
# man 9, bass monster
# gang, fuzzy, 'him'
# bertha, beatrice
# lloyd, floyd
# ace, snake, lil' arturo, big billy
# 002, 017
# ace, snake, arturo, billy
# ace, snake
# boys 2, 3, 4
# monty, slim
# bubbles, buttercup and the professor
# girls, robin
# barry, bubbles, and buttercup
# blossom, in the shop
# crowd, professor, ms. bellum
# governor, yokel, lummox

# %%
# Save one as second speaker
double_speakers = [    
    "blossom and buttercup",
    "blossom and bubbles",
    "the professor and blossom",
    "both blossom and buttercup",
    "buttercup and blossom",
    "blossom and the professor",
    "bubbles and blossom",
    "bubbles and buttercup",
    "buttercup and bubbles",
    "professor and buttercup",
    "professor utonium and javier xavier",
    "man and woman",
    "girls and erica",
    "momoko and miyako",
    "kaoru and miyako",
    "ms. bellumold woman 1",
    "ms. keaneold woman 2",
    "mayor and ms. bellum",
    "blossom/ms. bellum",
    "ms. bellum/blossom",
    "buttercup/green batman",
    "bubbles/bubbs wonder",
    "buttercup/professor",
    "professor/buttercup",
    "blossom/ms. bellum",
    "bubbles/mayor",
    "mayor/bubbles",
    "ms. bellum/blossom",
    "girl 1/ace",
    "girl 2/grubber",
    "girl 3/snake",
    "old woman/mojo",
    "mojo/old woman",
    "blossom/dachshund",
    "bubbles/centipede",
    "buttercup/cobra",
    "professor/older girl",
    "mojo/fish",
    "professor/ugly baby",
    "professor/nurse",
    "professor/astronaut",
    "professor/pink creature",
    "professor/morbid woman",
    "bubbles/narrator",
    "narrator/bubbles",
    "blossom/bubbles",
    "octi/him",
    "buttercup/bubblecup",
    "bubbles/children",
    "old man/janitor",
    "eyes/blonde hair covered boy",
    "blossom/liberty belle",
    "bubbles/harmony bunny",
    "buttercup/mange",
    "blossom/buttercup",
    "bubbles, buttercup",
"girls, professor",
"blossom, buttercup",
"blossom, bubbles and buttercup",
"kids, blossom",
"slim, junior",
"mojo, princess, boys",
"blossom, bubbles, buttercup and the professor",
"blossom, bubbles, and buttercup",
"professor, blossom, buttercup",
"brick, butch",
"blossom, bubbles",
"teen blossom, teen buttercup",
"girl 2, boy 1",
"skinny, tiny",
"blossom/ms. bellum, buttercup/professor",
"mayor, ms. bellum",
"mojo, 'him'",
"bossman, bossman 2",
"slim, slim 2",
"junior, juniors 2 and 3",
"bubbles, buttercup, random boy, random girl, another random boy, robin snyder, another random boy, two random boys, blossom, jared, and barry",
"random girl , random boy , random boy , buttercup  on the left, jared , and robin , blossom , and two boys",
"blossom, buttercup, jared, barry, and robin",
"chad, man with glasses, and pink haired lady",
"driver, robbers",
"girls, duplicates",
"kids, parents",
"stan, sandra",
"fields, anthropist, blind",
"class, ms. keane",
"pug faced paulie, scared",
"momoko, miyako, and kaoru",
"professor, ms. keane",
"ace, billy, arturo",
"fuzzy, princess, 'him'",
"kim, jeff, mary",
"joey, kim",
"man 9, bass monster",
"gang, fuzzy, 'him'",
"bertha, beatrice",
"lloyd, floyd",
"ace, snake, lil' arturo, big billy",
"002, 017",
"ace, snake, arturo, billy",
"ace, snake",
"boys 2, 3, 4",
"monty, slim",
"bubbles, buttercup and the professor",
"girls, robin",
"barry, bubbles, and buttercup",
"bubbles, blossom",
"many monkeys, chimpanzees, gorillas, orangutans, and even an uakari",
"crowd, professor, ms. bellum",
"governor, yokel, lummox",
"octi/'him'",
"'him'/ms. keane",
"blossom & buttercup",
"blossom & bubbles",
"bubbles & blossom",
"blossom & professor utonium",
"bubbles & buttercup",
"buttercup & bubbles",
"spikey haired boy & eyes/blonde hair covered boy",
"donny & chelsea"
]

blossom_values = [ 
    "blossom #2",
    "blosoom",
    "all blossoms",
    "blossom  and blossom",
    "the blossoms",
    "siren blossom",
    "teen blossom",
    "blossom as she fights the bunnies",
    "knockoff blossom",
    "survivor reject blossom",
    "angel blossom",
    "robot blossom",
    "robo blossom",
    "lice blossom",
    "french renaissance blossom",
    "old blossom",
    "blossom, in the shop",
    "blossom, to bubbles",
    "blossom's thoughts",
    "blossom ",
    "both blossom"
]

bubbles_values = [
    "bubbles",
    "bubbes",
    "dark bubbles",
    "teen bubbles",
    "knockoff bubbles",
    "robo bubbles",
    "french renaissance bubbles",
    "bubbles and doubles",
    "old bubbles",
    "bubblecup",
    "bubbles' voice",
    "bubbles #2"
]

buttercup_values = [
    "buttercup double",
    "buttecup",
    "real buttercup",
    "buttercup on video",
    "teen buttercup",
    "knockoff buttercup",
    "reject buttercup",
    "angel buttercup",
    "robo buttercup",
    "flashback buttercup",
    "old buttercup",
    "buttercup, to herself",
    "buttercup, disguised",
    "buttercup, as she accidentaly reveals herself",
    "buttercup, scared",
    "and buttercup",
    "buttercup  on the left",
    "buttercup's thoughts",
    "buttercup #2"
]

mojo_values = [
    "mojo",
    "jojo",
    "'mojo'",
    "'mojo' ",
    "mojo'",
    "mojo's thoughts"
]

professor_values = [
    "professor",
    "dream professor",
    "memory professor",
    "professor utonium",
    "kid professor",
    "young prof",
    "student prof",
    "the professor",
    "flashback professor",
]

mayor_values = [
    "mayor",
    "the mayor",
    "younger mayor",
    "mayor mayer",
    "mayor of new townsville",
    "lice mayor",
    "citiesville mayor",
]

him_values = [
    "him",
    "'him'",
    "memory him",
    "black spored him"
]

narrator_values = [
    "narrator",
    "male narrator",
    "man voiceover",
]

princess_values = [
    "princess morebucks",
    "princess",
    "princess morbucks",
    "morbucks",
    "morbucks' heart"
]

fuzzy_values = [
    "fuzzy",
    "fuzzy lumpkins"
]

brick_values = [
    "brick",
    "teen brick",
    "brickowski"
]

woman_values = [
    "old woman",
    "woman",
    "muscle woman",
    "woman in the suit",
    "policewoman",
    "woman 2",
    "woman 3",
    "brown skinned woman",
    "woman 1",
    "young woman",
    "adult teenage woman",
    "woman 4",
    "woman 5",
    "woman 6",
    "woman 7",
    "iss woman",
    "cowgirl woman",
    "backgrounder woman",
    "fat woman",
    "fainting woman",
    "nature woman",
    "jewel owner woman",
    "jamaican woman",
    "curler woman",
    "woman 8",
    "woman 9",
    "repairwoman",
    "morbid woman",
    "woman #2",
    "woman #3",
    "woman #1",
    "woman's voice",
    "lunch lady",
    "and pink haired lady",
    "rocket a.i. lady",
    "cleaning lady",
    "video lady",
    "lady" #1,
    "old lady",
    "banklady",
    "news lady",
    "elderly lady",
    "anchor lady",
    "lady",
    "baby lady",
    "random lady",
]

man_values = [
    "man",
    "policeman",
    "old man",
    "swan boat man",
    "barber man",
    "man 1",
    "man 2",
    "man 3",
    "man in court",
    "man in a blue long sleeved robe",
    "old man 1",
    "old man 2",
    "old man 3",
    "man with glasses",
    "policeman 1",
    "policeman 2",
    "security man 1",
    "security man 2",
    "postman",
    "renaissance man",
    "delivery man",
    "man with a green hat",
    "man wit a green hat",
    "man in the space suit",
    "running man",
    "pointing man",
    "manager",
    "french man with a french hat",
    "brown haired man with glasses",
    "man 4",
    "man 5",
    "hotdog man",
    "man 6",
    "man 7",
    "man 8",
    "man 9",
    "man 10",
    "man 11",
    "abs man",
    "commercial man",
    "prison man",
    "salesman",
    "henchman",
    "mailman",
    "backgrounder man",
    "bank manager",
    "pizza man",
    "rainbow man",
    "bagman",
    "gunman",
    "short man",
    "newsman",
    "jewel owner man",
    "smooth man",
    "anchorman",
    "businessman",
    "french renaissance man",
    "fireman 1",
    "man 12",
    "man 13",
    "man 14",
    "fireman 2",
    "man being stung by bees",
    "foam finger man",
    "man in overalls",
    "man in trough",
]

bliss_values = [
    "memory bliss",
    "bliss",
    "memory teenage bliss",
    "young memory bliss"
]

monster_values = [
    "monster",
    "pink tentacled monster",
    "green monster",
    "bass monster",
    "female fish monster",
    "red lizard monster",
    "lawyer monster",
    "monsters",
    "fancy monster",
    "purple octopus",
    "dragon",
    "pincered monster",
    "necktie wearing monster",
    "oneeyed monster",
    "singledout monster",
]

boy_values = [
    "boy",
    "huge boy",
    "pimple faced boy",
    "boy 1",
    "boy 2",
    "boy 3",
    "boy 4",
    "nerd boy",
    "bigger boy",
    "smaller boy",
    "boy with brown spiky hair",
    "man boy",
    "manboy",
    "spikey haired boy",
    "freckle faced boy",
    "boy 5",
    "boy 6",
    "boy 7",
    "boy nerd",
    "green haired boy with rapper glasses",
    "french renaissance orange haired boy",
    "redhead boy",
    "'injured' boy",
    "brownskinned boy",
    "random boy",
    "another random boy",
    "two random boys",
    "random boy ",
    "and two boys",
    "spikey haired boy & eyes/blonde hair covered boy",
    "blonde hair covered boy",
    "boys 2",
    "boy #1",
]

ppg_values = [
    "all 3 girls",
    "all three girls",
    "girls",
    "the girls",
    "old girls",
    "the 3 girls",
    "all girls",
    "powerpuff girls z",
    "the 4 girls"
]

rrb_values = [
    "boys"
]

girl_values = [
    "girl",
    "cool girl",
    "girl with braces",
    "girl 1",
    "girl 2",
    "girl 3",
    "blonde teenage girl",
    "blonde girl",
    "girl with glasses",
    "girl without glasses",
    "2 girls",
    "cool girl 1",
    "cool girl 3",
    "cool girl 2",
    "all 3 cool girls",
    "girl with brown hair",
    "brown haired girl",
    "cowgirl",
    "friendly girl",
    "derbytante girls",
    "spirit girl",
    "mail girl",
    "flower girl",
    "girl student",
    "girl 4",
    "2 unnamed girls",
    "unnamed girl with a pink shirt",
    "teenage girl 1",
    "teenage girl 3",
    "teenage girls",
    "pimple girl",
    "older girl",
    "random girl",
    "random girl ",
    "girl #1",
    "girl #2",
    "girl #3",
]

miyako_values = [
    "memory miyako",
    "miyako",
    "flashback miyako",
]

sapna_values = [
    "sapna,"
    "dream sapna",
    "spider sapna"
]

kaoru_values = [
    "kaoru matsubara"
]

announcer_values = [
    "space towtruck and the infinite jumper cables movie announcer",
    "announcer",
    "announcer 1",
    "announcer 2",
    "another announcer",
    "radio announcer",
    "tv announcer",
    "space towtruck announcer",
    "male pageant announcer",
    "video game announcer",
]

keane_values = [
    "ms. keane",
    "young keane",
    "keanes",
    "keane 2",
    "keane 1",
    "miss keane",
    "french renaissance ms. keane"
]

bellum_values = [
    "ms. bellum",
    "young bellum",
    "miss bellum"
]

billy_values = [
    "billy",
    "big billy"
]

butch_values = [
    "butch",
    "teen butch"
]

boomer_values = [
    "boomer",
    "teen boomer"
]

talking_dog_values = [
    "talking dog",
    "talking  dog",
    "talking dog billboard"
]

junior_values = [
    "junior",
    "junior 4"
]

bossman_values = [
    "bossman",
    "bossman 3",
    "bossman 2"
]

dick_values = [
    "dick",
    "student dick"
]

marianne_values = [
    'mrs. smith'
]

harold_values = [
    'mr. smith'
]

sedusa_values = [
    'ima'
]

# %%
import re

# All double speakers in consistent format (comma-separated)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: re.sub(r'(/|\sand\s|,\s|\s&\s)', ',', x) if x in double_speakers else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: re.sub('/', ',', x) if x in double_speakers else x)

all_lines.loc[all_lines['speaker'] == 'ms. bellumold woman 1', 'speaker'] = 'ms. bellum,woman'
all_lines.loc[all_lines['speaker'] == 'ms. keaneold woman 2', 'speaker'] = 'ms. keane,woman'

double_speaker_items = all_lines[all_lines['speaker'].isin(double_speakers)]
double_speaker_items['speaker']
# Out:
# Series([], Name: speaker, dtype: object)

# %%
len(all_lines['speaker'])
# Out:
# 20411

# %%
new_double_speakers = all_lines[all_lines['speaker'].str.contains(',', na=False)]
len(new_double_speakers['speaker'].value_counts())
# Out:
# 100

# %%
all_lines['speaker'] = all_lines['speaker'].str.split(',')
all_lines = all_lines.explode('speaker')
all_lines = all_lines.reset_index(drop=True)
all_lines
# Out:
#                     episode  \
# 0        15 Minutes of Fame
# 1        15 Minutes of Fame
# 2        15 Minutes of Fame
# 3        15 Minutes of Fame
# 4        15 Minutes of Fame
# ...                     ...
# 21049  You Snooze, You Lose
# 21050  You Snooze, You Lose
# 21051  You Snooze, You Lose
# 21052  You Snooze, You Lose
# 21053  You Snooze, You Lose
#
#                                                   dialog    speaker
# 0      And over here is our newest acquisition to the...     angela
# 1            Bubbles, you can calm down now. You did it!    blossom
# 2                              Yeah, dude! Check it out!  buttercup
# 3                                                   Meow        cat
# 4      That's right, cats can always get up a tree......    blossom
# ...                                                  ...        ...
# 21049  But it is I who planned it! I did it, not them...       mojo
# 21050        Iam responsible for trying to destroy you!        mojo
# 21051                          Okay. Thenyougo to jail.     blossom
# 21052                                      That's right!       mojo
# 21053  So once again the day is saved-thanks to the P...   narrator
#
# [21054 rows x 3 columns]

# %%
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'blossom' if x in blossom_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'bubbles' if x in bubbles_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'buttercup' if x in buttercup_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'professor' if x in professor_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'mayor' if x in mayor_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'mojo jojo' if x in mojo_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'narrator' if x in narrator_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'him' if x in him_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'princess morbucks' if x in princess_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'fuzzy' if x in fuzzy_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'woman' if x in woman_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'man' if x in man_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'brick' if x in brick_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'bliss' if x in bliss_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'monster' if x in monster_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'boy' if x in boy_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'girl' if x in girl_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'powerpuff girls' if x in ppg_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'rowdyruff boys' if x in rrb_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'sapna' if x in sapna_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'miyako' if x in miyako_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'kaoru' if x in kaoru_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'announcer' if x in announcer_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'ms. keane' if x in keane_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'ms. bellum' if x in bellum_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'billy' if x in billy_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'butch' if x in butch_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'boomer' if x in boomer_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'talking dog' if x in talking_dog_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'junior' if x in junior_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'bossman' if x in bossman_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'marianne' if x in marianne_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'harold' if x in harold_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'sedusa' if x in sedusa_values else x)

# %%
unique_speakers = all_lines['speaker'].unique()

for speaker in unique_speakers:
    if isinstance(speaker, str) and "femme" in speaker:
        print(speaker)
# Out:
# femme fatale

# %%
all_lines['speaker'].value_counts().head(60)
# Out:
# blossom              3997
# buttercup            3211
# bubbles              2890
# professor            1682
# narrator              966
# mojo jojo             834
# mayor                 726
# powerpuff girls       436
# ms. keane             370
# princess morbucks     361
# him                   246
# man                   237
# woman                 174
# ms. bellum            173
# brick                 165
# bliss                 108
# ace                   103
# announcer              85
# boy                    82
# sedusa                 77
# girl                   73
# bossman                68
# talking dog            67
# monster                65
# billy                  64
# barry                  63
# dick                   62
# fuzzy                  61
# bernie                 60
# maylyn                 60
# marianne               53
# boomer                 50
# butch                  50
# sapna                  50
# robin                  46
# brian                  46
# major glory            45
# mitch                  42
# donny                  41
# whitfield              39
# crowd                  38
# harold                 38
# jemmica                37
# bianca                 37
# steve                  35
# silico                 34
# thief                  32
# erica                  30
# slim                   28
# kids                   27
# teacher                27
# captain                26
# snake                  25
# lenny                  25
# femme fatale           23
# mr. green              23
# mary                   23
# mike                   23
# jared                  23
# 253                    23
# Name: speaker, dtype: int64

# %%
# Identify episodes with only 1 line, probably we need to filter them out
all_lines['episode'].value_counts()
# Out:
# Criss Cross Crisis                            281
# Superfriends                                  240
# Power-Noia                                    227
# Members Only                                  225
# Film Flam                                     222
#                                              ...
# Man Up 3: The Good, the Bad, and the Manly      1
# The Buttercup Job                               1
# Horn, Sweet Horn                                1
# The Oct-Father                                  1
# The Fog                                         1
# Name: episode, Length: 236, dtype: int64

# %%
import numpy as np

# Create a villain column
conditions = [
    all_lines['speaker'] == 'mojo jojo',
    all_lines['speaker'] == 'him',
    all_lines['speaker'] == 'talking dog',
    all_lines['speaker'] == 'sedusa',
    all_lines['speaker'] == 'princess morbucks',
    all_lines['speaker'] == 'dick',
    all_lines['speaker'] == 'bernie',
    all_lines['speaker'] == 'sandman',
    all_lines['speaker'] == 'lenny',
    all_lines['speaker'] == 'femme fatale',
    all_lines['speaker'] == 'gnome',
    all_lines['speaker'] == 'fuzzy',
    all_lines['speaker'].isin(['brick', 'boomer', 'butch']), 
    all_lines['speaker'].isin(['ace', 'grubber', 'billy', 'snake']),
    all_lines['speaker'].isin(['bossman', 'junior', 'slim']),
    all_lines['speaker'].isin(['marianne', 'harold', 'julie', 'bud']),
]
values = [
    'mojo jojo', 
    'him',
    'talking dog',
    'sedusa',
    'princess morbucks',
    'dick',
    'bernie',
    'sandman',
    'lenny',
    'femme fatale',
    'gnome',
    'fuzzy',
    'gangreen gang',
    'rowdyruff boys',
    'amoeba boys',
    'smith family'
]

# Use numpy's where function to create the new column
all_lines['villain'] = np.select(conditions, values, default=None)
all_lines['villain'].head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: villain, dtype: object

# %%
all_lines['villain'].value_counts()
# Out:
# mojo jojo            834
# princess morbucks    361
# gangreen gang        265
# him                  246
# rowdyruff boys       200
# amoeba boys          116
# smith family         105
# sedusa                77
# talking dog           67
# dick                  62
# fuzzy                 61
# bernie                60
# lenny                 25
# femme fatale          23
# sandman               14
# gnome                  7
# Name: villain, dtype: int64

# %%
seasons_1998_raw = pd.read_json('./ppg-seasons-1998.json', encoding='utf-8')
seasons_2016_raw = pd.read_json('./ppg-seasons-2016.json', encoding='utf-8')

seasons_2016_raw.head()
# Out:
#    year  season  episode_nr                       title  \
# 0  2016       1           1  Escape from Monster Island
# 1  2016       1           2          Princess Buttercup
# 2  2016       1           3                The Stayover
# 3  2016       1           4                     Painbow
# 4  2016       1           5            Horn, Sweet Horn
#
#                                          description
# 0  While Bubbles tries to decide whether to take ...
# 1  Buttercup starts hanging out with a bad crowd,...
# 2  Recovering from a candy hangover, Blossom and ...
# 3  A rainbow makes everyone in Townsville unnatur...
# 4  At Bubbles' request, the Professor tries to ma...

# %%
seasons_raw = pd.concat([seasons_1998_raw, seasons_2016_raw])
seasons_raw.head(10)
# Out:
#    year  season  episode_nr                                title  \
# 0  1998       1           0                  A Sticky Situation!
# 1  1998       1           1  Monkey See, Doggie Do/Mommy Fearest
# 2  1998       1           2        Insect Inside/Powerpuff Bluff
# 3  1998       1           3               Octi Evil/Geshundfight
# 4  1998       1           4              Buttercrush/Fuzzy Logic
# 5  1998       1           5           Boogie Frights/Abracadaver
# 6  1998       1           6               Telephonies/Tough Love
# 7  1998       1           7  Major Competition/Mr. Mojo's Rising
# 8  1998       1           8           Paste Makes Waste/Ice Sore
# 9  1998       1           9         Bubblevicious/The Bare Facts
#
#                                          description
# 0  Begins with the same opening sequence as the s...
# 1  In "Monkey See, Doggie Do", Mojo Jojo swipes s...
# 2  "Insect Inside" The city of Townsville becomes...
# 3  "Octi-Evil" Him is out to break up the Powerpu...
# 4  "Buttercrush" Buttercup develops a crush on Ac...
# 5  In "Boogie Frights", the Boogie Man comes up w...
# 6  "Telephonies" The Gangreen Gang gets hold of t...
# 7  "Major Competition" The Powerpuff Girl's place...
# 8  In "Paste Makes Waste", one of the Pokey Oaks ...
# 9  Bubbles is tired of being the cute and wants t...

# %%
seasons_raw['title'].head(50)
# Out:
# 0                                   A Sticky Situation!
# 1                   Monkey See, Doggie Do/Mommy Fearest
# 2                         Insect Inside/Powerpuff Bluff
# 3                                Octi Evil/Geshundfight
# 4                               Buttercrush/Fuzzy Logic
# 5                            Boogie Frights/Abracadaver
# 6                                Telephonies/Tough Love
# 7                   Major Competition/Mr. Mojo's Rising
# 8                            Paste Makes Waste/Ice Sore
# 9                          Bubblevicious/The Bare Facts
# 10                              Cat Man Do/Impeach Fuzz
# 11            Just Another Manic Mojo/Mime for a Change
# 12                                   The Rowdyruff Boys
# 13                                         Uh Oh Dynamo
# 14            Stuck Up, Up, and Away/Schoolhouse Rocked
# 15                           Collect Her/Supper Villain
# 16                     Birthday Bash/Too Pooped to Puff
# 17                       Beat Your Greens/Down 'n Dirty
# 18                    Dream Scheme/You Snooze, You Lose
# 19                          Slave the Day/Los Dos Mojos
# 20              A Very Special Blossom/Daylight Savings
# 21                                      Mo Job/Pet Feud
# 22                          Imaginary Fiend/Cootie Gras
# 23    The Powerpuff Girls' Best Rainy Day Adventure ...
# 24                              Twisted Sister/Cover Up
# 25                             Speed Demon/Mojo Jonesin
# 26          Something's a Ms./Slumbering with the Enemy
# 27                         Fallen Arches/The Mane Event
# 28                           Town and Out/Child Fearing
# 29                                   Criss Cross Crisis
# 30                        Bubblevision/Bought and Scold
# 31                       Gettin' Twiggy with It/Cop Out
# 32     Three Girls and a Monster/Monkey See, Doggie Two
# 33                      Jewel of the Aisle/Super Zeroes
# 34                           Candy Is Dandy/Catastrophe
# 35                          Hot Air Buffoon/Ploys R' Us
# 36                    The Headsuckers Moxy/Equal Fights
# 37                                           Powerprof.
# 38                       Moral Decay/Meet the Beat-Alls
# 39                           Helter Shelter/Power Lunch
# 40                                            Film Flam
# 41                                       All Chalked Up
# 42                                       Get Back, Jojo
# 43                                    Him Diddle Riddle
# 44                                         Members Only
# 45                                         Knock It Off
# 46                                         Superfriends
# 47                                    Nano of the North
# 48                                         Stray Bullet
# 49                                           Forced Kin
# Name: title, dtype: object

# %%
seasons = seasons_raw.copy()

seasons['title'] = seasons['title'].str.lower()
seasons['title'] = seasons['title'].str.split('/')
seasons['title_1'] = seasons['title'].str[0]
seasons['title_2'] = seasons['title'].str[1]
all_lines['episode'] = all_lines['episode'].str.lower()
seasons.head(10)
# Out:
#    year  season  episode_nr                                   title  \
# 0  1998       1           0                   [a sticky situation!]
# 1  1998       1           1  [monkey see, doggie do, mommy fearest]
# 2  1998       1           2        [insect inside, powerpuff bluff]
# 3  1998       1           3               [octi evil, geshundfight]
# 4  1998       1           4              [buttercrush, fuzzy logic]
# 5  1998       1           5           [boogie frights, abracadaver]
# 6  1998       1           6               [telephonies, tough love]
# 7  1998       1           7  [major competition, mr. mojo's rising]
# 8  1998       1           8           [paste makes waste, ice sore]
# 9  1998       1           9         [bubblevicious, the bare facts]
#
#                                          description                title_1  \
# 0  Begins with the same opening sequence as the s...    a sticky situation!
# 1  In "Monkey See, Doggie Do", Mojo Jojo swipes s...  monkey see, doggie do
# 2  "Insect Inside" The city of Townsville becomes...          insect inside
# 3  "Octi-Evil" Him is out to break up the Powerpu...              octi evil
# 4  "Buttercrush" Buttercup develops a crush on Ac...            buttercrush
# 5  In "Boogie Frights", the Boogie Man comes up w...         boogie frights
# 6  "Telephonies" The Gangreen Gang gets hold of t...            telephonies
# 7  "Major Competition" The Powerpuff Girl's place...      major competition
# 8  In "Paste Makes Waste", one of the Pokey Oaks ...      paste makes waste
# 9  Bubbles is tired of being the cute and wants t...          bubblevicious
#
#              title_2
# 0                NaN
# 1      mommy fearest
# 2    powerpuff bluff
# 3       geshundfight
# 4        fuzzy logic
# 5        abracadaver
# 6         tough love
# 7  mr. mojo's rising
# 8           ice sore
# 9     the bare facts

# %%
lines_with_seasons = pd.merge(all_lines, seasons, how='left', left_on='episode', right_on='title_1')
lines_with_seasons = pd.merge(lines_with_seasons, seasons, how='left', left_on='episode', right_on='title_2')

# %%
lines_with_seasons.head()
# Out:
#               episode                                             dialog  \
# 0  15 minutes of fame  And over here is our newest acquisition to the...
# 1  15 minutes of fame        Bubbles, you can calm down now. You did it!
# 2  15 minutes of fame                          Yeah, dude! Check it out!
# 3  15 minutes of fame                                               Meow
# 4  15 minutes of fame  That's right, cats can always get up a tree......
#
#      speaker villain  year_x  season_x  episode_nr_x               title_x  \
# 0     angela    None  2016.0       2.0           3.0  [15 minutes of fame]
# 1    blossom    None  2016.0       2.0           3.0  [15 minutes of fame]
# 2  buttercup    None  2016.0       2.0           3.0  [15 minutes of fame]
# 3        cat    None  2016.0       2.0           3.0  [15 minutes of fame]
# 4    blossom    None  2016.0       2.0           3.0  [15 minutes of fame]
#
#                                        description_x           title_1_x  \
# 0  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 1  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 2  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 3  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 4  Green Wing: When volunteering at a retirement ...  15 minutes of fame
#
#   title_2_x  year_y  season_y  episode_nr_y title_y description_y title_1_y  \
# 0       NaN     NaN       NaN           NaN     NaN           NaN       NaN
# 1       NaN     NaN       NaN           NaN     NaN           NaN       NaN
# 2       NaN     NaN       NaN           NaN     NaN           NaN       NaN
# 3       NaN     NaN       NaN           NaN     NaN           NaN       NaN
# 4       NaN     NaN       NaN           NaN     NaN           NaN       NaN
#
#   title_2_y
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
lines_with_seasons.groupby(['season_y'])['episode'].nunique()
# Out:
# season_y
# 1.0     7
# 2.0    13
# 3.0    11
# 4.0     1
# 5.0    10
# 6.0    12
# Name: episode, dtype: int64

# %%
lines_with_seasons.groupby(['season_x'])['episode'].nunique()
# Out:
# season_x
# 1.0    48
# 2.0    46
# 3.0    48
# 4.0    12
# 5.0    12
# 6.0    15
# Name: episode, dtype: int64

# %%
lines_with_seasons.columns
# Out:
# Index(['episode', 'dialog', 'speaker', 'villain', 'year_x', 'season_x',
#        'episode_nr_x', 'title_x', 'description_x', 'title_1_x', 'title_2_x',
#        'year_y', 'season_y', 'episode_nr_y', 'title_y', 'description_y',
#        'title_1_y', 'title_2_y'],
#       dtype='object')

# %%
lines_with_seasons['season'] = np.where(lines_with_seasons['season_x'].notna(), lines_with_seasons['season_x'], lines_with_seasons['season_y'])
lines_with_seasons['episode_nr'] = np.where(lines_with_seasons['episode_nr_x'].notna(), lines_with_seasons['episode_nr_x'], lines_with_seasons['episode_nr_y'])
lines_with_seasons['description'] = np.where(lines_with_seasons['description_x'].notna(), lines_with_seasons['description_x'], lines_with_seasons['description_y'])
lines_with_seasons['title_1'] = np.where(lines_with_seasons['title_1_x'].notna(), lines_with_seasons['title_1_x'], lines_with_seasons['title_1_y'])
lines_with_seasons['title_2'] = np.where(lines_with_seasons['title_2_x'].notna(), lines_with_seasons['title_2_x'], lines_with_seasons['title_2_y'])
lines_with_seasons['year'] = np.where(lines_with_seasons['year_x'].notna(), lines_with_seasons['year_x'], lines_with_seasons['year_y'])
lines_with_seasons['season'].value_counts()
# Out:
# 2.0    4877
# 3.0    4525
# 1.0    4370
# 4.0    2471
# 5.0    2407
# 6.0    2404
# Name: season, dtype: int64

# %%
lines_with_seasons['season'].isna().sum()
# Out:
# 0

# %%
lines_with_seasons.drop(columns=[
    'season_x', 'episode_nr_x',
       'title_x', 'description_x', 'title_1_x', 'title_2_x', 'season_y',
       'episode_nr_y', 'title_y', 'description_y', 'title_1_y', 'title_2_y', 'year_x', 'year_y' 
], inplace=True)

# %%
lines_with_seasons['episode_nr'] = np.where(lines_with_seasons['title_2'] == lines_with_seasons['episode'], lines_with_seasons['episode_nr'] + 0.2, lines_with_seasons['episode_nr'])
lines_with_seasons['episode_nr'] = np.where((lines_with_seasons['title_1'] == lines_with_seasons['episode']) & (lines_with_seasons['title_2'].notna()), lines_with_seasons['episode_nr'] + 0.1, lines_with_seasons['episode_nr'])

# %%
lines_with_seasons[lines_with_seasons['season'].isna()]['episode'].unique()
# Out:
# array([], dtype=object)

# %%
# NB They are all 2016, so for now I'm not too worried
lines_with_seasons[lines_with_seasons['dialog'].isna()]
# Out:
#                                 episode dialog speaker villain  season  \
# 2564                    bye bye, bellum   None     NaN    None     1.0
# 2947                      cheep thrills   None     NaN    None     1.0
# 6975                   horn, sweet horn   None     NaN    None     1.0
# 11383                       night mayor   None     NaN    None     6.0
# 12096            once upon a townsville   None     NaN    None     1.0
# 15351                      sideline dad   None     NaN    None     3.0
# 15352                  silent treatment   None     NaN    None     5.0
# 15764  small world: heart to heartstone   None     NaN    None     3.0
# 16597                      strong-armed   None     NaN    None     1.0
# 17753       take your kids to dooms day   None     NaN    None     2.0
# 18026                     the big sleep   None     NaN    None     1.0
# 18486                           the fog   None     NaN    None     3.0
# 19222                   the squashening   None     NaN    None     1.0
# 19223                      the stayover   None     NaN    None     1.0
# 20093         total eclipse of the kart   None     NaN    None     3.0
#
#        episode_nr                                        description  \
# 2564          7.0  The girls are overworked helping the Mayor whe...
# 2947         24.0  Cheep Thrills: After finding a baby monster in...
# 6975          5.0  At Bubbles' request, the Professor tries to ma...
# 11383         6.2  "Little Miss Interprets" When the Girls hear t...
# 12096        17.0  Chased by a dragon, Princess Bluebell accident...
# 15351        36.0  When the Girls start playing soccer, the Profe...
# 15352        14.1  The girls are pulled into a silent movie by an...
# 15764        16.0  The Powerpuff Girls are sent to the arctic on ...
# 16597         9.0  Bubbles wears a robotic cast for her broken ar...
# 17753        12.0  The Girls spend the day with the Professor at ...
# 18026        28.0  The Big Sleep: When the Professor's latest inv...
# 18486        23.0  A new villain arrives in Townsville and gives ...
# 19222        33.0  Rainy Day: The girls get into trouble when lef...
# 19223         3.0  Recovering from a candy hangover, Blossom and ...
# 20093        11.0  The Powerpuff Girls compete in a race against ...
#
#                                 title_1        title_2    year
# 2564                    bye bye, bellum            NaN  2016.0
# 2947                      cheep thrills            NaN  2016.0
# 6975                   horn, sweet horn            NaN  2016.0
# 11383            little miss interprets    night mayor  1998.0
# 12096            once upon a townsville            NaN  2016.0
# 15351                      sideline dad            NaN  2016.0
# 15352                  silent treatment  sweet 'n sour  1998.0
# 15764  small world: heart to heartstone            NaN  2016.0
# 16597                      strong-armed            NaN  2016.0
# 17753       take your kids to dooms day            NaN  2016.0
# 18026                     the big sleep            NaN  2016.0
# 18486                           the fog            NaN  2016.0
# 19222                   the squashening            NaN  2016.0
# 19223                      the stayover            NaN  2016.0
# 20093         total eclipse of the kart            NaN  2016.0

# %%
lines_with_seasons.dropna(subset=['dialog'], inplace=True)

# %%
lines_with_seasons[lines_with_seasons['dialog'].isna()]
# Out:
# Empty DataFrame
# Columns: [episode, dialog, speaker, villain, season, episode_nr, description, title_1, title_2, year]
# Index: []

# %%
lines_with_seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21039 entries, 0 to 21053
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   episode      21039 non-null  object
#  1   dialog       21039 non-null  object
#  2   speaker      20877 non-null  object
#  3   villain      2523 non-null   object
#  4   season       21039 non-null  float64
#  5   episode_nr   21039 non-null  float64
#  6   description  21039 non-null  object
#  7   title_1      21039 non-null  object
#  8   title_2      11008 non-null  object
#  9   year         21039 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 1.8+ MB

# %%
lines_with_seasons.head()
# Out:
#               episode                                             dialog  \
# 0  15 minutes of fame  And over here is our newest acquisition to the...
# 1  15 minutes of fame        Bubbles, you can calm down now. You did it!
# 2  15 minutes of fame                          Yeah, dude! Check it out!
# 3  15 minutes of fame                                               Meow
# 4  15 minutes of fame  That's right, cats can always get up a tree......
#
#      speaker villain  season  episode_nr  \
# 0     angela    None     2.0         3.0
# 1    blossom    None     2.0         3.0
# 2  buttercup    None     2.0         3.0
# 3        cat    None     2.0         3.0
# 4    blossom    None     2.0         3.0
#
#                                          description             title_1  \
# 0  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 1  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 2  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 3  Green Wing: When volunteering at a retirement ...  15 minutes of fame
# 4  Green Wing: When volunteering at a retirement ...  15 minutes of fame
#
#   title_2    year
# 0     NaN  2016.0
# 1     NaN  2016.0
# 2     NaN  2016.0
# 3     NaN  2016.0
# 4     NaN  2016.0

# %%
# Fill all lines without a speaker with the speaker before. CHECK!!
no_speakers = lines_with_seasons[lines_with_seasons['speaker'].isna()]
no_speakers.head()
# Out:
#            episode                                             dialog speaker  \
# 3514       cop out                          Back to you there, Kevin.     NaN
# 4769  dream scheme            It is the setting of this little story.     NaN
# 4771  dream scheme           Where people are dressed in PJ and robe.     NaN
# 4772  dream scheme  They kick off their slippers and climb into beds,     NaN
# 4773  dream scheme   Fluff up their pillows and lay down their heads.     NaN
#
#      villain  season  episode_nr  \
# 3514    None     3.0         5.2
# 4769    None     2.0         5.1
# 4771    None     2.0         5.1
# 4772    None     2.0         5.1
# 4773    None     2.0         5.1
#
#                                             description  \
# 3514  "Gettin' Twiggy With It" Mitch is told to take...
# 4769  "Dream Scheme" The Sandman would like a little...
# 4771  "Dream Scheme" The Sandman would like a little...
# 4772  "Dream Scheme" The Sandman would like a little...
# 4773  "Dream Scheme" The Sandman would like a little...
#
#                      title_1               title_2    year
# 3514  gettin' twiggy with it               cop out  1998.0
# 4769            dream scheme  you snooze, you lose  1998.0
# 4771            dream scheme  you snooze, you lose  1998.0
# 4772            dream scheme  you snooze, you lose  1998.0
# 4773            dream scheme  you snooze, you lose  1998.0

# %%
no_speakers.count()
# Out:
# episode        162
# dialog         162
# speaker          0
# villain          0
# season         162
# episode_nr     162
# description    162
# title_1        162
# title_2        125
# year           162
# dtype: int64

# %%
lines_with_seasons['speaker'].fillna(method='ffill', inplace=True)

# %%
lines_with_seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21039 entries, 0 to 21053
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   episode      21039 non-null  object
#  1   dialog       21039 non-null  object
#  2   speaker      21039 non-null  object
#  3   villain      2523 non-null   object
#  4   season       21039 non-null  float64
#  5   episode_nr   21039 non-null  float64
#  6   description  21039 non-null  object
#  7   title_1      21039 non-null  object
#  8   title_2      11008 non-null  object
#  9   year         21039 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 1.8+ MB

# %%
previous_no_speakers = lines_with_seasons[lines_with_seasons.index.isin(no_speakers.index)]
previous_no_speakers.count()
# Out:
# episode        162
# dialog         162
# speaker        162
# villain          0
# season         162
# episode_nr     162
# description    162
# title_1        162
# title_2        125
# year           162
# dtype: int64

# %%
previous_no_speakers.iloc[:10, :]
# Out:
#            episode                                             dialog  \
# 3514       cop out                          Back to you there, Kevin.
# 4769  dream scheme            It is the setting of this little story.
# 4771  dream scheme           Where people are dressed in PJ and robe.
# 4772  dream scheme  They kick off their slippers and climb into beds,
# 4773  dream scheme   Fluff up their pillows and lay down their heads.
# 4775  dream scheme             Enter the Sandman to do them up right.
# 4777  dream scheme        He pulls out a magical brown grain of sand.
# 4779  dream scheme     And out goes the victim, asleep for the night.
# 4781  dream scheme       The Sandman does his job, singing his ditty.
# 4783  dream scheme            Putting you to sleep is what I'm about.
#
#               speaker villain  season  episode_nr  \
# 3514  female reporter    None     3.0         5.2
# 4769         narrator    None     2.0         5.1
# 4771         narrator    None     2.0         5.1
# 4772         narrator    None     2.0         5.1
# 4773         narrator    None     2.0         5.1
# 4775         narrator    None     2.0         5.1
# 4777         narrator    None     2.0         5.1
# 4779         narrator    None     2.0         5.1
# 4781         narrator    None     2.0         5.1
# 4783          sandman    None     2.0         5.1
#
#                                             description  \
# 3514  "Gettin' Twiggy With It" Mitch is told to take...
# 4769  "Dream Scheme" The Sandman would like a little...
# 4771  "Dream Scheme" The Sandman would like a little...
# 4772  "Dream Scheme" The Sandman would like a little...
# 4773  "Dream Scheme" The Sandman would like a little...
# 4775  "Dream Scheme" The Sandman would like a little...
# 4777  "Dream Scheme" The Sandman would like a little...
# 4779  "Dream Scheme" The Sandman would like a little...
# 4781  "Dream Scheme" The Sandman would like a little...
# 4783  "Dream Scheme" The Sandman would like a little...
#
#                      title_1               title_2    year
# 3514  gettin' twiggy with it               cop out  1998.0
# 4769            dream scheme  you snooze, you lose  1998.0
# 4771            dream scheme  you snooze, you lose  1998.0
# 4772            dream scheme  you snooze, you lose  1998.0
# 4773            dream scheme  you snooze, you lose  1998.0
# 4775            dream scheme  you snooze, you lose  1998.0
# 4777            dream scheme  you snooze, you lose  1998.0
# 4779            dream scheme  you snooze, you lose  1998.0
# 4781            dream scheme  you snooze, you lose  1998.0
# 4783            dream scheme  you snooze, you lose  1998.0

# %%
lines_with_seasons['word_count_for_line'] = lines_with_seasons['dialog'].str.split(' ')
lines_with_seasons['word_count_for_line'] = lines_with_seasons['word_count_for_line'].apply(len)
lines_with_seasons[['dialog', 'word_count_for_line']].head(15)
# Out:
#                                                dialog  word_count_for_line
# 0   And over here is our newest acquisition to the...                   49
# 1         Bubbles, you can calm down now. You did it!                    9
# 2                           Yeah, dude! Check it out!                    5
# 3                                                Meow                    1
# 4   That's right, cats can always get up a tree......                   15
# 5                                         Meow, Meow.                    2
# 6   The city of Townsville. This is where the Powe...                   11
# 7   Oh, you might know them as those three cute li...                  121
# 8   I'm Brian, and this is my documentary. And you...                   31
# 9              Sugar... spice... and everything nice.                    5
# 10  Yep, those are pretty normal ingredients, all ...                   34
# 11  The city of Townsville. A great city with many...                   31
# 12  The newly renovated and revitalized Old Townsv...                   24
# 13  Although this bus looks better than that corpo...                   22
# 14  There are other reminders and countless monume...                   15

# %%
lines_1998 = lines_with_seasons[lines_with_seasons['year'] == 1998]

summed_speakers_1998 = lines_1998.groupby('speaker')['word_count_for_line'].sum().reset_index()
summed_speakers_1998 = summed_speakers_1998.sort_values('word_count_for_line', ascending=False).reset_index(drop=True)
summed_speakers_1998.head(50)
# Out:
#               speaker  word_count_for_line
# 0             blossom                18626
# 1           professor                13171
# 2           buttercup                11452
# 3            narrator                11423
# 4             bubbles                11101
# 5           mojo jojo                 9180
# 6               mayor                 6673
# 7           ms. keane                 2992
# 8   princess morbucks                 2861
# 9                 him                 2334
# 10         ms. bellum                 1521
# 11              brick                 1379
# 12                man                 1350
# 13    powerpuff girls                 1292
# 14              brian                 1041
# 15             bernie                  915
# 16              woman                  897
# 17                ace                  824
# 18             sedusa                  817
# 19               dick                  802
# 20        talking dog                  793
# 21          whitfield                  680
# 22        major glory                  630
# 23          announcer                  624
# 24           marianne                  507
# 25            bossman                  473
# 26              fuzzy                  446
# 27            monster                  437
# 28             harold                  373
# 29              gnome                  362
# 30       femme fatale                  350
# 31              billy                  329
# 32          mr. green                  324
# 33              thief                  311
# 34            sandman                  302
# 35              robin                  285
# 36              lenny                  268
# 37              mitch                  258
# 38                boy                  255
# 39                253                  251
# 40              butch                  244
# 41               girl                  243
# 42            burglar                  240
# 43            teacher                  232
# 44           reporter                  228
# 45             boomer                  210
# 46            captain                  197
# 47          wednesday                  184
# 48              agent                  179
# 49              maria                  178

# %%
lines_2016 = lines_with_seasons[lines_with_seasons['year'] == 2016]

summed_speakers_2016 = lines_2016.groupby('speaker')['word_count_for_line'].sum().reset_index()
summed_speakers_2016.sort_values('word_count_for_line', ascending=False).head(50).reset_index(drop=True)
# Out:
#               speaker  word_count_for_line
# 0             blossom                12830
# 1           buttercup                12047
# 2             bubbles                10564
# 3           professor                 4322
# 4   princess morbucks                 1865
# 5               bliss                 1082
# 6               mayor                  832
# 7           mojo jojo                  795
# 8                 man                  753
# 9               sapna                  667
# 10             maylyn                  663
# 11          ms. keane                  586
# 12              woman                  498
# 13              barry                  480
# 14             bianca                  451
# 15          announcer                  448
# 16              donny                  399
# 17            jemmica                  393
# 18             silico                  369
# 19              erica                  369
# 20                him                  350
# 21          miss moss                  344
# 22                boy                  324
# 23             paulie                  315
# 24        deb o' nair                  252
# 25               girl                  246
# 26              steve                  220
# 27              jared                  218
# 28        schedulebot                  216
# 29            allegro                  192
# 30         salamander                  184
# 31          duplikate                  182
# 32             lester                  173
# 33               gnat                  164
# 34   pug faced paulie                  161
# 35            bossman                  150
# 36           narrator                  146
# 37      javier xavier                  146
# 38              malty                  142
# 39          earthplow                  140
# 40            doubles                  135
# 41              video                  127
# 42            chelsea                  125
# 43            swapper                  122
# 44    powerpuff girls                  120
# 45               joey                  112
# 46           the gnat                  110
# 47      rubber bandit                  109
# 48              largo                  108
# 49         eyesoceles                  108

# %%
summed_villains = lines_1998.groupby('villain')['word_count_for_line'].sum().reset_index()
summed_villains = summed_villains.sort_values('word_count_for_line', ascending=False).reset_index(drop=True)
summed_villains.head(50)
# Out:
#               villain  word_count_for_line
# 0           mojo jojo                 9180
# 1   princess morbucks                 2861
# 2                 him                 2334
# 3       gangreen gang                 1833
# 4      rowdyruff boys                 1348
# 5        smith family                  970
# 6              bernie                  915
# 7              sedusa                  817
# 8                dick                  802
# 9         talking dog                  793
# 10        amoeba boys                  652
# 11              fuzzy                  446
# 12       femme fatale                  350
# 13              gnome                  348
# 14              lenny                  268
# 15            sandman                  109

# %%
lines_with_seasons['villain'].value_counts().head(50)
# Out:
# mojo jojo            834
# princess morbucks    361
# gangreen gang        265
# him                  246
# rowdyruff boys       200
# amoeba boys          116
# smith family         105
# sedusa                77
# talking dog           67
# dick                  62
# fuzzy                 61
# bernie                60
# lenny                 25
# femme fatale          23
# sandman               14
# gnome                  7
# Name: villain, dtype: int64

# %%
# Good: First 8 good guys (the lower range tend either to be one-epsiode characters, or an (unrelated) aggregate)
good_aggregate_1998 = summed_speakers_1998.loc[:10, :]
good_aggregate_1998
# Out:
#               speaker  word_count_for_line
# 0             blossom                18626
# 1           professor                13171
# 2           buttercup                11452
# 3            narrator                11423
# 4             bubbles                11101
# 5           mojo jojo                 9180
# 6               mayor                 6673
# 7           ms. keane                 2992
# 8   princess morbucks                 2861
# 9                 him                 2334
# 10         ms. bellum                 1521

# %%
# All villains that are in top 50 most speaking people that are not an (unrelated) aggregate
villains_aggregate_1998 = summed_villains

# %%
good_aggregate_1998.to_json('./good_all.json', orient='records')
villains_aggregate_1998.to_json('./villains_all.json', orient='records')

# %%
good_aggregate_seasons_1998 = lines_1998.groupby(['speaker', 'season'])['word_count_for_line'].sum().reset_index()
good_aggregate_seasons_1998 = good_aggregate_seasons_1998.sort_values(['season', 'word_count_for_line'], ascending=[True, False]).reset_index(drop=True)
good_aggregate_seasons_1998 = good_aggregate_seasons_1998[
    (good_aggregate_seasons_1998['speaker'].isin([
        "blossom",
        "professor",
        "buttercup",
        "narrator",
        "bubbles",
        "mayor",
        "ms. keane",
        "ms. bellum"
    ])) | (good_aggregate_seasons_1998['word_count_for_line'] > 250)
]
good_aggregate_seasons_1998.head(50)
# Out:
#                speaker  season  word_count_for_line
# 0              blossom     1.0                 2112
# 1            mojo jojo     1.0                 2088
# 2             narrator     1.0                 1778
# 3              bubbles     1.0                 1772
# 4            buttercup     1.0                 1365
# 5                mayor     1.0                 1292
# 6            professor     1.0                 1271
# 7           ms. bellum     1.0                  336
# 8               sedusa     1.0                  325
# 9                  253     1.0                  251
# 10           ms. keane     1.0                  250
# 92             blossom     2.0                 3554
# 93            narrator     2.0                 3027
# 94           buttercup     2.0                 2134
# 95             bubbles     2.0                 1891
# 96           professor     2.0                 1849
# 97           mojo jojo     2.0                 1524
# 98           ms. keane     2.0                 1222
# 99               mayor     2.0                 1013
# 100  princess morbucks     2.0                  905
# 101           marianne     2.0                  507
# 102         ms. bellum     2.0                  421
# 103             harold     2.0                  373
# 104                man     2.0                  335
# 105          whitfield     2.0                  334
# 106            sandman     2.0                  302
# 107                ace     2.0                  298
# 108    powerpuff girls     2.0                  294
# 109              billy     2.0                  288
# 110              lenny     2.0                  268
# 200            blossom     3.0                 3683
# 201          professor     3.0                 2470
# 202          buttercup     3.0                 2096
# 203            bubbles     3.0                 1892
# 204              mayor     3.0                 1731
# 205          mojo jojo     3.0                 1675
# 206           narrator     3.0                 1537
# 207  princess morbucks     3.0                  687
# 208         ms. bellum     3.0                  465
# 209       femme fatale     3.0                  350
# 210          announcer     3.0                  315
# 211              woman     3.0                  280
# 212              brick     3.0                  275
# 213                man     3.0                  266
# 225          ms. keane     3.0                  126
# 304          professor     4.0                 3091
# 305            blossom     4.0                 3071
# 306            bubbles     4.0                 1698
# 307          buttercup     4.0                 1697
# 308          mojo jojo     4.0                 1489

# %%
villains_aggregate_seasons_1998 = lines_1998.groupby(['villain', 'season'])['word_count_for_line'].sum().reset_index()
villains_aggregate_seasons_1998 = villains_aggregate_seasons_1998.sort_values(['season', 'word_count_for_line'], ascending=[True, False]).reset_index(drop=True)
villains_aggregate_seasons_1998.head(50)
# Out:
#               villain  season  word_count_for_line
# 0           mojo jojo     1.0                 2088
# 1              sedusa     1.0                  325
# 2                 him     1.0                  181
# 3       gangreen gang     1.0                  134
# 4               fuzzy     1.0                  132
# 5         talking dog     1.0                   50
# 6        smith family     1.0                    6
# 7           mojo jojo     2.0                 1524
# 8        smith family     2.0                  944
# 9   princess morbucks     2.0                  905
# 10     rowdyruff boys     2.0                  653
# 11              lenny     2.0                  268
# 12        amoeba boys     2.0                  248
# 13                him     2.0                  196
# 14             sedusa     2.0                  146
# 15            sandman     2.0                  109
# 16        talking dog     2.0                    1
# 17          mojo jojo     3.0                 1675
# 18  princess morbucks     3.0                  687
# 19       femme fatale     3.0                  350
# 20      gangreen gang     3.0                  275
# 21     rowdyruff boys     3.0                  267
# 22                him     3.0                  152
# 23              fuzzy     3.0                  125
# 24          mojo jojo     4.0                 1489
# 25                him     4.0                 1016
# 26             bernie     4.0                  915
# 27               dick     4.0                  802
# 28  princess morbucks     4.0                  661
# 29        talking dog     4.0                   14
# 30        amoeba boys     4.0                   11
# 31     rowdyruff boys     4.0                    3
# 32      gangreen gang     5.0                 1321
# 33        talking dog     5.0                  683
# 34  princess morbucks     5.0                  608
# 35                him     5.0                  542
# 36          mojo jojo     5.0                  446
# 37              gnome     5.0                  348
# 38        amoeba boys     5.0                  343
# 39              fuzzy     5.0                  185
# 40     rowdyruff boys     5.0                  103
# 41       smith family     5.0                   20
# 42          mojo jojo     6.0                 1958
# 43             sedusa     6.0                  346
# 44     rowdyruff boys     6.0                  322
# 45                him     6.0                  247
# 46      gangreen gang     6.0                  103
# 47        amoeba boys     6.0                   50
# 48        talking dog     6.0                   45
# 49              fuzzy     6.0                    4

# %%
good_aggregate_seasons_1998.to_json('./good_seasons.json', orient='records')
villains_aggregate_seasons_1998.to_json('./villains_seasons.json', orient='records')

# %%
good_aggregate_episodes_1998 = lines_1998.groupby(['speaker', 'season', 'episode_nr', 'episode'])['word_count_for_line'].sum().reset_index()
good_aggregate_episodes_1998 = good_aggregate_episodes_1998.sort_values(['season', 'episode_nr', 'episode', 'word_count_for_line'], ascending=[True, True, True, False]).reset_index(drop=True)
good_aggregate_episodes_1998 = good_aggregate_episodes_1998[
    (good_aggregate_episodes_1998['speaker'].isin([
        "blossom",
        "professor",
        "buttercup",
        "narrator",
        "bubbles",
        "mayor",
        "ms. keane",
        "ms. bellum"
    ])) | (good_aggregate_episodes_1998['word_count_for_line'] > 100)
]
good_aggregate_episodes_1998.head(50)
# Out:
#          speaker  season  episode_nr                episode  \
# 0      mojo jojo     1.0         1.1  monkey see, doggie do
# 1       narrator     1.0         1.1  monkey see, doggie do
# 2        blossom     1.0         1.1  monkey see, doggie do
# 3      professor     1.0         1.1  monkey see, doggie do
# 9          mayor     1.0         1.1  monkey see, doggie do
# 11       bubbles     1.0         1.1  monkey see, doggie do
# 14        sedusa     1.0         1.2          mommy fearest
# 15     professor     1.0         1.2          mommy fearest
# 16      narrator     1.0         1.2          mommy fearest
# 17       blossom     1.0         1.2          mommy fearest
# 18       bubbles     1.0         1.2          mommy fearest
# 19     buttercup     1.0         1.2          mommy fearest
# 20         mayor     1.0         1.2          mommy fearest
# 26         mayor     1.0         2.2        powerpuff bluff
# 27           253     1.0         2.2        powerpuff bluff
# 28       blossom     1.0         2.2        powerpuff bluff
# 29    ms. bellum     1.0         2.2        powerpuff bluff
# 30      narrator     1.0         2.2        powerpuff bluff
# 32     buttercup     1.0         2.2        powerpuff bluff
# 35       bubbles     1.0         2.2        powerpuff bluff
# 44           him     1.0         3.1              octi evil
# 45          octi     1.0         3.1              octi evil
# 46       bubbles     1.0         3.1              octi evil
# 47      narrator     1.0         3.1              octi evil
# 48       blossom     1.0         3.1              octi evil
# 49     buttercup     1.0         3.1              octi evil
# 50     professor     1.0         3.1              octi evil
# 51         mayor     1.0         3.1              octi evil
# 52       blossom     1.0         7.1      major competition
# 53         mayor     1.0         7.1      major competition
# 54      narrator     1.0         7.1      major competition
# 55     major man     1.0         7.1      major competition
# 56   male chorus     1.0         7.1      major competition
# 58     buttercup     1.0         7.1      major competition
# 61       bubbles     1.0         7.1      major competition
# 62     professor     1.0         7.1      major competition
# 71     mojo jojo     1.0         7.2      mr. mojo's rising
# 72     professor     1.0         7.2      mr. mojo's rising
# 73      narrator     1.0         7.2      mr. mojo's rising
# 74       blossom     1.0         7.2      mr. mojo's rising
# 75       bubbles     1.0         7.2      mr. mojo's rising
# 76     buttercup     1.0         7.2      mr. mojo's rising
# 78     buttercup     1.0         8.1      paste makes waste
# 79     ms. keane     1.0         8.1      paste makes waste
# 80       blossom     1.0         8.1      paste makes waste
# 81      narrator     1.0         8.1      paste makes waste
# 84       bubbles     1.0         8.1      paste makes waste
# 102    buttercup     1.0         8.2               ice sore
# 103      blossom     1.0         8.2               ice sore
# 104    professor     1.0         8.2               ice sore
#
#      word_count_for_line
# 0                    292
# 1                    169
# 2                    139
# 3                     71
# 9                     11
# 11                     5
# 14                   325
# 15                   193
# 16                   160
# 17                   120
# 18                    74
# 19                    70
# 20                    47
# 26                   278
# 27                   251
# 28                   156
# 29                   126
# 30                   115
# 32                    65
# 35                    18
# 44                   181
# 45                   140
# 46                   138
# 47                   135
# 48                   134
# 49                    97
# 50                    31
# 51                    13
# 52                   164
# 53                   155
# 54                   127
# 55                   104
# 56                   102
# 58                    49
# 61                    28
# 62                    23
# 71                   431
# 72                   285
# 73                   121
# 74                    68
# 75                    51
# 76                    23
# 78                   194
# 79                   169
# 80                    91
# 81                    88
# 84                    26
# 102                  203
# 103                  181
# 104                  131

# %%
villains_aggregate_episodes_1998 = lines_1998.groupby(['villain', 'season', 'episode_nr', 'episode'])['word_count_for_line'].sum().reset_index()
villains_aggregate_episodes_1998 = villains_aggregate_episodes_1998.sort_values(['season', 'episode_nr', 'episode', 'word_count_for_line'], ascending=[True, True, True, False]).reset_index(drop=True)
villains_aggregate_episodes_1998.head(50)
# Out:
#               villain  season  episode_nr                    episode  \
# 0           mojo jojo     1.0         1.1      monkey see, doggie do
# 1              sedusa     1.0         1.2              mommy fearest
# 2                 him     1.0         3.1                  octi evil
# 3         talking dog     1.0         7.1          major competition
# 4           mojo jojo     1.0         7.2          mr. mojo's rising
# 5        smith family     1.0         8.1          paste makes waste
# 6           mojo jojo     1.0         9.1              bubblevicious
# 7         talking dog     1.0         9.1              bubblevicious
# 8           mojo jojo     1.0         9.2             the bare facts
# 9               fuzzy     1.0        10.2               impeach fuzz
# 10        talking dog     1.0        10.2               impeach fuzz
# 11          mojo jojo     1.0        11.1    just another manic mojo
# 12          mojo jojo     1.0        12.0         the rowdyruff boys
# 13      gangreen gang     1.0        12.0         the rowdyruff boys
# 14        talking dog     1.0        12.0         the rowdyruff boys
# 15        talking dog     1.0        13.0               uh oh dynamo
# 16  princess morbucks     2.0         1.1     stuck up, up, and away
# 17     rowdyruff boys     2.0         1.2         schoolhouse rocked
# 18              lenny     2.0         2.1                collect her
# 19       smith family     2.0         2.2             supper villain
# 20          mojo jojo     2.0         3.1              birthday bash
# 21        amoeba boys     2.0         3.1              birthday bash
# 22  princess morbucks     2.0         3.1              birthday bash
# 23                him     2.0         3.1              birthday bash
# 24            sandman     2.0         5.1               dream scheme
# 25          mojo jojo     2.0         5.2       you snooze, you lose
# 26        amoeba boys     2.0         5.2       you snooze, you lose
# 27     rowdyruff boys     2.0         6.1              slave the day
# 28          mojo jojo     2.0         6.2              los dos mojos
# 29        talking dog     2.0         6.2              los dos mojos
# 30          mojo jojo     2.0         7.1     a very special blossom
# 31  princess morbucks     2.0         8.1                     mo job
# 32          mojo jojo     2.0         8.1                     mo job
# 33          mojo jojo     2.0         9.2                cootie gras
# 34       smith family     2.0        10.2              just desserts
# 35                him     2.0        12.1                speed demon
# 36          mojo jojo     2.0        12.2               mojo jonesin
# 37             sedusa     2.0        13.1          something's a ms.
# 38          mojo jojo     2.0        13.2  slumbering with the enemy
# 39          mojo jojo     3.0         2.2              child fearing
# 40          mojo jojo     3.0         3.0         criss cross crisis
# 41     rowdyruff boys     3.0         3.0         criss cross crisis
# 42              fuzzy     3.0         3.0         criss cross crisis
# 43  princess morbucks     3.0         4.2           bought and scold
# 44      gangreen gang     3.0         5.2                    cop out
# 45          mojo jojo     3.0         6.2     monkey see, doggie two
# 46          mojo jojo     3.0         8.1             candy is dandy
# 47       femme fatale     3.0        10.2               equal fights
# 48          mojo jojo     3.0        11.0                 powerprof.
# 49          mojo jojo     3.0        12.1                moral decay
#
#     word_count_for_line
# 0                   292
# 1                   325
# 2                   181
# 3                     7
# 4                   431
# 5                     6
# 6                   113
# 7                    24
# 8                   103
# 9                   132
# 10                    5
# 11                  790
# 12                  359
# 13                  134
# 14                    6
# 15                    8
# 16                  545
# 17                  254
# 18                  268
# 19                  421
# 20                  180
# 21                  170
# 22                  103
# 23                   95
# 24                  109
# 25                  287
# 26                   78
# 27                  399
# 28                  316
# 29                    1
# 30                   44
# 31                  257
# 32                  201
# 33                  169
# 34                  523
# 35                  101
# 36                  207
# 37                  146
# 38                  120
# 39                  315
# 40                  164
# 41                   26
# 42                   18
# 43                  555
# 44                  275
# 45                  564
# 46                   76
# 47                  350
# 48                  122
# 49                   68

# %%
good_aggregate_episodes_1998.to_json('./good_episodes.json', orient='records')
villains_aggregate_episodes_1998.to_json('./villains_episodes.json', orient='records')

# %%
all_episodes = lines_1998.groupby(['season', 'episode_nr', 'episode', 'title_1', 'title_2', 'description'])['word_count_for_line'].sum().reset_index()
all_episodes = all_episodes.sort_values(['season', 'episode_nr', 'episode'], ascending=[True, True, True]).reset_index(drop=True)
all_episodes.head(50)
# Out:
#     season  episode_nr                                            episode  \
# 0      1.0         1.1                              monkey see, doggie do
# 1      1.0         1.2                                      mommy fearest
# 2      1.0         2.2                                    powerpuff bluff
# 3      1.0         3.1                                          octi evil
# 4      1.0         7.1                                  major competition
# 5      1.0         7.2                                  mr. mojo's rising
# 6      1.0         8.1                                  paste makes waste
# 7      1.0         8.2                                           ice sore
# 8      1.0         9.1                                      bubblevicious
# 9      1.0         9.2                                     the bare facts
# 10     1.0        10.1                                         cat man do
# 11     1.0        10.2                                       impeach fuzz
# 12     1.0        11.1                            just another manic mojo
# 13     1.0        11.2                                  mime for a change
# 14     2.0         1.1                             stuck up, up, and away
# 15     2.0         1.2                                 schoolhouse rocked
# 16     2.0         2.1                                        collect her
# 17     2.0         2.2                                     supper villain
# 18     2.0         3.1                                      birthday bash
# 19     2.0         3.2                                 too pooped to puff
# 20     2.0         4.1                                   beat your greens
# 21     2.0         4.2                                      down 'n dirty
# 22     2.0         5.1                                       dream scheme
# 23     2.0         5.2                               you snooze, you lose
# 24     2.0         6.1                                      slave the day
# 25     2.0         6.2                                      los dos mojos
# 26     2.0         7.1                             a very special blossom
# 27     2.0         7.2                                   daylight savings
# 28     2.0         8.1                                             mo job
# 29     2.0         8.2                                           pet feud
# 30     2.0         9.1                                    imaginary fiend
# 31     2.0         9.2                                        cootie gras
# 32     2.0        10.1  the powerpuff girls' best rainy day adventure ...
# 33     2.0        10.2                                      just desserts
# 34     2.0        11.1                                     twisted sister
# 35     2.0        11.2                                           cover up
# 36     2.0        12.1                                        speed demon
# 37     2.0        12.2                                       mojo jonesin
# 38     2.0        13.1                                  something's a ms.
# 39     2.0        13.2                          slumbering with the enemy
# 40     3.0         1.1                                      fallen arches
# 41     3.0         1.2                                     the mane event
# 42     3.0         2.1                                       town and out
# 43     3.0         2.2                                      child fearing
# 44     3.0         4.1                                       bubblevision
# 45     3.0         4.2                                   bought and scold
# 46     3.0         5.1                             gettin' twiggy with it
# 47     3.0         5.2                                            cop out
# 48     3.0         6.1                          three girls and a monster
# 49     3.0         6.2                             monkey see, doggie two
#
#                                               title_1  \
# 0                               monkey see, doggie do
# 1                               monkey see, doggie do
# 2                                       insect inside
# 3                                           octi evil
# 4                                   major competition
# 5                                   major competition
# 6                                   paste makes waste
# 7                                   paste makes waste
# 8                                       bubblevicious
# 9                                       bubblevicious
# 10                                         cat man do
# 11                                         cat man do
# 12                            just another manic mojo
# 13                            just another manic mojo
# 14                             stuck up, up, and away
# 15                             stuck up, up, and away
# 16                                        collect her
# 17                                        collect her
# 18                                      birthday bash
# 19                                      birthday bash
# 20                                   beat your greens
# 21                                   beat your greens
# 22                                       dream scheme
# 23                                       dream scheme
# 24                                      slave the day
# 25                                      slave the day
# 26                             a very special blossom
# 27                             a very special blossom
# 28                                             mo job
# 29                                             mo job
# 30                                    imaginary fiend
# 31                                    imaginary fiend
# 32  the powerpuff girls' best rainy day adventure ...
# 33  the powerpuff girls' best rainy day adventure ...
# 34                                     twisted sister
# 35                                     twisted sister
# 36                                        speed demon
# 37                                        speed demon
# 38                                  something's a ms.
# 39                                  something's a ms.
# 40                                      fallen arches
# 41                                      fallen arches
# 42                                       town and out
# 43                                       town and out
# 44                                       bubblevision
# 45                                       bubblevision
# 46                             gettin' twiggy with it
# 47                             gettin' twiggy with it
# 48                          three girls and a monster
# 49                          three girls and a monster
#
#                       title_2  \
# 0               mommy fearest
# 1               mommy fearest
# 2             powerpuff bluff
# 3                geshundfight
# 4           mr. mojo's rising
# 5           mr. mojo's rising
# 6                    ice sore
# 7                    ice sore
# 8              the bare facts
# 9              the bare facts
# 10               impeach fuzz
# 11               impeach fuzz
# 12          mime for a change
# 13          mime for a change
# 14         schoolhouse rocked
# 15         schoolhouse rocked
# 16             supper villain
# 17             supper villain
# 18         too pooped to puff
# 19         too pooped to puff
# 20              down 'n dirty
# 21              down 'n dirty
# 22       you snooze, you lose
# 23       you snooze, you lose
# 24              los dos mojos
# 25              los dos mojos
# 26           daylight savings
# 27           daylight savings
# 28                   pet feud
# 29                   pet feud
# 30                cootie gras
# 31                cootie gras
# 32              just desserts
# 33              just desserts
# 34                   cover up
# 35                   cover up
# 36               mojo jonesin
# 37               mojo jonesin
# 38  slumbering with the enemy
# 39  slumbering with the enemy
# 40             the mane event
# 41             the mane event
# 42              child fearing
# 43              child fearing
# 44           bought and scold
# 45           bought and scold
# 46                    cop out
# 47                    cop out
# 48     monkey see, doggie two
# 49     monkey see, doggie two
#
#                                           description  word_count_for_line
# 0   In "Monkey See, Doggie Do", Mojo Jojo swipes s...                  810
# 1   In "Monkey See, Doggie Do", Mojo Jojo swipes s...                 1079
# 2   "Insect Inside" The city of Townsville becomes...                 1271
# 3   "Octi-Evil" Him is out to break up the Powerpu...                  869
# 4   "Major Competition" The Powerpuff Girl's place...                  940
# 5   "Major Competition" The Powerpuff Girl's place...                  981
# 6   In "Paste Makes Waste", one of the Pokey Oaks ...                  764
# 7   In "Paste Makes Waste", one of the Pokey Oaks ...                  962
# 8   Bubbles is tired of being the cute and wants t...                  854
# 9   Bubbles is tired of being the cute and wants t...                 1634
# 10  "Cat Man Do" The Girls save an innocent little...                  704
# 11  "Cat Man Do" The Girls save an innocent little...                  785
# 12  In "Just Another Manic Mojo", Mojo Jojo's morn...                 1140
# 13  In "Just Another Manic Mojo", Mojo Jojo's morn...                  795
# 14  "Stuck Up, Up, and Away" Bratty little Princes...                 1199
# 15  "Stuck Up, Up, and Away" Bratty little Princes...                 1207
# 16  "Collect Her" Lenny Baxter, a rabid fan of Pow...                  845
# 17  "Collect Her" Lenny Baxter, a rabid fan of Pow...                 1011
# 18  "Birthday Bash" It's the Girls birthday, and t...                 1057
# 19  "Birthday Bash" It's the Girls birthday, and t...                  932
# 20  "Beat Your Greens" When Broccoli Aliens from s...                 1113
# 21  "Beat Your Greens" When Broccoli Aliens from s...                  477
# 22  "Dream Scheme" The Sandman would like a little...                 1174
# 23  "Dream Scheme" The Sandman would like a little...                  832
# 24  "Slave the Day" When the Girls save Big Billy'...                  918
# 25  "Slave the Day" When the Girls save Big Billy'...                 1038
# 26  "A Very Special Blossom" When the Professor wa...                 1319
# 27  "A Very Special Blossom" When the Professor wa...                  936
# 28  "Mo Job" Princess hires Mojo to devise the per...                  756
# 29  "Mo Job" Princess hires Mojo to devise the per...                  760
# 30  In "Imaginary Fiend", a new kid at school prov...                  995
# 31  In "Imaginary Fiend", a new kid at school prov...                  644
# 32  "The Powerpuff Girls Best Rainy Day Adventure ...                 1372
# 33  "The Powerpuff Girls Best Rainy Day Adventure ...                  757
# 34  After finding themselves far too tired after a...                  762
# 35  After finding themselves far too tired after a...                  499
# 36  "Speed Demon" The Girls accidentally fly the s...                  871
# 37  "Speed Demon" The Girls accidentally fly the s...                  757
# 38  "Something's a Ms." Miss Bellum is acting very...                 1092
# 39  "Something's a Ms." Miss Bellum is acting very...                  453
# 40  "Fallen Arches" A gang of old-time villains co...                 1175
# 41  "Fallen Arches" A gang of old-time villains co...                  695
# 42  "Town and Out" When the Professor gets a new j...                  935
# 43  "Town and Out" When the Professor gets a new j...                  828
# 44  "Bubble Vision" Bubbles fighting has been real...                  701
# 45  "Bubble Vision" Bubbles fighting has been real...                 1100
# 46  "Gettin' Twiggy With It" Mitch is told to take...                  472
# 47  "Gettin' Twiggy With It" Mitch is told to take...                  897
# 48  "Three Girls and a Monster" The Girls are once...                  524
# 49  "Three Girls and a Monster" The Girls are once...                  845

# %%
all_episodes.to_json('./all_episodes.json', orient='records')
