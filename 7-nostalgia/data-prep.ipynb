# %%
import pandas as pd

raw_data_1 = pd.read_json('./ppg-episode-transcripts-1.json', encoding='utf-8')
raw_data_2 = pd.read_json('./ppg-episode-transcripts-2.json', encoding='utf-8')

# %%
raw_data = pd.concat([raw_data_1, raw_data_2])

raw_data.head()
# Out:
#                             episode  \
# 0  'Twas the Fight Before Christmas
# 1                     A Documentary
# 2                   A Made Up Story
# 3            A Very Special Blossom
# 4                     Air Buttercup
#
#                                               dialog
# 0  [Narrator: 'Twas the city of Townsville, and a...
# 1  [Brian Larsen: The city of Townsville. This is...
# 2  [Narrator: The city of Townsville!  Where some...
# 3  [Narrator: The city of Townsville. And it's a ...
# 4  [The girls are seen eating lunch in the cafete...

# %%
raw_data.describe()
# Out:
#                       episode  \
# count                     155
# unique                    155
# top     The Headsucker's Moxy
# freq                        1
#
#                                                    dialog
# count                                                 155
# unique                                                155
# top     [Narrator: The city of Townsville! A secure pl...
# freq                                                    1

# %%
# Drop all
# - Animated shorts
# - Movies
# - PPG Z episodes
episodes_to_drop = [
   'a comedy of terrors', # powerpuff girls Z
    'enter the entourage',  # powerpuff girls Z
    "it's all because of him", # powerpuff girls Z
    'powerpuff girls to the rescue', # powerpuff girls Z

   'air buttercup', # Animated short, 2016
   "bubbles' beauty blog", # Animated short, 2016
   'ping pong z', # Animated short, 2016
   'run, blossom, run!', # Animated short, 2016
    "i'll be bake", # Animated short, 2017
    'mojo builds a shelf', # Animated short, 2017
    'the powerpuff girls rule!!!', # TV short, 2008

   'crime 101', # Pilot, 1995/1996
   'meat fuzzy lumkins', # Pilot, 1995

   'whoopass stew' # Movie, their first-ever appearance, 1992
   'the powerpuff girls movie', # Movie, 2002
   "'twas the fight before christmas",  # Movie, 2003
   'powerpuff girls special: dance pantsed', # Movie (weird style), 2014

   'ttg v ppg', # Teen titans, not ppg 
]

raw_data = raw_data[~raw_data['episode'].str.lower().isin(episodes_to_drop)]

# %%
all_lines = raw_data.explode(column='dialog')
all_lines = all_lines.reset_index(drop=True)
all_lines.head()
# Out:
#          episode                                             dialog
# 0  A Documentary  Brian Larsen: The city of Townsville. This is ...
# 1  A Documentary  Brian: Oh, you might know them as those three ...
# 2  A Documentary  Brian: I'm Brian, and this is my documentary. ...
# 3  A Documentary      Brian: Sugar... spice... and everything nice.
# 4  A Documentary  Brian: Yep, those are pretty normal ingredient...

# %%
all_lines[all_lines['dialog'].isna()]['episode']
# Out:
# 11879    Small World: Heart to Heartstone
# Name: episode, dtype: object

# %%
speakers = all_lines['dialog'].str.extract("^([.,*#-'/\w\s]*):")

all_lines['speaker'] = speakers
all_lines['speaker'] = all_lines['speaker'].str.strip()
all_lines['speaker'] = all_lines['speaker'].str.lower()
all_lines['speaker'] = all_lines['speaker'].str.strip()
speakers.nunique()
# Out:
# 0    758
# dtype: int64

# %%
all_lines['dialog'].head(50)
# Out:
# 0     Brian Larsen: The city of Townsville. This is ...
# 1     Brian: Oh, you might know them as those three ...
# 2     Brian: I'm Brian, and this is my documentary. ...
# 3         Brian: Sugar... spice... and everything nice.
# 4     Brian: Yep, those are pretty normal ingredient...
# 5     Brian: The city of Townsville. A great city wi...
# 6     Brian: The newly renovated and revitalized Old...
# 7     Brian: Although this bus looks better than tha...
# 8     Brian: There are other reminders and countless...
# 9     Brian: Their photos have graced newspapers and...
# 10    Brian: They have merchandising... and even the...
# 11    Brian: My first visit was unannounced... and j...
# 12    Brian: the girls flew away. Three bright strea...
# 13    Brian: Okay... I'm driving up through the city...
# 14    Brian: I keep trying to get closer, but the ba...
# 15    Brian: I'm- I'm okay, now I'm gonna get out of...
# 16    Brian: And just when I thought I was going to ...
# 17    Brian: And although I played this cat- and- mo...
# 18    Brian: I started at their school, the Pokey Oa...
# 19    Ms. Keane: Well, let me tell you, the girls ar...
# 20    Brian: Could you tell me more about the Powerp...
# 21    Ms. Keane: Well, um... I'm their teacher. I re...
# 22    Brian: As I left the school, I happened upon t...
# 23    Carl: About the Powerpuff Girls, huh? Well, th...
# 24    Brian: I didn't get much from Carl. But he gav...
# 25    Brian: This is Dave, the local cop who hauled ...
# 26    Dave: Oh, yeah. I been in a few sticky situati...
# 27    Dave: Naah, I don't have monster enforcement t...
# 28    Brian: With little luck on the grassroots leve...
# 29    Mayor: Okay, everyone. That about does it for ...
# 30    Brian: Ah, Mayor!  Uh, hi. I'm shooting a docu...
# 31    Mayor: Look, I don't know nothin' about nothin...
# 32    Ms. Bellum: I'm sorry, but you're going to hav...
# 33          Brian: Uh, just let me ask a few questions.
# 34    Ms. Bellum: Uh, this is an unannounced visit. ...
# 35                       Brian: Don't touch the camera!
# 36    Brian: That really didn't get me anywhere. Wit...
# 37    Talking Dog: I'm a talking dog. That is so muc...
# 38    Brian: Having dealt with the positive side of ...
# 39           Brian: But this proved even more fleeting.
# 40                      Princess: Sorry. No interviews!
# 41               Fuzzy: GET OFFA MY PROPERTY, DAGNABIT!
# 42             Brian: Yeah, but wait, I just want to...
# 43                          Fuzzy: NO TRESPASSIN'! OFF!
# 44    Brian: Mr. Mojo? Uh, hi. My name is Brian, and...
# 45              Mojo: Can't talk, planning evil scheme.
# 46    Brian: With all the opinions and facts I gathe...
# 47    Brian: I found Officer Dave again, in hopes th...
# 48    Brian: After Officer Dave showed me a few poli...
# 49    Brian: And it wasn't long before we got the call.
# Name: dialog, dtype: object

# %%
dialog_lines = all_lines['dialog']
dialog_lines = dialog_lines.reset_index(drop=True)
dialog_lines
# Out:
# 0        Brian Larsen: The city of Townsville. This is ...
# 1        Brian: Oh, you might know them as those three ...
# 2        Brian: I'm Brian, and this is my documentary. ...
# 3            Brian: Sugar... spice... and everything nice.
# 4        Brian: Yep, those are pretty normal ingredient...
#                                ...
# 16245                           Buttercup: Correct, Mayor.
# 16246                                          Mayor: Huh?
# 16247                               Bubbles: That’s right.
# 16248                                             Mayor: …
# 16249    Narrator: And so once again the day— My head h...
# Name: dialog, Length: 16250, dtype: object

# %%
def process_dialog(dialog):
    if isinstance(dialog, str):
        parts = dialog.split(': ')
        if len(parts) > 1:
            return ' '.join(parts[1:])
        elif len(parts) == 1:
            return parts[0]
    else:
        return None
    
dialog_without_speaker = dialog_lines.apply(process_dialog)

# %%
dialog_without_speaker.head(50)
# Out:
# 0     The city of Townsville. This is where the Powe...
# 1     Oh, you might know them as those three cute li...
# 2     I'm Brian, and this is my documentary. And you...
# 3                Sugar... spice... and everything nice.
# 4     Yep, those are pretty normal ingredients, all ...
# 5     The city of Townsville. A great city with many...
# 6     The newly renovated and revitalized Old Townsv...
# 7     Although this bus looks better than that corpo...
# 8     There are other reminders and countless monume...
# 9     Their photos have graced newspapers and tabloi...
# 10    They have merchandising... and even their own ...
# 11    My first visit was unannounced... and just as ...
# 12    the girls flew away. Three bright streaks cut ...
# 13    Okay... I'm driving up through the city, and t...
# 14    I keep trying to get closer, but the battle ke...
# 15    I'm- I'm okay, now I'm gonna get out of my car...
# 16    And just when I thought I was going to capture...
# 17    And although I played this cat- and- mouse gam...
# 18    I started at their school, the Pokey Oaks. Ms....
# 19    Well, let me tell you, the girls are fantastic...
# 20    Could you tell me more about the Powerpuff sid...
# 21    Well, um... I'm their teacher. I really don't ...
# 22    As I left the school, I happened upon the tras...
# 23    About the Powerpuff Girls, huh? Well, they kee...
# 24    I didn't get much from Carl. But he gave me an...
# 25    This is Dave, the local cop who hauled me in f...
# 26    Oh, yeah. I been in a few sticky situations wi...
# 27    Naah, I don't have monster enforcement trainin...
# 28    With little luck on the grassroots level, I de...
# 29    Okay, everyone. That about does it for the pay...
# 30    Ah, Mayor!  Uh, hi. I'm shooting a documentary...
# 31    Look, I don't know nothin' about nothin'!  You...
# 32        I'm sorry, but you're going to have to leave.
# 33                 Uh, just let me ask a few questions.
# 34          Uh, this is an unannounced visit. Security!
# 35                              Don't touch the camera!
# 36    That really didn't get me anywhere. With my in...
# 37    I'm a talking dog. That is so much better than...
# 38    Having dealt with the positive side of the spe...
# 39                  But this proved even more fleeting.
# 40                                Sorry. No interviews!
# 41                      GET OFFA MY PROPERTY, DAGNABIT!
# 42                    Yeah, but wait, I just want to...
# 43                                 NO TRESPASSIN'! OFF!
# 44    Mr. Mojo? Uh, hi. My name is Brian, and I'm ma...
# 45                    Can't talk, planning evil scheme.
# 46    With all the opinions and facts I gathered abo...
# 47    I found Officer Dave again, in hopes that he c...
# 48    After Officer Dave showed me a few police tric...
# 49           And it wasn't long before we got the call.
# Name: dialog, dtype: object

# %%
all_lines['dialog'] = dialog_without_speaker
all_lines['dialog']
# Out:
# 0        The city of Townsville. This is where the Powe...
# 1        Oh, you might know them as those three cute li...
# 2        I'm Brian, and this is my documentary. And you...
# 3                   Sugar... spice... and everything nice.
# 4        Yep, those are pretty normal ingredients, all ...
#                                ...
# 16245                                      Correct, Mayor.
# 16246                                                 Huh?
# 16247                                        That’s right.
# 16248                                                    …
# 16249            And so once again the day— My head hurts!
# Name: dialog, Length: 16250, dtype: object

# %%
unique_speakers = all_lines['speaker'].unique()

for speaker in unique_speakers:
    if isinstance(speaker, str) and ',' in speaker:
        print(speaker)
# Out:
# bubbles, buttercup
# blossom, buttercup
# kids, blossom
# slim, junior
# mojo, princess, boys
# professor, blossom, buttercup
# brick, butch
# blossom, bubbles
# teen blossom, teen buttercup
# girl 2, boy 1
# blossom/ms. bellum, buttercup/professor
# mayor, ms. bellum
# mojo, 'him'
# bossman, bossman 2
# slim, slim 2
# junior, juniors 2 and 3
# driver, robbers
# girls, duplicates
# kids, parents
# stan, sandra
# fields, anthropist, blind
# class, ms. keane
# girls, professor
# professor, ms. keane
# ace, billy, arturo
# fuzzy, princess, 'him'
# kim, jeff, mary
# joey, kim
# necktie wearing monster, waitress
# man 9, bass monster
# gang, fuzzy, 'him'
# bertha, beatrice
# lloyd, floyd
# ace, snake, lil arturo, big billy
# 002, 017
# nephews, fuzzy
# ace, snake, arturo, billy
# ace, snake
# boys 2, 3, 4
# monty, slim
# bubbles, buttercup and the professor
# girls, robin
# crowd, professor, ms. bellum
# governor, yokel, lummox
# lil arturo, snake
# snake, arturo, billy

# %%
# Save one as second speaker
double_speakers = [    
    "blossom and buttercup",
    "blossom and bubbles",
    "the professor and blossom",
    "both blossom and buttercup",
    "buttercup and blossom",
    "blossom and the professor",
    "bubbles and blossom",
    "bubbles and buttercup",
    "buttercup and bubbles",
    "professor and buttercup",
    "professor utonium and javier xavier",
    "man and woman",
    "girls and erica",
    "momoko and miyako",
    "kaoru and miyako",
    "ms. bellumold woman 1",
    "ms. keaneold woman 2",
    "mayor and ms. bellum",
    "blossom/ms. bellum",
    "ms. bellum/blossom",
    "buttercup/green batman",
    "bubbles/bubbs wonder",
    "buttercup/professor",
    "professor/buttercup",
    "blossom/ms. bellum",
    "bubbles/mayor",
    "mayor/bubbles",
    "ms. bellum/blossom",
    "girl 1/ace",
    "girl 2/grubber",
    "girl 3/snake",
    "old woman/mojo",
    "mojo/old woman",
    "blossom/dachshund",
    "bubbles/centipede",
    "buttercup/cobra",
    "professor/older girl",
    "mojo/fish",
    "professor/ugly baby",
    "professor/nurse",
    "professor/astronaut",
    "professor/pink creature",
    "professor/morbid woman",
    "bubbles/narrator",
    "narrator/bubbles",
    "blossom/bubbles",
    "octi/him",
    "buttercup/bubblecup",
    "bubbles/children",
    "old man/janitor",
    "eyes/blonde hair covered boy",
    "blossom/liberty belle",
    "bubbles/harmony bunny",
    "buttercup/mange",
    "blossom/buttercup",
    "bubbles, buttercup",
"girls, professor",
"blossom, buttercup",
"blossom, bubbles and buttercup",
"kids, blossom",
"slim, junior",
"mojo, princess, boys",
"blossom, bubbles, buttercup and the professor",
"blossom, bubbles, and buttercup",
"professor, blossom, buttercup",
"brick, butch",
"blossom, bubbles",
"teen blossom, teen buttercup",
"girl 2, boy 1",
"skinny, tiny",
"blossom/ms. bellum, buttercup/professor",
"mayor, ms. bellum",
"mojo, 'him'",
"bossman, bossman 2",
"slim, slim 2",
"junior, juniors 2 and 3",
"bubbles, buttercup, random boy, random girl, another random boy, robin snyder, another random boy, two random boys, blossom, jared, and barry",
"random girl , random boy , random boy , buttercup  on the left, jared , and robin , blossom , and two boys",
"blossom, buttercup, jared, barry, and robin",
"chad, man with glasses, and pink haired lady",
"driver, robbers",
"girls, duplicates",
"kids, parents",
"stan, sandra",
"fields, anthropist, blind",
"class, ms. keane",
"pug faced paulie, scared",
"momoko, miyako, and kaoru",
"professor, ms. keane",
"ace, billy, arturo",
"fuzzy, princess, 'him'",
"kim, jeff, mary",
"joey, kim",
"man 9, bass monster",
"gang, fuzzy, 'him'",
"bertha, beatrice",
"lloyd, floyd",
"ace, snake, lil' arturo, big billy",
"002, 017",
"ace, snake, arturo, billy",
"ace, snake",
"boys 2, 3, 4",
"monty, slim",
"bubbles, buttercup and the professor",
"girls, robin",
"barry, bubbles, and buttercup",
"bubbles, blossom",
"many monkeys, chimpanzees, gorillas, orangutans, and even an uakari",
"crowd, professor, ms. bellum",
"governor, yokel, lummox",
"octi/'him'",
"'him'/ms. keane",
"blossom & buttercup",
"blossom & bubbles",
"bubbles & blossom",
"blossom & professor utonium",
"bubbles & buttercup",
"buttercup & bubbles",
"spikey haired boy & eyes/blonde hair covered boy",
"donny & chelsea"
]

blossom_values = [ 
    "blossom #2",
    "blosoom",
    "all blossoms",
    "blossom  and blossom",
    "the blossoms",
    "siren blossom",
    "teen blossom",
    "blossom as she fights the bunnies",
    "knockoff blossom",
    "survivor reject blossom",
    "angel blossom",
    "robot blossom",
    "robo blossom",
    "lice blossom",
    "french renaissance blossom",
    "old blossom",
    "blossom, in the shop",
    "blossom, to bubbles",
    "blossom's thoughts",
    "blossom ",
    "both blossom"
]

bubbles_values = [
    "bubbles",
    "bubbes",
    "dark bubbles",
    "teen bubbles",
    "knockoff bubbles",
    "robo bubbles",
    "french renaissance bubbles",
    "bubbles and doubles",
    "old bubbles",
    "bubblecup",
    "bubbles' voice",
    "bubbles #2"
]

buttercup_values = [
    "buttercup double",
    "buttecup",
    "real buttercup",
    "buttercup on video",
    "teen buttercup",
    "knockoff buttercup",
    "reject buttercup",
    "angel buttercup",
    "robo buttercup",
    "flashback buttercup",
    "old buttercup",
    "buttercup, to herself",
    "buttercup, disguised",
    "buttercup, as she accidentaly reveals herself",
    "buttercup, scared",
    "and buttercup",
    "buttercup  on the left",
    "buttercup's thoughts",
    "buttercup #2"
]

mojo_values = [
    "mojo",
    "jojo",
    "'mojo'",
    "'mojo' ",
    "mojo'",
    "mojo's thoughts"
]

professor_values = [
    "professor",
    "dream professor",
    "memory professor",
    "professor utonium",
    "kid professor",
    "young prof",
    "student prof",
    "the professor",
    "flashback professor",
]

mayor_values = [
    "mayor",
    "the mayor",
    "younger mayor",
    "mayor mayer",
    "mayor of new townsville",
    "lice mayor",
    "citiesville mayor",
    "dream mayor"
]

him_values = [
    "him",
    "'him'",
    "memory him",
    "black spored him"
]

narrator_values = [
    "narrator",
    "male narrator",
    "man voiceover",
]

princess_values = [
    "princess morebucks",
    "princess",
    "princess morbucks",
    "morbucks",
    "morbucks' heart"
]

fuzzy_values = [
    "fuzzy",
    "fuzzy lumpkins"
]

brick_values = [
    "brick",
    "teen brick"
]

mike_values = [
    "brickowski",
    "mike"
]

woman_values = [
    "old woman",
    "woman",
    "muscle woman",
    "woman in the suit",
    "policewoman",
    "woman 2",
    "woman 3",
    "brown skinned woman",
    "woman 1",
    "young woman",
    "adult teenage woman",
    "woman 4",
    "woman 5",
    "woman 6",
    "woman 7",
    "iss woman",
    "cowgirl woman",
    "backgrounder woman",
    "fat woman",
    "fainting woman",
    "nature woman",
    "jewel owner woman",
    "jamaican woman",
    "curler woman",
    "woman 8",
    "woman 9",
    "repairwoman",
    "morbid woman",
    "woman #2",
    "woman #3",
    "woman #1",
    "woman's voice",
    "lunch lady",
    "and pink haired lady",
    "rocket a.i. lady",
    "cleaning lady",
    "video lady",
    "lady" #1,
    "old lady",
    "banklady",
    "news lady",
    "elderly lady",
    "anchor lady",
    "lady",
    "baby lady",
    "random lady",
    "lady #1"
]

man_values = [
    "man",
    "policeman",
    "old man",
    "swan boat man",
    "barber man",
    "man 1",
    "man 2",
    "man 3",
    "man in court",
    "man in a blue long sleeved robe",
    "old man 1",
    "old man 2",
    "old man 3",
    "man with glasses",
    "policeman 1",
    "policeman 2",
    "security man 1",
    "security man 2",
    "postman",
    "renaissance man",
    "delivery man",
    "man with a green hat",
    "man wit a green hat",
    "man in the space suit",
    "running man",
    "pointing man",
    "manager",
    "french man with a french hat",
    "brown haired man with glasses",
    "man 4",
    "man 5",
    "hotdog man",
    "man 6",
    "man 7",
    "man 8",
    "man 9",
    "man 10",
    "man 11",
    "abs man",
    "commercial man",
    "prison man",
    "salesman",
    "henchman",
    "mailman",
    "backgrounder man",
    "bank manager",
    "pizza man",
    "rainbow man",
    "bagman",
    "gunman",
    "short man",
    "newsman",
    "jewel owner man",
    "smooth man",
    "anchorman",
    "businessman",
    "french renaissance man",
    "fireman 1",
    "man 12",
    "man 13",
    "man 14",
    "fireman 2",
    "man being stung by bees",
    "foam finger man",
    "man in overalls",
    "man in trough",
    "male actor",
    "male chorus",
    "male voice",
    "male staff member",
    "man #1",
    "man #2",
    "man #3",
    "man #4",
]

bliss_values = [
    "memory bliss",
    "bliss",
    "memory teenage bliss",
    "young memory bliss"
]

monster_values = [
    "monster",
    "pink tentacled monster",
    "green monster",
    "bass monster",
    "female fish monster",
    "red lizard monster",
    "lawyer monster",
    "monsters",
    "fancy monster",
    "purple octopus",
    "dragon",
    "pincered monster",
    "necktie wearing monster",
    "oneeyed monster",
    "singledout monster",
    "monster #1",
    "crowd of monsters"
]

boy_values = [
    "boy",
    "huge boy",
    "pimple faced boy",
    "boy 1",
    "boy 2",
    "boy 3",
    "boy 4",
    "nerd boy",
    "bigger boy",
    "smaller boy",
    "boy with brown spiky hair",
    "man boy",
    "manboy",
    "spikey haired boy",
    "freckle faced boy",
    "boy 5",
    "boy 6",
    "boy 7",
    "boy nerd",
    "green haired boy with rapper glasses",
    "french renaissance orange haired boy",
    "redhead boy",
    "'injured' boy",
    "brownskinned boy",
    "random boy",
    "another random boy",
    "two random boys",
    "random boy ",
    "and two boys",
    "spikey haired boy & eyes/blonde hair covered boy",
    "blonde hair covered boy",
    "boys 2",
    "boy #1",
]

ppg_values = [
    "all 3 girls",
    "all three girls",
    "girls",
    "the girls",
    "old girls",
    "the 3 girls",
    "all girls",
    "powerpuff girls z",
    "the 4 girls"
]

rrb_values = [
    "boys"
]

girl_values = [
    "girl",
    "cool girl",
    "girl with braces",
    "girl 1",
    "girl 2",
    "girl 3",
    "blonde teenage girl",
    "blonde girl",
    "girl with glasses",
    "girl without glasses",
    "2 girls",
    "cool girl 1",
    "cool girl 3",
    "cool girl 2",
    "all 3 cool girls",
    "girl with brown hair",
    "brown haired girl",
    "cowgirl",
    "friendly girl",
    "derbytante girls",
    "spirit girl",
    "mail girl",
    "flower girl",
    "girl student",
    "girl 4",
    "2 unnamed girls",
    "unnamed girl with a pink shirt",
    "teenage girl 1",
    "teenage girl 3",
    "teenage girls",
    "pimple girl",
    "older girl",
    "random girl",
    "random girl ",
    "girl #1",
    "girl #2",
    "girl #3",
]

miyako_values = [
    "memory miyako",
    "miyako",
    "flashback miyako",
]

sapna_values = [
    "sapna,"
    "dream sapna",
    "spider sapna"
]

kaoru_values = [
    "kaoru matsubara"
]

announcer_values = [
    "space towtruck and the infinite jumper cables movie announcer",
    "announcer",
    "announcer 1",
    "announcer 2",
    "another announcer",
    "radio announcer",
    "tv announcer",
    "space towtruck announcer",
    "male pageant announcer",
    "video game announcer",
]

keane_values = [
    "ms. keane",
    "young keane",
    "keanes",
    "keane 2",
    "keane 1",
    "miss keane",
    "french renaissance ms. keane",
    "ms. keane"
]

bellum_values = [
    "ms. bellum",
    "young bellum",
    "miss bellum",
    "dream ms. bellum",
    "ms.bellum",
    "ms. bellum"
]

billy_values = [
    "billy",
    "big billy",
    " billy",
    " big billy",
]

arturo_values = [
    "lil arturo",
    " lil arturo",
    " arturo"
]

butch_values = [
    "butch",
    "teen butch"
]

boomer_values = [
    "boomer",
    "teen boomer"
]

talking_dog_values = [
    "talking dog",
    "talking  dog",
    "talking dog billboard"
]

junior_values = [
    "junior",
    "junior 4"
]

bossman_values = [
    "bossman",
    "bossman 3",
    "bossman 2"
]

dick_values = [
    "dick",
    "student dick"
]

marianne_values = [
    'mrs. smith'
]

harold_values = [
    'mr. smith'
]

sedusa_values = [
    'ima'
]

reporter_values = [
    "reporter",
    "reporter 2",
    "female reporter",
    "male reporter",
    "radio reporter",
    "tv reporter 1",
    "tv reporter 2",
    "tv reporter 3",
    "various reporters",
    "tv reporter 4",
]

thief_values = [
    "robber",
    "robbers",
    "'robber' 1",
    "'robber' 2",
    "thin robber",
    "fat robber",
    "short robber",
    "robber 1",
    "robber 2",
    "thief"
]

kid_values = [
    "kids",
    "kid",
    "beefy kid",
    "fat kid",
    "kid 1",
    "kid 2",
    "kid 3",
    "wedgie kid",
]

snake_values = [
    " snake"
]

cop_values = [
    "chief of police",
    "blond 'policeman'",
    "policeman #1",
    "policeman #2",
    "cop",
    "fat cop",
    "thin cop",
    "radio cop",
    "cop 2",
    "cop 1",
]

# %%
import re

# All double speakers in consistent format (comma-separated)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: re.sub(r'(/|\sand\s|,\s|\s&\s)', ',', x) if x in double_speakers else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: re.sub('/', ',', x) if x in double_speakers else x)

all_lines.loc[all_lines['speaker'] == 'ms. bellumold woman 1', 'speaker'] = 'ms. bellum,woman'
all_lines.loc[all_lines['speaker'] == 'ms. keaneold woman 2', 'speaker'] = 'ms. keane,woman'

double_speaker_items = all_lines[all_lines['speaker'].isin(double_speakers)]
double_speaker_items['speaker']
# Out:
# Series([], Name: speaker, dtype: object)

# %%
len(all_lines['speaker'])
# Out:
# 16250

# %%
new_double_speakers = all_lines[all_lines['speaker'].str.contains(',', na=False)]
len(new_double_speakers['speaker'].value_counts())
# Out:
# 81

# %%
all_lines['speaker'] = all_lines['speaker'].str.split(',')
all_lines = all_lines.explode('speaker')
all_lines = all_lines.reset_index(drop=True)
all_lines
# Out:
#                      episode  \
# 0              A Documentary
# 1              A Documentary
# 2              A Documentary
# 3              A Documentary
# 4              A Documentary
# ...                      ...
# 16656  The Headsucker's Moxy
# 16657  The Headsucker's Moxy
# 16658  The Headsucker's Moxy
# 16659  The Headsucker's Moxy
# 16660  The Headsucker's Moxy
#
#                                                   dialog       speaker
# 0      The city of Townsville. This is where the Powe...  brian larsen
# 1      Oh, you might know them as those three cute li...         brian
# 2      I'm Brian, and this is my documentary. And you...         brian
# 3                 Sugar... spice... and everything nice.         brian
# 4      Yep, those are pretty normal ingredients, all ...         brian
# ...                                                  ...           ...
# 16656                                    Correct, Mayor.     buttercup
# 16657                                               Huh?         mayor
# 16658                                      That’s right.       bubbles
# 16659                                                  …         mayor
# 16660          And so once again the day— My head hurts!      narrator
#
# [16661 rows x 3 columns]

# %%
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'blossom' if x in blossom_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'bubbles' if x in bubbles_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'buttercup' if x in buttercup_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'professor' if x in professor_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'mayor' if x in mayor_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'mojo jojo' if x in mojo_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'narrator' if x in narrator_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'him' if x in him_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'princess morbucks' if x in princess_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'fuzzy' if x in fuzzy_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'woman' if x in woman_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'man' if x in man_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'brick' if x in brick_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'bliss' if x in bliss_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'monster' if x in monster_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'boy' if x in boy_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'girl' if x in girl_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'powerpuff girls' if x in ppg_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'rowdyruff boys' if x in rrb_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'sapna' if x in sapna_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'miyako' if x in miyako_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'kaoru' if x in kaoru_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'announcer' if x in announcer_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'ms keane' if x in keane_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'ms bellum' if x in bellum_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'billy' if x in billy_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'arturo' if x in arturo_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'butch' if x in butch_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'boomer' if x in boomer_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'talking dog' if x in talking_dog_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'junior' if x in junior_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'bossman' if x in bossman_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'marianne' if x in marianne_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'harold' if x in harold_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'sedusa' if x in sedusa_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'reporter' if x in reporter_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'thief' if x in thief_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'kid' if x in kid_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'snake' if x in snake_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'cop' if x in cop_values else x)
all_lines['speaker'] = all_lines['speaker'].apply(lambda x: 'mike' if x in mike_values else x)

# %%
unique_speakers = all_lines['speaker'].unique()

for speaker in unique_speakers:
    if isinstance(speaker, str) and "dog" in speaker:
        print(speaker)
# Out:
# talking dog
# dog #2
# cellmate dog
# dog puppet
# dog

# %%
all_lines['speaker'].value_counts().head(60)
# Out:
# blossom              2927
# buttercup            2058
# bubbles              1948
# professor            1475
# narrator             1077
# mojo jojo             869
# mayor                 753
# powerpuff girls       449
# ms keane              329
# him                   249
# princess morbucks     235
# man                   219
# ms bellum             181
# ace                   169
# woman                 152
# brick                 142
# fuzzy                 111
# bossman                91
# billy                  82
# sedusa                 77
# talking dog            69
# dick                   62
# monster                62
# bernie                 60
# announcer              54
# marianne               53
# thief                  52
# butch                  50
# boomer                 50
# girl                   46
# brian                  46
# mike                   46
# robin                  46
# boy                    45
# major glory            45
# arturo                 42
# mitch                  42
# snake                  41
# whitfield              39
# cop                    39
# kid                    38
# harold                 38
# crowd                  35
# slim                   34
# reporter               32
# junior                 32
# teacher                27
# captain                26
# lenny                  25
# sapna                  25
# voice                  24
# mopey                  23
# femme fatale           23
# mr. green              23
# 253                    23
# mary                   23
# madame argentina       21
# shaquille              20
# rowdyruff boys         19
# crack                  19
# Name: speaker, dtype: int64

# %%
# Identify episodes with only 1 line, probably we need to filter them out
all_lines['episode'].value_counts()
# Out:
# Criss Cross Crisis                  281
# Superfriends                        240
# Power-Noia                          227
# Members Only                        225
# Film Flam                           222
#                                    ...
# What's the Big Idea?                 59
# Neighbor Hood                        55
# Down 'n Dirty                        53
# Small World: Abra-Disaster           31
# Small World: Heart to Heartstone      1
# Name: episode, Length: 142, dtype: int64

# %%
import numpy as np

# Create a villain column
conditions = [
    all_lines['speaker'] == 'mojo jojo',
    all_lines['speaker'] == 'him',
    all_lines['speaker'] == 'sedusa',
    all_lines['speaker'] == 'princess morbucks',
    all_lines['speaker'] == 'dick',
    all_lines['speaker'] == 'bernie',
    all_lines['speaker'] == 'sandman',
    all_lines['speaker'] == 'lenny',
    all_lines['speaker'] == 'femme fatale',
    all_lines['speaker'] == 'gnome',
    all_lines['speaker'] == 'fuzzy',
    all_lines['speaker'].isin(['brick', 'boomer', 'butch', 'rowdyruff boys']), 
    all_lines['speaker'].isin(['ace', 'grubber', 'billy', 'snake', 'arturo']),
    all_lines['speaker'].isin(['bossman', 'junior', 'slim', 'amoeba boys']),
    all_lines['speaker'].isin(['marianne', 'harold', 'julie', 'bud']),
]
values = [
    'mojo jojo', 
    'him',
    'sedusa',
    'princess morbucks',
    'dick',
    'bernie',
    'sandman',
    'lenny',
    'femme fatale',
    'gnome',
    'fuzzy',
    'rowdyruff boys',
    'gangreen gang',
    'amoeba boys',
    'smith family'
]

# Use numpy's where function to create the new column
all_lines['villain'] = np.select(conditions, values, default=None)
all_lines['villain'].head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: villain, dtype: object

# %%
all_lines['villain'].value_counts()
# Out:
# mojo jojo            869
# gangreen gang        350
# rowdyruff boys       261
# him                  249
# princess morbucks    235
# amoeba boys          157
# fuzzy                111
# smith family         105
# sedusa                77
# dick                  62
# bernie                60
# lenny                 25
# femme fatale          23
# sandman               14
# gnome                  7
# Name: villain, dtype: int64

# %%
seasons_1998_raw = pd.read_json('./ppg-seasons-1998.json', encoding='utf-8')
seasons_2016_raw = pd.read_json('./ppg-seasons-2016.json', encoding='utf-8')

seasons_2016_raw.head()
# Out:
#    year  season  episode_nr                       title  \
# 0  2016       1           1  Escape from Monster Island
# 1  2016       1           2          Princess Buttercup
# 2  2016       1           3                The Stayover
# 3  2016       1           4                     Painbow
# 4  2016       1           5            Horn, Sweet Horn
#
#                                          description
# 0  While Bubbles tries to decide whether to take ...
# 1  Buttercup starts hanging out with a bad crowd,...
# 2  Recovering from a candy hangover, Blossom and ...
# 3  A rainbow makes everyone in Townsville unnatur...
# 4  At Bubbles' request, the Professor tries to ma...

# %%
seasons_raw = pd.concat([seasons_1998_raw, seasons_2016_raw])
seasons_raw.head(10)
# Out:
#    year  season  episode_nr                                title  \
# 0  1998       1           0                  A Sticky Situation!
# 1  1998       1           1  Monkey See, Doggie Do/Mommy Fearest
# 2  1998       1           2        Insect Inside/Powerpuff Bluff
# 3  1998       1           3               Octi Evil/Geshundfight
# 4  1998       1           4              Buttercrush/Fuzzy Logic
# 5  1998       1           5           Boogie Frights/Abracadaver
# 6  1998       1           6               Telephonies/Tough Love
# 7  1998       1           7  Major Competition/Mr. Mojo's Rising
# 8  1998       1           8           Paste Makes Waste/Ice Sore
# 9  1998       1           9         Bubblevicious/The Bare Facts
#
#                                          description
# 0  Begins with the same opening sequence as the s...
# 1  In "Monkey See, Doggie Do", Mojo Jojo swipes s...
# 2  "Insect Inside" The city of Townsville becomes...
# 3  "Octi-Evil" Him is out to break up the Powerpu...
# 4  "Buttercrush" Buttercup develops a crush on Ac...
# 5  In "Boogie Frights", the Boogie Man comes up w...
# 6  "Telephonies" The Gangreen Gang gets hold of t...
# 7  "Major Competition" The Powerpuff Girl's place...
# 8  In "Paste Makes Waste", one of the Pokey Oaks ...
# 9  Bubbles is tired of being the cute and wants t...

# %%
seasons_raw['title'].head(50)
# Out:
# 0                                   A Sticky Situation!
# 1                   Monkey See, Doggie Do/Mommy Fearest
# 2                         Insect Inside/Powerpuff Bluff
# 3                                Octi Evil/Geshundfight
# 4                               Buttercrush/Fuzzy Logic
# 5                            Boogie Frights/Abracadaver
# 6                                Telephonies/Tough Love
# 7                   Major Competition/Mr. Mojo's Rising
# 8                            Paste Makes Waste/Ice Sore
# 9                          Bubblevicious/The Bare Facts
# 10                              Cat Man Do/Impeach Fuzz
# 11            Just Another Manic Mojo/Mime for a Change
# 12                                   The Rowdyruff Boys
# 13                                         Uh Oh Dynamo
# 14            Stuck Up, Up, and Away/Schoolhouse Rocked
# 15                           Collect Her/Supper Villain
# 16                     Birthday Bash/Too Pooped to Puff
# 17                       Beat Your Greens/Down 'n Dirty
# 18                    Dream Scheme/You Snooze, You Lose
# 19                          Slave the Day/Los Dos Mojos
# 20              A Very Special Blossom/Daylight Savings
# 21                                      Mo Job/Pet Feud
# 22                          Imaginary Fiend/Cootie Gras
# 23    The Powerpuff Girls' Best Rainy Day Adventure ...
# 24                              Twisted Sister/Cover Up
# 25                             Speed Demon/Mojo Jonesin
# 26          Something's a Ms./Slumbering with the Enemy
# 27                         Fallen Arches/The Mane Event
# 28                           Town and Out/Child Fearing
# 29                                   Criss Cross Crisis
# 30                        Bubblevision/Bought and Scold
# 31                       Gettin' Twiggy with It/Cop Out
# 32     Three Girls and a Monster/Monkey See, Doggie Two
# 33                      Jewel of the Aisle/Super Zeroes
# 34                           Candy Is Dandy/Catastrophe
# 35                          Hot Air Buffoon/Ploys R' Us
# 36                   The Headsucker's Moxy/Equal Fights
# 37                                           Powerprof.
# 38                       Moral Decay/Meet the Beat-Alls
# 39                           Helter Shelter/Power Lunch
# 40                                            Film Flam
# 41                                       All Chalked Up
# 42                                       Get Back, Jojo
# 43                                    Him Diddle Riddle
# 44                                         Members Only
# 45                                         Knock It Off
# 46                                         Superfriends
# 47                                    Nano of the North
# 48                                         Stray Bullet
# 49                                           Forced Kin
# Name: title, dtype: object

# %%
seasons = seasons_raw.copy()

seasons['title'] = seasons['title'].str.lower()
seasons['title'] = seasons['title'].str.split('/')
seasons['title_1'] = seasons['title'].str[0]
seasons['title_2'] = seasons['title'].str[1]
all_lines['episode'] = all_lines['episode'].str.lower()
seasons.head(10)
# Out:
#    year  season  episode_nr                                   title  \
# 0  1998       1           0                   [a sticky situation!]
# 1  1998       1           1  [monkey see, doggie do, mommy fearest]
# 2  1998       1           2        [insect inside, powerpuff bluff]
# 3  1998       1           3               [octi evil, geshundfight]
# 4  1998       1           4              [buttercrush, fuzzy logic]
# 5  1998       1           5           [boogie frights, abracadaver]
# 6  1998       1           6               [telephonies, tough love]
# 7  1998       1           7  [major competition, mr. mojo's rising]
# 8  1998       1           8           [paste makes waste, ice sore]
# 9  1998       1           9         [bubblevicious, the bare facts]
#
#                                          description                title_1  \
# 0  Begins with the same opening sequence as the s...    a sticky situation!
# 1  In "Monkey See, Doggie Do", Mojo Jojo swipes s...  monkey see, doggie do
# 2  "Insect Inside" The city of Townsville becomes...          insect inside
# 3  "Octi-Evil" Him is out to break up the Powerpu...              octi evil
# 4  "Buttercrush" Buttercup develops a crush on Ac...            buttercrush
# 5  In "Boogie Frights", the Boogie Man comes up w...         boogie frights
# 6  "Telephonies" The Gangreen Gang gets hold of t...            telephonies
# 7  "Major Competition" The Powerpuff Girl's place...      major competition
# 8  In "Paste Makes Waste", one of the Pokey Oaks ...      paste makes waste
# 9  Bubbles is tired of being the cute and wants t...          bubblevicious
#
#              title_2
# 0                NaN
# 1      mommy fearest
# 2    powerpuff bluff
# 3       geshundfight
# 4        fuzzy logic
# 5        abracadaver
# 6         tough love
# 7  mr. mojo's rising
# 8           ice sore
# 9     the bare facts

# %%
lines_with_seasons = pd.merge(all_lines, seasons, how='left', left_on='episode', right_on='title_1')
lines_with_seasons = pd.merge(lines_with_seasons, seasons, how='left', left_on='episode', right_on='title_2')

# %%
lines_with_seasons.head()
# Out:
#          episode                                             dialog  \
# 0  a documentary  The city of Townsville. This is where the Powe...
# 1  a documentary  Oh, you might know them as those three cute li...
# 2  a documentary  I'm Brian, and this is my documentary. And you...
# 3  a documentary             Sugar... spice... and everything nice.
# 4  a documentary  Yep, those are pretty normal ingredients, all ...
#
#         speaker villain  year_x  season_x  episode_nr_x  \
# 0  brian larsen    None  1998.0       5.0           9.0
# 1         brian    None  1998.0       5.0           9.0
# 2         brian    None  1998.0       5.0           9.0
# 3         brian    None  1998.0       5.0           9.0
# 4         brian    None  1998.0       5.0           9.0
#
#                             title_x  \
# 0  [a documentary, girls gone mild]
# 1  [a documentary, girls gone mild]
# 2  [a documentary, girls gone mild]
# 3  [a documentary, girls gone mild]
# 4  [a documentary, girls gone mild]
#
#                                        description_x      title_1_x  \
# 0  ."Documentary" A film student attempts to do a...  a documentary
# 1  ."Documentary" A film student attempts to do a...  a documentary
# 2  ."Documentary" A film student attempts to do a...  a documentary
# 3  ."Documentary" A film student attempts to do a...  a documentary
# 4  ."Documentary" A film student attempts to do a...  a documentary
#
#          title_2_x  year_y  season_y  episode_nr_y title_y description_y  \
# 0  girls gone mild     NaN       NaN           NaN     NaN           NaN
# 1  girls gone mild     NaN       NaN           NaN     NaN           NaN
# 2  girls gone mild     NaN       NaN           NaN     NaN           NaN
# 3  girls gone mild     NaN       NaN           NaN     NaN           NaN
# 4  girls gone mild     NaN       NaN           NaN     NaN           NaN
#
#   title_1_y title_2_y
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
lines_with_seasons.groupby(['season_y'])['episode'].nunique()
# Out:
# season_y
# 1.0    11
# 2.0    13
# 3.0    11
# 4.0     1
# 5.0    10
# 6.0    12
# Name: episode, dtype: int64

# %%
lines_with_seasons.groupby(['season_x'])['episode'].nunique()
# Out:
# season_x
# 1.0    13
# 2.0    14
# 3.0    17
# 4.0    12
# 5.0    12
# 6.0    15
# Name: episode, dtype: int64

# %%
lines_with_seasons.columns
# Out:
# Index(['episode', 'dialog', 'speaker', 'villain', 'year_x', 'season_x',
#        'episode_nr_x', 'title_x', 'description_x', 'title_1_x', 'title_2_x',
#        'year_y', 'season_y', 'episode_nr_y', 'title_y', 'description_y',
#        'title_1_y', 'title_2_y'],
#       dtype='object')

# %%
lines_with_seasons['season'] = np.where(lines_with_seasons['season_x'].notna(), lines_with_seasons['season_x'], lines_with_seasons['season_y'])
lines_with_seasons['episode_nr'] = np.where(lines_with_seasons['episode_nr_x'].notna(), lines_with_seasons['episode_nr_x'], lines_with_seasons['episode_nr_y'])
lines_with_seasons['description'] = np.where(lines_with_seasons['description_x'].notna(), lines_with_seasons['description_x'], lines_with_seasons['description_y'])
lines_with_seasons['title_1'] = np.where(lines_with_seasons['title_1_x'].notna(), lines_with_seasons['title_1_x'], lines_with_seasons['title_1_y'])
lines_with_seasons['title_2'] = np.where(lines_with_seasons['title_2_x'].notna(), lines_with_seasons['title_2_x'], lines_with_seasons['title_2_y'])
lines_with_seasons['year'] = np.where(lines_with_seasons['year_x'].notna(), lines_with_seasons['year_x'], lines_with_seasons['year_y'])
lines_with_seasons['season'].value_counts()
# Out:
# 2.0    3006
# 6.0    2954
# 3.0    2922
# 1.0    2724
# 5.0    2584
# 4.0    2471
# Name: season, dtype: int64

# %%
lines_with_seasons['season'].isna().sum()
# Out:
# 0

# %%
lines_with_seasons.drop(columns=[
    'season_x', 'episode_nr_x',
       'title_x', 'description_x', 'title_1_x', 'title_2_x', 'season_y',
       'episode_nr_y', 'title_y', 'description_y', 'title_1_y', 'title_2_y', 'year_x', 'year_y' 
], inplace=True)

# %%
lines_with_seasons['episode_nr'] = np.where(lines_with_seasons['title_2'] == lines_with_seasons['episode'], lines_with_seasons['episode_nr'] + 0.2, lines_with_seasons['episode_nr'])
lines_with_seasons['episode_nr'] = np.where((lines_with_seasons['title_1'] == lines_with_seasons['episode']) & (lines_with_seasons['title_2'].notna()), lines_with_seasons['episode_nr'] + 0.1, lines_with_seasons['episode_nr'])

# %%
lines_with_seasons[lines_with_seasons['season'].isna()]['episode'].unique()
# Out:
# array([], dtype=object)

# %%
# NB They are all 2016, so for now I'm not too worried
lines_with_seasons[lines_with_seasons['dialog'].isna()]
# Out:
#                                 episode dialog speaker villain  season  \
# 12171  small world: heart to heartstone   None     NaN    None     3.0
#
#        episode_nr                                        description  \
# 12171        16.0  The Powerpuff Girls are sent to the arctic on ...
#
#                                 title_1 title_2    year
# 12171  small world: heart to heartstone     NaN  2016.0

# %%
lines_with_seasons.dropna(subset=['dialog'], inplace=True)

# %%
lines_with_seasons[lines_with_seasons['dialog'].isna()]
# Out:
# Empty DataFrame
# Columns: [episode, dialog, speaker, villain, season, episode_nr, description, title_1, title_2, year]
# Index: []

# %%
lines_with_seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16660 entries, 0 to 16660
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   episode      16660 non-null  object
#  1   dialog       16660 non-null  object
#  2   speaker      16524 non-null  object
#  3   villain      2605 non-null   object
#  4   season       16660 non-null  float64
#  5   episode_nr   16660 non-null  float64
#  6   description  16660 non-null  object
#  7   title_1      16660 non-null  object
#  8   title_2      12707 non-null  object
#  9   year         16660 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 1.4+ MB

# %%
lines_with_seasons.head()
# Out:
#          episode                                             dialog  \
# 0  a documentary  The city of Townsville. This is where the Powe...
# 1  a documentary  Oh, you might know them as those three cute li...
# 2  a documentary  I'm Brian, and this is my documentary. And you...
# 3  a documentary             Sugar... spice... and everything nice.
# 4  a documentary  Yep, those are pretty normal ingredients, all ...
#
#         speaker villain  season  episode_nr  \
# 0  brian larsen    None     5.0         9.1
# 1         brian    None     5.0         9.1
# 2         brian    None     5.0         9.1
# 3         brian    None     5.0         9.1
# 4         brian    None     5.0         9.1
#
#                                          description        title_1  \
# 0  ."Documentary" A film student attempts to do a...  a documentary
# 1  ."Documentary" A film student attempts to do a...  a documentary
# 2  ."Documentary" A film student attempts to do a...  a documentary
# 3  ."Documentary" A film student attempts to do a...  a documentary
# 4  ."Documentary" A film student attempts to do a...  a documentary
#
#            title_2    year
# 0  girls gone mild  1998.0
# 1  girls gone mild  1998.0
# 2  girls gone mild  1998.0
# 3  girls gone mild  1998.0
# 4  girls gone mild  1998.0

# %%
# Fill all lines without a speaker with the speaker before. CHECK!!
no_speakers = lines_with_seasons[lines_with_seasons['speaker'].isna()]
no_speakers.head()
# Out:
#            episode                                             dialog speaker  \
# 2579       cop out                          Back to you there, Kevin.     NaN
# 3757  dream scheme            It is the setting of this little story.     NaN
# 3759  dream scheme           Where people are dressed in PJ and robe.     NaN
# 3760  dream scheme  They kick off their slippers and climb into beds,     NaN
# 3761  dream scheme   Fluff up their pillows and lay down their heads.     NaN
#
#      villain  season  episode_nr  \
# 2579    None     3.0         5.2
# 3757    None     2.0         5.1
# 3759    None     2.0         5.1
# 3760    None     2.0         5.1
# 3761    None     2.0         5.1
#
#                                             description  \
# 2579  "Gettin' Twiggy With It" Mitch is told to take...
# 3757  "Dream Scheme" The Sandman would like a little...
# 3759  "Dream Scheme" The Sandman would like a little...
# 3760  "Dream Scheme" The Sandman would like a little...
# 3761  "Dream Scheme" The Sandman would like a little...
#
#                      title_1               title_2    year
# 2579  gettin' twiggy with it               cop out  1998.0
# 3757            dream scheme  you snooze, you lose  1998.0
# 3759            dream scheme  you snooze, you lose  1998.0
# 3760            dream scheme  you snooze, you lose  1998.0
# 3761            dream scheme  you snooze, you lose  1998.0

# %%
no_speakers.count()
# Out:
# episode        136
# dialog         136
# speaker          0
# villain          0
# season         136
# episode_nr     136
# description    136
# title_1        136
# title_2        128
# year           136
# dtype: int64

# %%
lines_with_seasons['speaker'].fillna(method='ffill', inplace=True)

# %%
lines_with_seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16660 entries, 0 to 16660
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   episode      16660 non-null  object
#  1   dialog       16660 non-null  object
#  2   speaker      16660 non-null  object
#  3   villain      2605 non-null   object
#  4   season       16660 non-null  float64
#  5   episode_nr   16660 non-null  float64
#  6   description  16660 non-null  object
#  7   title_1      16660 non-null  object
#  8   title_2      12707 non-null  object
#  9   year         16660 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 1.4+ MB

# %%
previous_no_speakers = lines_with_seasons[lines_with_seasons.index.isin(no_speakers.index)]
previous_no_speakers.count()
# Out:
# episode        136
# dialog         136
# speaker        136
# villain          0
# season         136
# episode_nr     136
# description    136
# title_1        136
# title_2        128
# year           136
# dtype: int64

# %%
previous_no_speakers.iloc[:10, :]
# Out:
#            episode                                             dialog  \
# 2579       cop out                          Back to you there, Kevin.
# 3757  dream scheme            It is the setting of this little story.
# 3759  dream scheme           Where people are dressed in PJ and robe.
# 3760  dream scheme  They kick off their slippers and climb into beds,
# 3761  dream scheme   Fluff up their pillows and lay down their heads.
# 3763  dream scheme             Enter the Sandman to do them up right.
# 3765  dream scheme        He pulls out a magical brown grain of sand.
# 3767  dream scheme     And out goes the victim, asleep for the night.
# 3769  dream scheme       The Sandman does his job, singing his ditty.
# 3771  dream scheme            Putting you to sleep is what I'm about.
#
#        speaker villain  season  episode_nr  \
# 2579  reporter    None     3.0         5.2
# 3757  narrator    None     2.0         5.1
# 3759  narrator    None     2.0         5.1
# 3760  narrator    None     2.0         5.1
# 3761  narrator    None     2.0         5.1
# 3763  narrator    None     2.0         5.1
# 3765  narrator    None     2.0         5.1
# 3767  narrator    None     2.0         5.1
# 3769  narrator    None     2.0         5.1
# 3771   sandman    None     2.0         5.1
#
#                                             description  \
# 2579  "Gettin' Twiggy With It" Mitch is told to take...
# 3757  "Dream Scheme" The Sandman would like a little...
# 3759  "Dream Scheme" The Sandman would like a little...
# 3760  "Dream Scheme" The Sandman would like a little...
# 3761  "Dream Scheme" The Sandman would like a little...
# 3763  "Dream Scheme" The Sandman would like a little...
# 3765  "Dream Scheme" The Sandman would like a little...
# 3767  "Dream Scheme" The Sandman would like a little...
# 3769  "Dream Scheme" The Sandman would like a little...
# 3771  "Dream Scheme" The Sandman would like a little...
#
#                      title_1               title_2    year
# 2579  gettin' twiggy with it               cop out  1998.0
# 3757            dream scheme  you snooze, you lose  1998.0
# 3759            dream scheme  you snooze, you lose  1998.0
# 3760            dream scheme  you snooze, you lose  1998.0
# 3761            dream scheme  you snooze, you lose  1998.0
# 3763            dream scheme  you snooze, you lose  1998.0
# 3765            dream scheme  you snooze, you lose  1998.0
# 3767            dream scheme  you snooze, you lose  1998.0
# 3769            dream scheme  you snooze, you lose  1998.0
# 3771            dream scheme  you snooze, you lose  1998.0

# %%
lines_with_seasons['word_count_for_line'] = lines_with_seasons['dialog'].str.split(' ')
lines_with_seasons['word_count_for_line'] = lines_with_seasons['word_count_for_line'].apply(len)
lines_with_seasons[['dialog', 'word_count_for_line']].head(15)
# Out:
#                                                dialog  word_count_for_line
# 0   The city of Townsville. This is where the Powe...                   11
# 1   Oh, you might know them as those three cute li...                  121
# 2   I'm Brian, and this is my documentary. And you...                   31
# 3              Sugar... spice... and everything nice.                    5
# 4   Yep, those are pretty normal ingredients, all ...                   34
# 5   The city of Townsville. A great city with many...                   31
# 6   The newly renovated and revitalized Old Townsv...                   24
# 7   Although this bus looks better than that corpo...                   22
# 8   There are other reminders and countless monume...                   15
# 9   Their photos have graced newspapers and tabloi...                    9
# 10  They have merchandising... and even their own ...                   38
# 11  My first visit was unannounced... and just as ...                   10
# 12  the girls flew away. Three bright streaks cut ...                   24
# 13  Okay... I'm driving up through the city, and t...                   21
# 14  I keep trying to get closer, but the battle ke...                   13

# %%
lines_1998 = lines_with_seasons[lines_with_seasons['year'] == 1998]

summed_speakers_1998 = lines_1998.groupby('speaker')['word_count_for_line'].sum().reset_index()
summed_speakers_1998 = summed_speakers_1998.sort_values('word_count_for_line', ascending=False).reset_index(drop=True)

# Add instances in which PPG speak all together to single girls, drop PPG column
pppg_value = summed_speakers_1998[summed_speakers_1998['speaker'] == 'powerpuff girls']['word_count_for_line'].values[0]
# summed_speakers_1998.loc[summed_speakers_1998['speaker'] == 'blossom', 'word_count_for_line'] += pppg_value
# summed_speakers_1998.loc[summed_speakers_1998['speaker'] == 'bubbles', 'word_count_for_line'] += pppg_value
# summed_speakers_1998.loc[summed_speakers_1998['speaker'] == 'buttercup', 'word_count_for_line'] += pppg_value
# summed_speakers_1998 = summed_speakers_1998[summed_speakers_1998['speaker'] != 'powerpuff girls']

summed_speakers_1998.head(50)
# Out:
#               speaker  word_count_for_line
# 0             blossom                21050
# 1           professor                14823
# 2            narrator                12839
# 3           buttercup                12609
# 4             bubbles                11962
# 5           mojo jojo                10387
# 6               mayor                 7573
# 7            ms keane                 2996
# 8   princess morbucks                 2861
# 9                 him                 2684
# 10                man                 1746
# 11          ms bellum                 1567
# 12                ace                 1449
# 13    powerpuff girls                 1352
# 14              brick                 1104
# 15              brian                 1041
# 16              woman                 1040
# 17             bernie                  915
# 18             sedusa                  817
# 19               dick                  802
# 20              fuzzy                  799
# 21        talking dog                  797
# 22            bossman                  700
# 23          whitfield                  680
# 24        major glory                  630
# 25          announcer                  624
# 26                cop                  533
# 27           marianne                  507
# 28           reporter                  496
# 29              thief                  489
# 30              billy                  448
# 31            monster                  448
# 32               mike                  421
# 33             harold                  373
# 34              gnome                  362
# 35       femme fatale                  350
# 36          mr. green                  324
# 37            sandman                  302
# 38               girl                  297
# 39              robin                  285
# 40              lenny                  268
# 41              mitch                  258
# 42                boy                  255
# 43            teacher                  253
# 44              snake                  252
# 45                253                  251
# 46                kid                  250
# 47             arturo                  248
# 48              butch                  244
# 49            burglar                  240

# %%
summed_speakers_1998['word_count_for_line'].sum()
# Out:
# 137275

# %%
lines_2016 = lines_with_seasons[lines_with_seasons['year'] == 2016]

summed_speakers_2016 = lines_2016.groupby('speaker')['word_count_for_line'].sum().reset_index()
summed_speakers_2016.sort_values('word_count_for_line', ascending=False).head(50).reset_index(drop=True)
# Out:
#               speaker  word_count_for_line
# 0             blossom                  716
# 1             bubbles                  626
# 2           buttercup                  509
# 3               sapna                  261
# 4           professor                  244
# 5   princess morbucks                  197
# 6              lester                  173
# 7                 man                  120
# 8               woman                  119
# 9           mojo jojo                   91
# 10              mayor                   48
# 11    powerpuff girls                   18
# 12              skull                   17
# 13               girl                   13
# 14               gnat                    7
# 15              geese                    6
# 16           ms keane                    4
# 17              voice                    3
# 18              barry                    1
# 19        derbytantes                    1

# %%
summed_villains = lines_1998.groupby('villain')['word_count_for_line'].sum().reset_index()
summed_villains = summed_villains.sort_values('word_count_for_line', ascending=False).reset_index(drop=True)
summed_villains.head(50)
# Out:
#               villain  word_count_for_line
# 0           mojo jojo                10387
# 1   princess morbucks                 2861
# 2                 him                 2684
# 3       gangreen gang                 2485
# 4      rowdyruff boys                 1593
# 5        smith family                  970
# 6         amoeba boys                  953
# 7              bernie                  915
# 8              sedusa                  817
# 9                dick                  802
# 10              fuzzy                  799
# 11       femme fatale                  350
# 12              gnome                  348
# 13              lenny                  268
# 14            sandman                  109

# %%
lines_with_seasons['villain'].value_counts().head(50)
# Out:
# mojo jojo            869
# gangreen gang        350
# rowdyruff boys       261
# him                  249
# princess morbucks    235
# amoeba boys          157
# fuzzy                111
# smith family         105
# sedusa                77
# dick                  62
# bernie                60
# lenny                 25
# femme fatale          23
# sandman               14
# gnome                  7
# Name: villain, dtype: int64

# %%
# Good: First 9 good guys (the lower range tend either to be one-epsiode characters, or an (unrelated) aggregate)
good_aggregate_1998 = summed_speakers_1998.loc[:20, :]
good_aggregate_1998
# Out:
#               speaker  word_count_for_line
# 0             blossom                21050
# 1           professor                14823
# 2            narrator                12839
# 3           buttercup                12609
# 4             bubbles                11962
# 5           mojo jojo                10387
# 6               mayor                 7573
# 7            ms keane                 2996
# 8   princess morbucks                 2861
# 9                 him                 2684
# 10                man                 1746
# 11          ms bellum                 1567
# 12                ace                 1449
# 13    powerpuff girls                 1352
# 14              brick                 1104
# 15              brian                 1041
# 16              woman                 1040
# 17             bernie                  915
# 18             sedusa                  817
# 19               dick                  802
# 20              fuzzy                  799

# %%
# All villains that are in top 50 most speaking people that are not an (unrelated) aggregate
villains_aggregate_1998 = summed_villains

# %%
good_aggregate_1998.to_json('./good_all.json', orient='records')
villains_aggregate_1998.to_json('./villains_all.json', orient='records')

# %%
good_aggregate_seasons_1998 = lines_1998.groupby(['speaker', 'season'])['word_count_for_line'].sum().reset_index()
good_aggregate_seasons_1998 = good_aggregate_seasons_1998.sort_values(['season', 'word_count_for_line'], ascending=[True, False]).reset_index(drop=True)
good_aggregate_seasons_1998 = good_aggregate_seasons_1998[
    (good_aggregate_seasons_1998['speaker'].isin([
        "blossom",
        "professor",
        "buttercup",
        "narrator",
        "bubbles",
        "mayor",
        "ms keane",
        "ms bellum"
    ])) | (good_aggregate_seasons_1998['word_count_for_line'] > 250)
]
good_aggregate_seasons_1998.head(50)
# Out:
#                speaker  season  word_count_for_line
# 0              blossom     1.0                 3215
# 1             narrator     1.0                 2835
# 2            mojo jojo     1.0                 2223
# 3              bubbles     1.0                 2162
# 4            buttercup     1.0                 1871
# 5            professor     1.0                 1794
# 6                mayor     1.0                 1747
# 7                  him     1.0                  531
# 8                  ace     1.0                  406
# 9            ms bellum     1.0                  378
# 10               fuzzy     1.0                  353
# 11              sedusa     1.0                  325
# 12                 man     1.0                  298
# 13            ms keane     1.0                  254
# 14                 253     1.0                  251
# 110            blossom     2.0                 3556
# 111           narrator     2.0                 3027
# 112          buttercup     2.0                 2136
# 113            bubbles     2.0                 1891
# 114          professor     2.0                 1849
# 115          mojo jojo     2.0                 1525
# 116           ms keane     2.0                 1222
# 117              mayor     2.0                 1013
# 118  princess morbucks     2.0                  905
# 119           marianne     2.0                  507
# 120          ms bellum     2.0                  421
# 121             harold     2.0                  373
# 122                man     2.0                  335
# 123          whitfield     2.0                  334
# 124            sandman     2.0                  302
# 125                ace     2.0                  298
# 126    powerpuff girls     2.0                  294
# 127              billy     2.0                  288
# 128              lenny     2.0                  268
# 207            blossom     3.0                 3993
# 208          professor     3.0                 2470
# 209          buttercup     3.0                 2189
# 210            bubbles     3.0                 1958
# 211              mayor     3.0                 1820
# 212          mojo jojo     3.0                 1675
# 213           narrator     3.0                 1601
# 214  princess morbucks     3.0                  687
# 215          ms bellum     3.0                  465
# 216       femme fatale     3.0                  350
# 217          announcer     3.0                  315
# 218                man     3.0                  293
# 219              woman     3.0                  280
# 220               mike     3.0                  275
# 232           ms keane     3.0                  126
# 307          professor     4.0                 3091

# %%
villains_aggregate_seasons_1998 = lines_1998.groupby(['villain', 'season'])['word_count_for_line'].sum().reset_index()
villains_aggregate_seasons_1998 = villains_aggregate_seasons_1998.sort_values(['season', 'word_count_for_line'], ascending=[True, False]).reset_index(drop=True)
villains_aggregate_seasons_1998.head(50)
# Out:
#               villain  season  word_count_for_line
# 0           mojo jojo     1.0                 2223
# 1       gangreen gang     1.0                  731
# 2                 him     1.0                  531
# 3               fuzzy     1.0                  353
# 4              sedusa     1.0                  325
# 5         amoeba boys     1.0                  301
# 6      rowdyruff boys     1.0                  154
# 7        smith family     1.0                    6
# 8           mojo jojo     2.0                 1525
# 9        smith family     2.0                  944
# 10  princess morbucks     2.0                  905
# 11      gangreen gang     2.0                  759
# 12              lenny     2.0                  268
# 13        amoeba boys     2.0                  248
# 14                him     2.0                  196
# 15             sedusa     2.0                  146
# 16            sandman     2.0                  109
# 17     rowdyruff boys     2.0                    5
# 18          mojo jojo     3.0                 1675
# 19  princess morbucks     3.0                  687
# 20       femme fatale     3.0                  350
# 21      gangreen gang     3.0                  298
# 22                him     3.0                  152
# 23              fuzzy     3.0                  125
# 24          mojo jojo     4.0                 1489
# 25                him     4.0                 1016
# 26             bernie     4.0                  915
# 27               dick     4.0                  802
# 28  princess morbucks     4.0                  661
# 29        amoeba boys     4.0                   11
# 30      gangreen gang     4.0                    3
# 31     rowdyruff boys     5.0                 1327
# 32          mojo jojo     5.0                  622
# 33  princess morbucks     5.0                  608
# 34                him     5.0                  542
# 35      gangreen gang     5.0                  358
# 36              gnome     5.0                  348
# 37        amoeba boys     5.0                  343
# 38              fuzzy     5.0                  185
# 39       smith family     5.0                   20
# 40          mojo jojo     6.0                 2853
# 41             sedusa     6.0                  346
# 42      gangreen gang     6.0                  336
# 43                him     6.0                  247
# 44              fuzzy     6.0                  136
# 45     rowdyruff boys     6.0                  107
# 46        amoeba boys     6.0                   50

# %%
good_aggregate_seasons_1998.to_json('./good_seasons.json', orient='records')
villains_aggregate_seasons_1998.to_json('./villains_seasons.json', orient='records')

# %%
good_aggregate_episodes_1998 = lines_1998.groupby(['speaker', 'season', 'episode_nr', 'episode'])['word_count_for_line'].sum().reset_index()
good_aggregate_episodes_1998 = good_aggregate_episodes_1998.sort_values(['season', 'episode_nr', 'episode', 'word_count_for_line'], ascending=[True, True, True, False]).reset_index(drop=True)
good_aggregate_episodes_1998 = good_aggregate_episodes_1998[
    (good_aggregate_episodes_1998['speaker'].isin([
        "blossom",
        "professor",
        "buttercup",
        "narrator",
        "bubbles",
        "mayor",
        "ms keane",
        "ms bellum"
    ])) | (good_aggregate_episodes_1998['word_count_for_line'] > 100)
]
good_aggregate_episodes_1998.head(50)
# Out:
#         speaker  season  episode_nr                episode  \
# 0     mojo jojo     1.0         1.1  monkey see, doggie do
# 1      narrator     1.0         1.1  monkey see, doggie do
# 2       blossom     1.0         1.1  monkey see, doggie do
# 3     professor     1.0         1.1  monkey see, doggie do
# 4         mayor     1.0         1.1  monkey see, doggie do
# 5       bubbles     1.0         1.1  monkey see, doggie do
# 6     buttercup     1.0         1.1  monkey see, doggie do
# 13       sedusa     1.0         1.2          mommy fearest
# 14    professor     1.0         1.2          mommy fearest
# 15     narrator     1.0         1.2          mommy fearest
# 16      blossom     1.0         1.2          mommy fearest
# 17      bubbles     1.0         1.2          mommy fearest
# 18    buttercup     1.0         1.2          mommy fearest
# 19        mayor     1.0         1.2          mommy fearest
# 25  roach coach     1.0         2.1          insect inside
# 26    professor     1.0         2.1          insect inside
# 27      blossom     1.0         2.1          insect inside
# 28     narrator     1.0         2.1          insect inside
# 29      bubbles     1.0         2.1          insect inside
# 30    buttercup     1.0         2.1          insect inside
# 31        mayor     1.0         2.1          insect inside
# 37    ms bellum     1.0         2.1          insect inside
# 38        mayor     1.0         2.2        powerpuff bluff
# 39          253     1.0         2.2        powerpuff bluff
# 40      blossom     1.0         2.2        powerpuff bluff
# 41    ms bellum     1.0         2.2        powerpuff bluff
# 42     narrator     1.0         2.2        powerpuff bluff
# 44    buttercup     1.0         2.2        powerpuff bluff
# 48      bubbles     1.0         2.2        powerpuff bluff
# 54          him     1.0         3.1              octi evil
# 55         octi     1.0         3.1              octi evil
# 56      bubbles     1.0         3.1              octi evil
# 57     narrator     1.0         3.1              octi evil
# 58      blossom     1.0         3.1              octi evil
# 59    buttercup     1.0         3.1              octi evil
# 60    professor     1.0         3.1              octi evil
# 61        mayor     1.0         3.1              octi evil
# 62      bossman     1.0         3.2           geshundfight
# 63      blossom     1.0         3.2           geshundfight
# 64    professor     1.0         3.2           geshundfight
# 65     narrator     1.0         3.2           geshundfight
# 66    buttercup     1.0         3.2           geshundfight
# 67        mayor     1.0         3.2           geshundfight
# 70      bubbles     1.0         3.2           geshundfight
# 74          ace     1.0         4.1            buttercrush
# 75     narrator     1.0         4.1            buttercrush
# 79      blossom     1.0         4.1            buttercrush
# 82      bubbles     1.0         4.1            buttercrush
# 84    buttercup     1.0         4.1            buttercrush
# 85        fuzzy     1.0         4.2            fuzzy logic
#
#     word_count_for_line
# 0                   325
# 1                   164
# 2                   101
# 3                    47
# 4                    42
# 5                    39
# 6                    22
# 13                  325
# 14                  193
# 15                  160
# 16                  120
# 17                   74
# 18                   70
# 19                   47
# 25                  238
# 26                  195
# 27                  175
# 28                  160
# 29                   67
# 30                   62
# 31                   45
# 37                    7
# 38                  278
# 39                  251
# 40                  156
# 41                  141
# 42                  115
# 44                   65
# 48                   18
# 54                  181
# 55                  140
# 56                  138
# 57                  135
# 58                  134
# 59                   97
# 60                   31
# 61                   13
# 62                  227
# 63                  222
# 64                  158
# 65                   93
# 66                   60
# 67                   54
# 70                   27
# 74                  304
# 75                  173
# 79                   33
# 82                    9
# 84                    2
# 85                  214

# %%
villains_aggregate_episodes_1998 = lines_1998.groupby(['villain', 'season', 'episode_nr', 'episode'])['word_count_for_line'].sum().reset_index()
villains_aggregate_episodes_1998 = villains_aggregate_episodes_1998.sort_values(['season', 'episode_nr', 'episode', 'word_count_for_line'], ascending=[True, True, True, False]).reset_index(drop=True)
villains_aggregate_episodes_1998.head(50)
# Out:
#               villain  season  episode_nr                    episode  \
# 0           mojo jojo     1.0         1.1      monkey see, doggie do
# 1              sedusa     1.0         1.2              mommy fearest
# 2                 him     1.0         3.1                  octi evil
# 3         amoeba boys     1.0         3.2               geshundfight
# 4      rowdyruff boys     1.0         3.2               geshundfight
# 5       gangreen gang     1.0         4.1                buttercrush
# 6               fuzzy     1.0         4.2                fuzzy logic
# 7       gangreen gang     1.0         6.1                telephonies
# 8           mojo jojo     1.0         6.1                telephonies
# 9                 him     1.0         6.1                telephonies
# 10              fuzzy     1.0         6.1                telephonies
# 11                him     1.0         6.2                 tough love
# 12          mojo jojo     1.0         7.2          mr. mojo's rising
# 13       smith family     1.0         8.1          paste makes waste
# 14          mojo jojo     1.0         9.1              bubblevicious
# 15          mojo jojo     1.0         9.2             the bare facts
# 16              fuzzy     1.0        10.2               impeach fuzz
# 17          mojo jojo     1.0        11.1    just another manic mojo
# 18          mojo jojo     1.0        12.0         the rowdyruff boys
# 19     rowdyruff boys     1.0        12.0         the rowdyruff boys
# 20  princess morbucks     2.0         1.1     stuck up, up, and away
# 21      gangreen gang     2.0         1.2         schoolhouse rocked
# 22              lenny     2.0         2.1                collect her
# 23       smith family     2.0         2.2             supper villain
# 24          mojo jojo     2.0         3.1              birthday bash
# 25        amoeba boys     2.0         3.1              birthday bash
# 26  princess morbucks     2.0         3.1              birthday bash
# 27                him     2.0         3.1              birthday bash
# 28     rowdyruff boys     2.0         3.1              birthday bash
# 29            sandman     2.0         5.1               dream scheme
# 30          mojo jojo     2.0         5.2       you snooze, you lose
# 31        amoeba boys     2.0         5.2       you snooze, you lose
# 32     rowdyruff boys     2.0         5.2       you snooze, you lose
# 33      gangreen gang     2.0         6.1              slave the day
# 34          mojo jojo     2.0         6.2              los dos mojos
# 35          mojo jojo     2.0         7.1     a very special blossom
# 36  princess morbucks     2.0         8.1                     mo job
# 37          mojo jojo     2.0         8.1                     mo job
# 38          mojo jojo     2.0         9.2                cootie gras
# 39       smith family     2.0        10.2              just desserts
# 40                him     2.0        12.1                speed demon
# 41          mojo jojo     2.0        12.2               mojo jonesin
# 42             sedusa     2.0        13.1          something's a ms.
# 43          mojo jojo     2.0        13.2  slumbering with the enemy
# 44          mojo jojo     3.0         2.2              child fearing
# 45          mojo jojo     3.0         3.0         criss cross crisis
# 46      gangreen gang     3.0         3.0         criss cross crisis
# 47              fuzzy     3.0         3.0         criss cross crisis
# 48  princess morbucks     3.0         4.2           bought and scold
# 49          mojo jojo     3.0         6.2     monkey see, doggie two
#
#     word_count_for_line
# 0                   325
# 1                   325
# 2                   181
# 3                   301
# 4                     5
# 5                   495
# 6                   214
# 7                   236
# 8                   102
# 9                    99
# 10                    7
# 11                  251
# 12                  431
# 13                    6
# 14                  113
# 15                  103
# 16                  132
# 17                  790
# 18                  359
# 19                  149
# 20                  545
# 21                  326
# 22                  268
# 23                  421
# 24                  180
# 25                  170
# 26                  103
# 27                   95
# 28                    3
# 29                  109
# 30                  288
# 31                   78
# 32                    2
# 33                  433
# 34                  316
# 35                   44
# 36                  257
# 37                  201
# 38                  169
# 39                  523
# 40                  101
# 41                  207
# 42                  146
# 43                  120
# 44                  315
# 45                  164
# 46                   26
# 47                   18
# 48                  555
# 49                  564

# %%
good_aggregate_episodes_1998.to_json('./good_episodes.json', orient='records')
villains_aggregate_episodes_1998.to_json('./villains_episodes.json', orient='records')

# %%
all_episodes = lines_1998.groupby(['season', 'episode_nr', 'episode', 'description'])['word_count_for_line'].sum().reset_index()
all_episodes = all_episodes.sort_values(['season', 'episode_nr', 'episode'], ascending=[True, True, True]).reset_index(drop=True)
all_episodes.head(50)
# Out:
#     season  episode_nr                                            episode  \
# 0      1.0         1.1                              monkey see, doggie do
# 1      1.0         1.2                                      mommy fearest
# 2      1.0         2.1                                      insect inside
# 3      1.0         2.2                                    powerpuff bluff
# 4      1.0         3.1                                          octi evil
# 5      1.0         3.2                                       geshundfight
# 6      1.0         4.1                                        buttercrush
# 7      1.0         4.2                                        fuzzy logic
# 8      1.0         5.1                                     boogie frights
# 9      1.0         5.2                                        abracadaver
# 10     1.0         6.1                                        telephonies
# 11     1.0         6.2                                         tough love
# 12     1.0         7.1                                  major competition
# 13     1.0         7.2                                  mr. mojo's rising
# 14     1.0         8.1                                  paste makes waste
# 15     1.0         8.2                                           ice sore
# 16     1.0         9.1                                      bubblevicious
# 17     1.0         9.2                                     the bare facts
# 18     1.0        10.1                                         cat man do
# 19     1.0        10.2                                       impeach fuzz
# 20     1.0        11.1                            just another manic mojo
# 21     1.0        11.2                                  mime for a change
# 22     1.0        12.0                                 the rowdyruff boys
# 23     1.0        13.0                                       uh oh dynamo
# 24     2.0         1.1                             stuck up, up, and away
# 25     2.0         1.2                                 schoolhouse rocked
# 26     2.0         2.1                                        collect her
# 27     2.0         2.2                                     supper villain
# 28     2.0         3.1                                      birthday bash
# 29     2.0         3.2                                 too pooped to puff
# 30     2.0         4.1                                   beat your greens
# 31     2.0         4.2                                      down 'n dirty
# 32     2.0         5.1                                       dream scheme
# 33     2.0         5.2                               you snooze, you lose
# 34     2.0         6.1                                      slave the day
# 35     2.0         6.2                                      los dos mojos
# 36     2.0         7.1                             a very special blossom
# 37     2.0         7.2                                   daylight savings
# 38     2.0         8.1                                             mo job
# 39     2.0         8.2                                           pet feud
# 40     2.0         9.1                                    imaginary fiend
# 41     2.0         9.2                                        cootie gras
# 42     2.0        10.1  the powerpuff girls' best rainy day adventure ...
# 43     2.0        10.2                                      just desserts
# 44     2.0        11.1                                     twisted sister
# 45     2.0        11.2                                           cover up
# 46     2.0        12.1                                        speed demon
# 47     2.0        12.2                                       mojo jonesin
# 48     2.0        13.1                                  something's a ms.
# 49     2.0        13.2                          slumbering with the enemy
#
#                                           description  word_count_for_line
# 0   In "Monkey See, Doggie Do", Mojo Jojo swipes s...                  803
# 1   In "Monkey See, Doggie Do", Mojo Jojo swipes s...                 1079
# 2   "Insect Inside" The city of Townsville becomes...                 1036
# 3   "Insect Inside" The city of Townsville becomes...                 1271
# 4   "Octi-Evil" Him is out to break up the Powerpu...                  869
# 5   "Octi-Evil" Him is out to break up the Powerpu...                  924
# 6   "Buttercrush" Buttercup develops a crush on Ac...                  735
# 7   "Buttercrush" Buttercup develops a crush on Ac...                  601
# 8   In "Boogie Frights", the Boogie Man comes up w...                 1125
# 9   In "Boogie Frights", the Boogie Man comes up w...                  530
# 10  "Telephonies" The Gangreen Gang gets hold of t...                  928
# 11  "Telephonies" The Gangreen Gang gets hold of t...                  813
# 12  "Major Competition" The Powerpuff Girl's place...                  940
# 13  "Major Competition" The Powerpuff Girl's place...                  981
# 14  In "Paste Makes Waste", one of the Pokey Oaks ...                  764
# 15  In "Paste Makes Waste", one of the Pokey Oaks ...                  964
# 16  Bubbles is tired of being the cute and wants t...                  854
# 17  Bubbles is tired of being the cute and wants t...                 1634
# 18  "Cat Man Do" The Girls save an innocent little...                  704
# 19  "Cat Man Do" The Girls save an innocent little...                  785
# 20  In "Just Another Manic Mojo", Mojo Jojo's morn...                 1140
# 21  In "Just Another Manic Mojo", Mojo Jojo's morn...                  795
# 22  Mojo Jojo is so outraged at his constant defea...                 1086
# 23  Worried about his little girls' safety, the Pr...                  613
# 24  "Stuck Up, Up, and Away" Bratty little Princes...                 1199
# 25  "Stuck Up, Up, and Away" Bratty little Princes...                 1207
# 26  "Collect Her" Lenny Baxter, a rabid fan of Pow...                  845
# 27  "Collect Her" Lenny Baxter, a rabid fan of Pow...                 1011
# 28  "Birthday Bash" It's the Girls birthday, and t...                 1057
# 29  "Birthday Bash" It's the Girls birthday, and t...                  932
# 30  "Beat Your Greens" When Broccoli Aliens from s...                 1113
# 31  "Beat Your Greens" When Broccoli Aliens from s...                  477
# 32  "Dream Scheme" The Sandman would like a little...                 1174
# 33  "Dream Scheme" The Sandman would like a little...                  833
# 34  "Slave the Day" When the Girls save Big Billy'...                  918
# 35  "Slave the Day" When the Girls save Big Billy'...                 1038
# 36  "A Very Special Blossom" When the Professor wa...                 1319
# 37  "A Very Special Blossom" When the Professor wa...                  936
# 38  "Mo Job" Princess hires Mojo to devise the per...                  756
# 39  "Mo Job" Princess hires Mojo to devise the per...                  760
# 40  In "Imaginary Fiend", a new kid at school prov...                  995
# 41  In "Imaginary Fiend", a new kid at school prov...                  644
# 42  "The Powerpuff Girls Best Rainy Day Adventure ...                 1376
# 43  "The Powerpuff Girls Best Rainy Day Adventure ...                  757
# 44  After finding themselves far too tired after a...                  762
# 45  After finding themselves far too tired after a...                  499
# 46  "Speed Demon" The Girls accidentally fly the s...                  871
# 47  "Speed Demon" The Girls accidentally fly the s...                  757
# 48  "Something's a Ms." Miss Bellum is acting very...                 1092
# 49  "Something's a Ms." Miss Bellum is acting very...                  453

# %%
all_episodes.to_json('./all_episodes.json', orient='records')

# %%
top_per_good = good_aggregate_episodes_1998[good_aggregate_episodes_1998['speaker'].isin(['blossom', 'bubbles', 'buttercup', 'professor', 'narrator'])]
top_per_good = top_per_good.groupby('speaker').apply(lambda x: x.nlargest(10, 'word_count_for_line')).reset_index(drop=True)

top_per_good = top_per_good.sort_values(['speaker', 'word_count_for_line'], ascending=[True, False])

top_per_villain = villains_aggregate_episodes_1998.groupby('villain').apply(lambda x: x.nlargest(10, 'word_count_for_line')).reset_index(drop=True)
top_per_villain = top_per_villain.sort_values(['villain', 'word_count_for_line'], ascending=[True, False])
    
top_per_good
# Out:
#       speaker  season  episode_nr  \
# 0     blossom     2.0        10.1
# 1     blossom     1.0         9.2
# 2     blossom     4.0         4.0
# 3     blossom     6.0        12.1
# 4     blossom     4.0        12.0
# 5     blossom     5.0         5.0
# 6     blossom     4.0         7.0
# 7     blossom     3.0        10.1
# 8     blossom     5.0        13.1
# 9     blossom     4.0        10.0
# 10    bubbles     1.0         9.2
# 11    bubbles     2.0        10.1
# 12    bubbles     6.0        15.2
# 13    bubbles     1.0        11.2
# 14    bubbles     4.0         7.0
# 15    bubbles     1.0         9.1
# 16    bubbles     4.0         2.0
# 17    bubbles     3.0        13.1
# 18    bubbles     2.0         6.2
# 19    bubbles     6.0         9.1
# 20  buttercup     3.0         3.0
# 21  buttercup     2.0        10.1
# 22  buttercup     5.0         5.0
# 23  buttercup     1.0         9.2
# 24  buttercup     3.0        12.1
# 25  buttercup     4.0         2.0
# 26  buttercup     3.0         6.1
# 27  buttercup     4.0        12.0
# 28  buttercup     5.0        13.1
# 29  buttercup     6.0        14.1
# 30   narrator     6.0        15.1
# 31   narrator     2.0         5.1
# 32   narrator     4.0         8.0
# 33   narrator     6.0         5.0
# 34   narrator     2.0         4.1
# 35   narrator     6.0        10.2
# 36   narrator     1.0         5.1
# 37   narrator     1.0        13.0
# 38   narrator     2.0         7.2
# 39   narrator     1.0         4.1
# 40  professor     4.0         3.0
# 41  professor     4.0         8.0
# 42  professor     5.0         3.2
# 43  professor     6.0         6.1
# 44  professor     6.0         4.2
# 45  professor     6.0        13.1
# 46  professor     2.0         7.1
# 47  professor     3.0        11.0
# 48  professor     4.0         1.0
# 49  professor     6.0        12.2
#
#                                               episode  word_count_for_line
# 0   the powerpuff girls' best rainy day adventure ...                  525
# 1                                      the bare facts                  462
# 2                                   him diddle riddle                  431
# 3                                crazy mixed up puffs                  396
# 4                                          power-noia                  377
# 5                           the boys are back in town                  341
# 6                                        superfriends                  336
# 7                               the headsucker's moxy                  310
# 8                                              curses                  298
# 9                                          forced kin                  284
# 10                                     the bare facts                  375
# 11  the powerpuff girls' best rainy day adventure ...                  371
# 12                                          octi gone                  343
# 13                                  mime for a change                  331
# 14                                       superfriends                  313
# 15                                      bubblevicious                  308
# 16                                     all chalked up                  260
# 17                                     helter shelter                  256
# 18                                      los dos mojos                  248
# 19                                 that's not my baby                  240
# 20                                 criss cross crisis                  337
# 21  the powerpuff girls' best rainy day adventure ...                  280
# 22                          the boys are back in town                  272
# 23                                     the bare facts                  266
# 24                                        moral decay                  253
# 25                                     all chalked up                  243
# 26                          three girls and a monster                  234
# 27                                         power-noia                  229
# 28                                             curses                  213
# 29                                    nuthin' special                  204
# 30               i see a funny cartoon in your future                 1015
# 31                                       dream scheme                  635
# 32                                  nano of the north                  410
# 33                                    a made up story                  354
# 34                                   beat your greens                  277
# 35                                city of frownsville                  267
# 36                                     boogie frights                  229
# 37                                       uh oh dynamo                  200
# 38                                   daylight savings                  187
# 39                                        buttercrush                  173
# 40                                     get back, jojo                  756
# 41                                  nano of the north                  541
# 42                                    shotgun wedding                  493
# 43                             little miss interprets                  448
# 44                               oops, i did it again                  447
# 45                                     roughing it up                  436
# 46                             a very special blossom                  433
# 47                                         powerprof.                  426
# 48                                          film flam                  403
# 49                                   mizzen in action                  402

# %%
top_per_villain
# Out:
#          villain  season  episode_nr               episode  \
# 0    amoeba boys     5.0         2.2    divide and conquer
# 1    amoeba boys     1.0         3.2          geshundfight
# 2    amoeba boys     2.0         3.1         birthday bash
# 3    amoeba boys     2.0         5.2  you snooze, you lose
# 4    amoeba boys     6.0        10.1            sun scream
# ..           ...     ...         ...                   ...
# 75        sedusa     2.0        13.1     something's a ms.
# 76  smith family     2.0        10.2         just desserts
# 77  smith family     2.0         2.2        supper villain
# 78  smith family     5.0         4.2   substitute creature
# 79  smith family     1.0         8.1     paste makes waste
#
#     word_count_for_line
# 0                   332
# 1                   301
# 2                   170
# 3                    78
# 4                    48
# ..                  ...
# 75                  146
# 76                  523
# 77                  421
# 78                   20
# 79                    6
#
# [80 rows x 5 columns]

# %%
top_per_good.to_json('./good_top.json', orient='records')
top_per_villain.to_json('./villain_top.json', orient='records')

# %%
lines_1998[(lines_1998['season'] == 3)].groupby('episode').sum().head(50)
# Out:
# /var/folders/dy/hw0ckby90bxf_gm4t4jmb1yh0000gn/T/ipykernel_25533/2961070111.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   lines_1998[(lines_1998['season'] == 3)].groupby('episode').sum().head(50)
#                            season  episode_nr      year  word_count_for_line
# episode
# bought and scold            285.0       399.0  189810.0                 1100
# bubblevision                327.0       446.9  217782.0                  701
# candy is dandy              336.0       907.2  223776.0                  765
# catastrophe                 240.0       656.0  159840.0                  457
# child fearing               261.0       191.4  173826.0                  828
# cop out                     258.0       447.2  171828.0                  897
# criss cross crisis          843.0       843.0  561438.0                 1961
# equal fights                390.0      1326.0  259740.0                 1255
# fallen arches               369.0       135.3  245754.0                 1175
# gettin' twiggy with it      195.0       331.5  129870.0                  472
# helter shelter              381.0      1663.7  253746.0                  941
# hot air buffoon             300.0       910.0  199800.0                 1122
# jewel of the aisle          246.0       582.2  163836.0                  720
# meet the beat-alls          456.0      1854.4  303696.0                 1472
# monkey see, doggie two      222.0       458.8  147852.0                  845
# moral decay                 303.0      1222.1  201798.0                  867
# ploys r' us                 417.0      1278.8  277722.0                  803
# power lunch                 264.0      1161.6  175824.0                  589
# powerprof.                  279.0      1023.0  185814.0                  878
# super zeroes                474.0      1137.6  315684.0                 1279
# the headsucker's moxy       279.0       939.3  185814.0                  652
# the mane event              234.0        93.6  155844.0                  695
# three girls and a monster   255.0       518.5  169830.0                  524
# town and out                300.0       210.0  199800.0                  935
